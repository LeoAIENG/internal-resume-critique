# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Fri Feb 14 18:53:24 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off | 00000000:0A:00.0 Off |                    0 |
# | N/A   29C    P0              57W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          Off | 00000000:0B:00.0 Off |                    0 |
# | N/A   28C    P0              51W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM4-80GB          Off | 00000000:0C:00.0 Off |                    0 |
# | N/A   35C    P0              52W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM4-80GB          Off | 00000000:0D:00.0 Off |                    0 |
# | N/A   30C    P0              58W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==2.5.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.5.1)
# Requirement already satisfied: torchao==0.6.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: torchvision==0.20.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: torchtune==0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: wandb==0.19.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.19.0)
# Requirement already satisfied: python-dotenv==1.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.0.1)
# Collecting peft
#   Downloading peft-0.14.0-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 KB 9.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: triton==3.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: networkx in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.5.8)
# Requirement already satisfied: fsspec in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (11.2.1.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (12.3.1.170)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (11.6.1.9)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (10.3.5.147)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.10/site-packages (from torchvision==0.20.1->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torchvision==0.20.1->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: omegaconf in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: safetensors in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: huggingface-hub in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: sentencepiece in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: tiktoken in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: blobfile>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: datasets in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: psutil in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (2.10.6)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (59.6.0)
# Requirement already satisfied: platformdirs in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (3.1.44)
# Requirement already satisfied: setproctitle in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (1.3.4)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (5.29.3)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (5.4.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (8.0.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft->-r requirements.txt (line 7)) (24.2)
# Collecting transformers
#   Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 39.1 MB/s eta 0:00:0000:0100:01
# Collecting accelerate>=0.21.0
#   Downloading accelerate-1.3.0-py3-none-any.whl (336 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 KB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: pycryptodomex>=3.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from blobfile>=2->torchtune==0.4.0->-r requirements.txt (line 4)) (3.21.0)
# Requirement already satisfied: lxml>=4.9 in /home/ubuntu/.local/lib/python3.10/site-packages (from blobfile>=2->torchtune==0.4.0->-r requirements.txt (line 4)) (5.3.1)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from blobfile>=2->torchtune==0.4.0->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.0->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb==0.19.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb==0.19.0->-r requirements.txt (line 5)) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (3.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (19.0.0)
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (3.11.12)
# Requirement already satisfied: xxhash in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (0.70.16)
# Requirement already satisfied: pandas in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (0.3.8)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ubuntu/.local/lib/python3.10/site-packages (from omegaconf->torchtune==0.4.0->-r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: regex>=2022.1.18 in /home/ubuntu/.local/lib/python3.10/site-packages (from tiktoken->torchtune==0.4.0->-r requirements.txt (line 4)) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 83.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (1.18.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2.4.6)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2025.1)
# Installing collected packages: tokenizers, transformers, accelerate, peft
# Successfully installed accelerate-1.3.0 peft-0.14.0 tokenizers-0.21.0 transformers-4.48.3

# %%
from IPython import get_ipython
from IPython.core.magic import register_cell_magic

ipython = get_ipython()
@register_cell_magic
def pybash(line, cell):
    ipython.run_cell_magic('bash', '', cell.format(**globals()))

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ## Configuration

# %%
import os

# %%
## CONFIG
NUM_GPUS = 4
HF_TOKEN = os.environ["HF_TOKEN_R"]
IGNORE_PATTERNS = "original/consolidated*"
CONFIG_FILE = "llama_3_1_8b_lora_distributed.yaml"

## MODEL
ORGANIZATION = "multimodalai"
BASE_MODEL_HF_ID = "meta-llama/Llama-3.1-8B"
CLIENT = "resume-critique"
MODEL = "llama3_1_8b"
MODEL_NUMBER = "4"
REV_N = "3"
FT_METHOD = "tt_lora"
MODEL_TYPE = "adapter"

MDATA_ID = f"model_{MODEL_NUMBER}_2k"
REV = f"rev_{REV_N}"
FT_MODEL_NAME = f"{CLIENT}-{MODEL}-{FT_METHOD}-{MDATA_ID}-{MODEL_TYPE}-{REV}"
FT_MODEL_HF_ID = f"multimodalai/{FT_MODEL_NAME}"

## DATASET
TRAINING_DATA = "resume_critique_model_4_v3.jsonl"
TEST_DATA = "resume_critique_model_4_test.jsonl"

## PATH
BASE_MODEL_PATH = "base_model/"
TOKENIZER_PATH = f"{BASE_MODEL_PATH}/original/tokenizer.model"
OUTPUT_MODEL_PATH = f"checkpoint/{ORGANIZATION}/{FT_MODEL_NAME}"
TRAINING_DATA_PATH = f"data/{TRAINING_DATA}"
TEST_DATA_PATH = f"data/{TEST_DATA}"
CONFIG_FILE_PATH = f"config/{CONFIG_FILE}"

## TRACKING
WANDB_GROUP_NAME = CLIENT
RUN_WANDB_NAME = f"run-{FT_MODEL_NAME}"
LOGS_PATH = "logs/"

# %%
# !mkdir -p {OUTPUT_MODEL_PATH}
# !mkdir -p {LOGS_PATH}

# %% [markdown]
# ## Download Base Model

# %%
# %%pybash
# tune download {BASE_MODEL_HF_ID} --output-dir {BASE_MODEL_PATH} --ignore-patterns {IGNORE_PATTERNS} --hf-token {HF_TOKEN}
# Out:
# Ignoring files matching the following patterns: original/consolidated*
# Fetching 16 files: 100%|██████████| 16/16 [01:59<00:00,  7.44s/it]
# Successfully downloaded model repo and wrote to the following locations:
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/special_tokens_map.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/.gitattributes
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/tokenizer.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/LICENSE
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/model.safetensors.index.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/tokenizer_config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/model-00004-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/README.md
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/original
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/USE_POLICY.md
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/generation_config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/model-00003-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/.cache
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/model-00001-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_4_rev_3/base_model/model-00002-of-00004.safetensors

# %% [markdown]
# ## Fine-Tune

# %%
# %%pybash
# tune run \
#     --nproc_per_node {NUM_GPUS} \
#     lora_finetune_distributed \
#     --config {CONFIG_FILE_PATH} \
#     tokenizer.path={TOKENIZER_PATH} \
#     checkpointer.checkpoint_dir={BASE_MODEL_PATH} \
#     checkpointer.output_dir={OUTPUT_MODEL_PATH} \
#     dataset.data_files={TRAINING_DATA_PATH} \
#     metric_logger.group={WANDB_GROUP_NAME} \
#     metric_logger.name={RUN_WANDB_NAME} \
# 	output_dir={OUTPUT_MODEL_PATH} \
# 	metric_logger.log_dir={LOGS_PATH}
# Out:
# Running with torchrun...
# W0214 16:29:03.540000 10538 torch/distributed/run.py:793]
# W0214 16:29:03.540000 10538 torch/distributed/run.py:793] *****************************************
# W0214 16:29:03.540000 10538 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0214 16:29:03.540000 10538 torch/distributed/run.py:793] *****************************************
# INFO:torchtune.utils._logging:Running LoRAFinetuneRecipeDistributed with resolved config:
#
# batch_size: 8
# checkpointer:
#   _component_: torchtune.training.FullModelHFCheckpointer
#   checkpoint_dir: base_model/
#   checkpoint_files:
#   - model-00001-of-00004.safetensors
#   - model-00002-of-00004.safetensors
#   - model-00003-of-00004.safetensors
#   - model-00004-of-00004.safetensors
#   model_type: LLAMA3
#   output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
#   recipe_checkpoint: null
# compile: false
# dataset:
#   _component_: torchtune.datasets.alpaca_dataset
#   data_files: data/resume_critique_model_4_v3.jsonl
#   packed: false
#   source: json
# device: cuda
# dtype: bf16
# enable_activation_checkpointing: true
# enable_activation_offloading: false
# epochs: 3
# gradient_accumulation_steps: 4
# log_every_n_steps: 1
# log_peak_memory_stats: true
# loss:
#   _component_: torchtune.modules.loss.CEWithChunkedOutputLoss
# lr_scheduler:
#   _component_: torchtune.training.lr_schedulers.get_cosine_schedule_with_warmup
#   num_warmup_steps: 30
# max_steps_per_epoch: null
# metric_logger:
#   _component_: torchtune.training.metric_logging.WandBLogger
#   group: resume-critique
#   log_dir: logs/
#   name: run-resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
# model:
#   _component_: torchtune.models.llama3_1.lora_llama3_1_8b
#   apply_lora_to_mlp: true
#   apply_lora_to_output: true
#   lora_alpha: 16
#   lora_attn_modules:
#   - q_proj
#   - k_proj
#   - v_proj
#   lora_dropout: 0.05
#   lora_rank: 8
# optimizer:
#   _component_: torch.optim.AdamW
#   fused: true
#   lr: 0.0003
#   weight_decay: 0.01
# output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
# profiler:
#   _component_: torchtune.training.setup_torch_profiler
#   active_steps: 2
#   cpu: true
#   cuda: true
#   enabled: false
#   num_cycles: 1
#   output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/profiling_outputs
#   profile_memory: false
#   record_shapes: true
#   wait_steps: 5
#   warmup_steps: 3
#   with_flops: false
#   with_stack: false
# resume_from_checkpoint: false
# save_adapter_weights_only: false
# seed: 42
# shuffle: true
# tokenizer:
#   _component_: torchtune.models.llama3.llama3_tokenizer
#   max_seq_len: 4096
#   path: base_model//original/tokenizer.model
#
# DEBUG:torchtune.utils._logging:Setting manual seed to local seed 42. Local seed is seed + rank = 42 + 0
# INFO:torchtune.utils._logging:Hint: enable_activation_checkpointing is True, but enable_activation_offloading isn't. Enabling activation offloading should reduce memory further.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: leonardo-mm (multimodalcompany). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.0
# wandb: Run data is saved locally in logs/wandb/run-20250214_162908-p4qn70zo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run run-resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
# wandb: ⭐️ View project at https://wandb.ai/multimodalcompany/torchtune
# wandb: 🚀 View run at https://wandb.ai/multimodalcompany/torchtune/runs/p4qn70zo
# INFO:torchtune.utils._logging:Logging base_model/torchtune_config.yaml to W&B under Files
# INFO:torchtune.utils._logging:FSDP is enabled. Instantiating model and loading checkpoint on Rank 0 ...
# INFO:torchtune.utils._logging:Instantiating model and loading checkpoint took 5.13 secs
# INFO:torchtune.utils._logging:Memory stats after model init:
# 	GPU peak memory allocation: 4.76 GiB
# 	GPU peak memory reserved: 4.86 GiB
# 	GPU peak memory active: 4.76 GiB
# INFO:torchtune.utils._logging:Optimizer is initialized.
# INFO:torchtune.utils._logging:Loss is initialized.
# Generating train split: 7322 examples [00:00, 17398.67 examples/s]
# INFO:torchtune.utils._logging:Dataset and Sampler are initialized.
# INFO:torchtune.utils._logging:Learning rate scheduler is initialized.
# WARNING:torchtune.utils._logging: Profiling disabled.
# INFO:torchtune.utils._logging: Profiler config after instantiation: {'enabled': False}
# 1|57|Loss: 1.6692761182785034: 100%|██████████| 57/57 [37:45<00:00, 39.22s/it]9702:  11%|█         | 6/57 [03:56<33:29, 39.41s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 9.98 secs
# INFO:torchtune.utils._logging:Retrieving optimizer state dict...
# INFO:torchtune.utils._logging:Getting optimizer state dict took 10.22 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0001_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0002_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0003_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0004_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.08 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/recipe_state.pt
# INFO:torchtune.utils._logging:Saving checkpoint took 23.83 secs
# 1|57|Loss: 1.6692761182785034: 100%|██████████| 57/57 [38:20<00:00, 40.35s/it]
#
#   2%|▏         | 1/57 [00:39<37:13, 39.88s/it]
# 2|58|Loss: 1.6918237209320068:   2%|▏         | 1/57 [00:39<37:13, 39.88s/it]
# 2|58|Loss: 1.6918237209320068:   4%|▎         | 2/57 [01:18<35:51, 39.13s/it]
# 2|59|Loss: 1.7305264472961426:   4%|▎         | 2/57 [01:18<35:51, 39.13s/it]
# 2|59|Loss: 1.7305264472961426:   5%|▌         | 3/57 [01:59<35:54, 39.91s/it]
# 2|60|Loss: 1.7382038831710815:   5%|▌         | 3/57 [01:59<35:54, 39.91s/it]
# 2|60|Loss: 1.7382038831710815:   7%|▋         | 4/57 [02:40<35:35, 40.30s/it]
# 2|61|Loss: 1.811945915222168:   7%|▋         | 4/57 [02:40<35:35, 40.30s/it]
# 2|61|Loss: 1.811945915222168:   9%|▉         | 5/57 [03:19<34:42, 40.05s/it]
# 2|62|Loss: 1.71416175365448:   9%|▉         | 5/57 [03:19<34:42, 40.05s/it]
# 2|62|Loss: 1.71416175365448:  11%|█         | 6/57 [03:58<33:37, 39.56s/it]
# 2|63|Loss: 1.7212122678756714:  11%|█         | 6/57 [03:58<33:37, 39.56s/it]
# 2|63|Loss: 1.7212122678756714:  12%|█▏        | 7/57 [04:38<33:06, 39.72s/it]
# 2|64|Loss: 1.6686210632324219:  12%|█▏        | 7/57 [04:38<33:06, 39.72s/it]
# 2|64|Loss: 1.6686210632324219:  14%|█▍        | 8/57 [05:19<32:43, 40.07s/it]
# 2|65|Loss: 1.6428247690200806:  14%|█▍        | 8/57 [05:19<32:43, 40.07s/it]
# 2|65|Loss: 1.6428247690200806:  16%|█▌        | 9/57 [05:57<31:32, 39.43s/it]
# 2|66|Loss: 1.768449306488037:  16%|█▌        | 9/57 [05:57<31:32, 39.43s/it]
# 2|66|Loss: 1.768449306488037:  18%|█▊        | 10/57 [06:38<31:14, 39.88s/it]
# 2|67|Loss: 1.667847752571106:  18%|█▊        | 10/57 [06:38<31:14, 39.88s/it]
# 2|67|Loss: 1.667847752571106:  19%|█▉        | 11/57 [07:18<30:36, 39.92s/it]
# 2|68|Loss: 1.6218430995941162:  19%|█▉        | 11/57 [07:18<30:36, 39.92s/it]
# 2|68|Loss: 1.6218430995941162:  21%|██        | 12/57 [07:59<30:08, 40.20s/it]
# 2|69|Loss: 1.6525827646255493:  21%|██        | 12/57 [07:59<30:08, 40.20s/it]
# 2|69|Loss: 1.6525827646255493:  23%|██▎       | 13/57 [08:39<29:36, 40.38s/it]
# 2|70|Loss: 1.7104029655456543:  23%|██▎       | 13/57 [08:39<29:36, 40.38s/it]
# 2|70|Loss: 1.7104029655456543:  25%|██▍       | 14/57 [09:20<29:02, 40.52s/it]
# 2|71|Loss: 1.6507034301757812:  25%|██▍       | 14/57 [09:20<29:02, 40.52s/it]
# 2|71|Loss: 1.6507034301757812:  26%|██▋       | 15/57 [10:01<28:19, 40.46s/it]
# 2|72|Loss: 1.7084267139434814:  26%|██▋       | 15/57 [10:01<28:19, 40.46s/it]
# 2|72|Loss: 1.7084267139434814:  28%|██▊       | 16/57 [10:41<27:43, 40.57s/it]
# 2|73|Loss: 1.6690378189086914:  28%|██▊       | 16/57 [10:41<27:43, 40.57s/it]
# 2|73|Loss: 1.6690378189086914:  30%|██▉       | 17/57 [11:21<26:52, 40.31s/it]
# 2|74|Loss: 1.6577974557876587:  30%|██▉       | 17/57 [11:21<26:52, 40.31s/it]
# 2|74|Loss: 1.6577974557876587:  32%|███▏      | 18/57 [11:57<25:25, 39.12s/it]
# 2|75|Loss: 1.6494299173355103:  32%|███▏      | 18/57 [11:57<25:25, 39.12s/it]
# 2|75|Loss: 1.6494299173355103:  33%|███▎      | 19/57 [12:35<24:29, 38.68s/it]
# 2|76|Loss: 1.6616441011428833:  33%|███▎      | 19/57 [12:35<24:29, 38.68s/it]
# 2|76|Loss: 1.6616441011428833:  35%|███▌      | 20/57 [13:16<24:14, 39.32s/it]
# 2|77|Loss: 1.6358616352081299:  35%|███▌      | 20/57 [13:16<24:14, 39.32s/it]
# 2|77|Loss: 1.6358616352081299:  37%|███▋      | 21/57 [13:57<23:51, 39.77s/it]
# 2|78|Loss: 1.6436184644699097:  37%|███▋      | 21/57 [13:57<23:51, 39.77s/it]
# 2|78|Loss: 1.6436184644699097:  39%|███▊      | 22/57 [14:38<23:22, 40.08s/it]
# 2|79|Loss: 1.6872851848602295:  39%|███▊      | 22/57 [14:38<23:22, 40.08s/it]
# 2|79|Loss: 1.6872851848602295:  40%|████      | 23/57 [15:15<22:17, 39.35s/it]
# 2|80|Loss: 1.5608128309249878:  40%|████      | 23/57 [15:15<22:17, 39.35s/it]
# 2|80|Loss: 1.5608128309249878:  42%|████▏     | 24/57 [15:56<21:53, 39.79s/it]
# 2|81|Loss: 1.6481071710586548:  42%|████▏     | 24/57 [15:56<21:53, 39.79s/it]
# 2|81|Loss: 1.6481071710586548:  44%|████▍     | 25/57 [16:37<21:23, 40.10s/it]
# 2|82|Loss: 1.6121046543121338:  44%|████▍     | 25/57 [16:37<21:23, 40.10s/it]
# 2|82|Loss: 1.6121046543121338:  46%|████▌     | 26/57 [17:18<20:49, 40.32s/it]
# 2|83|Loss: 1.6196109056472778:  46%|████▌     | 26/57 [17:18<20:49, 40.32s/it]
# 2|83|Loss: 1.6196109056472778:  47%|████▋     | 27/57 [17:58<20:13, 40.47s/it]
# 2|84|Loss: 1.6490974426269531:  47%|████▋     | 27/57 [17:58<20:13, 40.47s/it]
# 2|84|Loss: 1.6490974426269531:  49%|████▉     | 28/57 [18:38<19:26, 40.24s/it]
# 2|85|Loss: 1.706346869468689:  49%|████▉     | 28/57 [18:38<19:26, 40.24s/it]
# 2|85|Loss: 1.706346869468689:  51%|█████     | 29/57 [19:13<17:58, 38.51s/it]
# 2|86|Loss: 1.5715528726577759:  51%|█████     | 29/57 [19:13<17:58, 38.51s/it]
# 2|86|Loss: 1.5715528726577759:  53%|█████▎    | 30/57 [19:53<17:38, 39.22s/it]
# 2|87|Loss: 1.616142988204956:  53%|█████▎    | 30/57 [19:53<17:38, 39.22s/it]
# 2|87|Loss: 1.616142988204956:  54%|█████▍    | 31/57 [20:31<16:43, 38.58s/it]
# 2|88|Loss: 1.682379961013794:  54%|█████▍    | 31/57 [20:31<16:43, 38.58s/it]
# 2|88|Loss: 1.682379961013794:  56%|█████▌    | 32/57 [21:11<16:19, 39.19s/it]
# 2|89|Loss: 1.6726375818252563:  56%|█████▌    | 32/57 [21:11<16:19, 39.19s/it]
# 2|89|Loss: 1.6726375818252563:  58%|█████▊    | 33/57 [21:49<15:28, 38.70s/it]
# 2|90|Loss: 1.6785513162612915:  58%|█████▊    | 33/57 [21:49<15:28, 38.70s/it]
# 2|90|Loss: 1.6785513162612915:  60%|█████▉    | 34/57 [22:28<14:52, 38.80s/it]
# 2|91|Loss: 1.645841360092163:  60%|█████▉    | 34/57 [22:28<14:52, 38.80s/it]
# 2|91|Loss: 1.645841360092163:  61%|██████▏   | 35/57 [23:09<14:26, 39.40s/it]
# 2|92|Loss: 1.6598854064941406:  61%|██████▏   | 35/57 [23:09<14:26, 39.40s/it]
# 2|92|Loss: 1.6598854064941406:  63%|██████▎   | 36/57 [23:48<13:49, 39.51s/it]
# 2|93|Loss: 1.619971513748169:  63%|██████▎   | 36/57 [23:48<13:49, 39.51s/it]
# 2|93|Loss: 1.619971513748169:  65%|██████▍   | 37/57 [24:28<13:11, 39.56s/it]
# 2|94|Loss: 1.6636652946472168:  65%|██████▍   | 37/57 [24:28<13:11, 39.56s/it]
# 2|94|Loss: 1.6636652946472168:  67%|██████▋   | 38/57 [25:09<12:38, 39.93s/it]
# 2|95|Loss: 1.6667128801345825:  67%|██████▋   | 38/57 [25:09<12:38, 39.93s/it]
# 2|95|Loss: 1.6667128801345825:  68%|██████▊   | 39/57 [25:45<11:40, 38.92s/it]
# 2|96|Loss: 1.6088752746582031:  68%|██████▊   | 39/57 [25:45<11:40, 38.92s/it]
# 2|96|Loss: 1.6088752746582031:  70%|███████   | 40/57 [26:26<11:11, 39.50s/it]
# 2|97|Loss: 1.701551079750061:  70%|███████   | 40/57 [26:26<11:11, 39.50s/it]
# 2|97|Loss: 1.701551079750061:  72%|███████▏  | 41/57 [27:07<10:35, 39.73s/it]
# 2|98|Loss: 1.7182888984680176:  72%|███████▏  | 41/57 [27:07<10:35, 39.73s/it]
# 2|98|Loss: 1.7182888984680176:  74%|███████▎  | 42/57 [27:47<10:01, 40.07s/it]
# 2|99|Loss: 1.711151361465454:  74%|███████▎  | 42/57 [27:47<10:01, 40.07s/it]
# 2|99|Loss: 1.711151361465454:  75%|███████▌  | 43/57 [28:26<09:14, 39.59s/it]
# 2|100|Loss: 1.5810351371765137:  75%|███████▌  | 43/57 [28:26<09:14, 39.59s/it]
# 2|100|Loss: 1.5810351371765137:  77%|███████▋  | 44/57 [29:03<08:23, 38.74s/it]
# 2|101|Loss: 1.6328403949737549:  77%|███████▋  | 44/57 [29:03<08:23, 38.74s/it]
# 2|101|Loss: 1.6328403949737549:  79%|███████▉  | 45/57 [29:42<07:45, 38.83s/it]
# 2|102|Loss: 1.664778232574463:  79%|███████▉  | 45/57 [29:42<07:45, 38.83s/it]
# 2|102|Loss: 1.664778232574463:  81%|████████  | 46/57 [30:22<07:11, 39.19s/it]
# 2|103|Loss: 1.6470674276351929:  81%|████████  | 46/57 [30:22<07:11, 39.19s/it]
# 2|103|Loss: 1.6470674276351929:  82%|████████▏ | 47/57 [31:00<06:29, 38.98s/it]
# 2|104|Loss: 1.6283717155456543:  84%|████████▍ | 48/57 [31:36<05:43, 38.17s/it]
# 2|105|Loss: 1.635135293006897:  86%|████████▌ | 49/57 [32:17<05:11, 38.97s/it]
# 2|106|Loss: 1.6945877075195312:  86%|████████▌ | 49/57 [32:17<05:11, 38.97s/it]
# 2|106|Loss: 1.6945877075195312:  88%|████████▊ | 50/57 [32:56<04:32, 38.99s/it]
# 2|107|Loss: 1.6380159854888916:  89%|████████▉ | 51/57 [33:37<03:57, 39.50s/it]
# 2|108|Loss: 1.6538103818893433:  91%|█████████ | 52/57 [34:17<03:17, 39.56s/it]
# 2|110|Loss: 1.603391170501709:  93%|█████████▎| 53/57 [34:55<02:37, 39.30s/it]
# 2|110|Loss: 1.603391170501709:  95%|█████████▍| 54/57 [35:36<01:58, 39.62s/it]
# 2|111|Loss: 1.6556965112686157:  95%|█████████▍| 54/57 [35:36<01:58, 39.62s/it]
# 2|112|Loss: 1.6224445104599:  96%|█████████▋| 55/57 [36:15<01:19, 39.53s/it]
# 2|112|Loss: 1.6224445104599:  98%|█████████▊| 56/57 [36:56<00:39, 39.92s/it]
# 2|113|Loss: 1.7166796922683716:  98%|█████████▊| 56/57 [36:56<00:39, 39.92s/it]
# 2|114|Loss: 1.5982626676559448: 100%|██████████| 57/57 [37:34<00:00, 39.32s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 9.72 secs
# INFO:torchtune.utils._logging:Retrieving optimizer state dict...
# INFO:torchtune.utils._logging:Getting optimizer state dict took 9.95 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0001_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0002_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0003_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0004_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.08 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/recipe_state.pt
# INFO:torchtune.utils._logging:Saving checkpoint took 25.89 secs
# 2|114|Loss: 1.5982626676559448: 100%|██████████| 57/57 [38:10<00:00, 40.19s/it]
# 3|171|Loss: 1.6295361518859863: 100%|██████████| 57/57 [37:18<00:00, 38.59s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 17.55 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0001_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0002_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0003_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/hf_model_0004_2.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_2.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Saving final epoch checkpoint.
# INFO:torchtune.utils._logging:The full model checkpoint, including all weights and configurations, has been saved successfully.You can now use this checkpoint for further training or inference.
# INFO:torchtune.utils._logging:Saving checkpoint took 34.25 secs
# 3|171|Loss: 1.6295361518859863: 100%|██████████| 57/57 [38:10<00:00, 40.19s/it]
# wandb:
# wandb:
# wandb: Run history:
# wandb:               global_step ▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:                      loss ▇██▇▇▃▂▃▃▃▃▂▂▃▂▂▂▂▂▂▁▁▂▁▂▁▂▂���▂▂▁▂▁▂▂▁▂▂▂
# wandb:                        lr ▁▂▄▇▇█████���███▇▇▇▇▆▆▆▆▆▅▅▄▄▄▃▃▃▃▂▂▂▁▁▁▁▁
# wandb:        peak_memory_active █▇▄███▁████▄█████▆█▆▄████��███████▅████▂█
# wandb:         peak_memory_alloc ███▇▁██��███▅▃█▇█▅████▆██▅████████▅██▂███
# wandb:      peak_memory_reserved ▁███████████████████████████████████████
# wandb: tokens_per_second_per_gpu ▇▇▇▇▆▇▇▇▆▆▆▇▆█▆▆▆▇▆▆▇█▇▇▇▇▁▇▆▇▇▆▇▇▆▇▇▆���█
# wandb:
# wandb: Run summary:
# wandb:               global_step 171
# wandb:                      loss 1.62954
# wandb:                        lr 0
# wandb:        peak_memory_active 40.13183
# wandb:         peak_memory_alloc 40.13183
# wandb:      peak_memory_reserved 53.20703
# wandb: tokens_per_second_per_gpu 1241.63745
# wandb:
# wandb: 🚀 View run run-resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3 at: https://wandb.ai/multimodalcompany/torchtune/runs/p4qn70zo
# wandb: ⭐️ View project at: https://wandb.ai/multimodalcompany/torchtune
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: logs/wandb/run-20250214_162908-p4qn70zo/logs

# %% [markdown]
# ## Save the Model

# %%
HF_TOKEN = os.environ["HF_TOKEN_W"]

# %%
# %%pybash
# huggingface-cli login --token {HF_TOKEN}
# huggingface-cli repo create -y --organization {ORGANIZATION} {FT_MODEL_NAME}
# huggingface-cli upload {FT_MODEL_HF_ID} {OUTPUT_MODEL_PATH}
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `leo-mm-write-token-2` has been saved to /home/ubuntu/.cache/huggingface/stored_tokens
# Your token has been saved to /home/ubuntu/.cache/huggingface/token
# Login successful.
# The current active token is: `leo-mm-write-token-2`
# git version 2.34.1
# Looks like you do not have git-lfs installed, please install. You can install from https://git-lfs.github.com/. Then run `git lfs install` (you only have to do this once).
#
# You are about to create multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
#
# Your repo now lives at:
#   https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Start hashing 19 files.
# Finished hashing 19 files.
# adapter_0.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
# adapter_1.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
# adapter_2.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
#
#
# Upload 17 LFS files:   0%|          | 0/17 [00:00<?, ?it/s]
#
#
# adapter_model.bin:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
#
#
#
# adapter_0.pt:   8%|▊         | 3.19M/40.0M [00:00<00:01, 31.9MB/s]
# adapter_1.pt:  21%|██        | 8.36M/40.0M [00:00<00:00, 83.4MB/s]
#
# adapter_2.pt:  10%|▉         | 3.85M/40.0M [00:00<00:00, 38.5MB/s]
#
#
# adapter_model.bin:  22%|██▏       | 8.68M/40.0M [00:00<00:00, 86.7MB/s]
#
#
#
#
# adapter_0.pt:  22%|██▏       | 8.60M/40.0M [00:00<00:01, 27.7MB/s]7MB/s]
#
#
# adapter_0.pt:  32%|███▏      | 12.7M/40.0M [00:00<00:00, 28.4MB/s]MB/s]
#
# adapter_2.pt:  22%|██▏       | 8.72M/40.0M [00:00<00:02, 15.4MB/s]
# adapter_1.pt:  42%|████▏     | 16.7M/40.0M [00:00<00:00, 28.3MB/s]
#
# adapter_2.pt:  38%|███▊      | 15.3M/40.0M [00:00<00:00, 24.8MB/s]
# adapter_1.pt:  80%|████████  | 32.0M/40.0M [00:00<00:00, 32.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:   0%|          | 17.1M/4.98G [00:01<05:52, 14.1MB/s]
#
# adapter_2.pt:  47%|████▋     | 18.8M/40.0M [00:01<00:01, 14.5MB/s]
#
#
#
#
# adapter_1.pt: 100%|██████████| 40.0M/40.0M [00:01<00:00, 28.9MB/s]8MB/s]
#
#
# adapter_2.pt:  69%|██████▉   | 27.6M/40.0M [00:01<00:00, 18.0MB/s]
#
#
# adapter_model.bin:  80%|████████  | 32.0M/40.0M [00:01<00:00, 16.9MB/s]
#
# adapter_2.pt:  79%|███████▊  | 31.4M/40.0M [00:01<00:00, 19.8MB/s]
# hf_model_0001_1.pt:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 26.6M/4.98G [00:01<06:22, 12.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 29.3M/4.98G [00:01<05:41, 14.5MB/s]
# hf_model_0001_1.pt:   0%|          | 16.0M/4.98G [00:00<01:41, 48.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 32.0M/4.98G [00:02<07:30, 11.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 45.3M/4.98G [00:02<03:16, 25.1MB/s]
#
# adapter_model.bin: 100%|██████████| 40.0M/40.0M [00:02<00:00, 15.8MB/s]A
#
# hf_model_0001_1.pt:   1%|          | 32.0M/4.98G [00:01<02:58, 27.8MB/s]
#
#
# hf_model_0001_2.pt:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# hf_model_0001_1.pt:   1%|          | 47.0M/4.98G [00:01<01:56, 42.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 51.0M/4.98G [00:02<04:30, 18.2MB/s]
#
#
# hf_model_0001_2.pt:   0%|          | 15.5M/4.98G [00:00<00:35, 141MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|          | 57.9M/4.98G [00:03<03:34, 22.9MB/s]
# adapter_2.pt: 100%|██████████| 40.0M/40.0M [00:03<00:00, 11.6MB/s]3MB/s]
#
#
#
#
#
# hf_model_0001_0.pt:   1%|▏         | 62.4M/4.98G [00:03<04:27, 18.4MB/s]
#
#
# hf_model_0001_2.pt:   1%|          | 29.6M/4.98G [00:00<02:06, 39.2MB/s]
# hf_model_0001_1.pt:   1%|▏         | 64.0M/4.98G [00:02<02:51, 28.7MB/s]
#
# hf_model_0002_0.pt:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
#
#
# hf_model_0001_2.pt:   1%|          | 36.9M/4.98G [00:00<02:27, 33.5MB/s]
#
#
# hf_model_0001_2.pt:   1%|          | 46.5M/4.98G [00:01<02:09, 37.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:   1%|▏         | 65.9M/4.98G [00:04<06:00, 13.6MB/s]
# hf_model_0001_1.pt:   2%|▏         | 80.0M/4.98G [00:02<02:26, 33.5MB/s]
#
# hf_model_0002_0.pt:   0%|          | 11.0M/5.00G [00:00<03:04, 27.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 79.9M/4.98G [00:04<03:07, 26.2MB/s]
#
# hf_model_0002_0.pt:   0%|          | 14.3M/5.00G [00:00<03:36, 23.0MB/s]
#
#
# hf_model_0001_2.pt:   1%|          | 51.5M/4.98G [00:01<03:24, 24.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 85.5M/4.98G [00:04<04:07, 19.8MB/s]
#
# hf_model_0002_0.pt:   0%|          | 16.4M/5.00G [00:01<06:21, 13.0MB/s]
#
#
# hf_model_0001_2.pt:   1%|▏         | 64.0M/4.98G [00:02<02:56, 27.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 96.0M/4.98G [00:04<03:17, 24.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 110M/4.98G [00:05<02:08, 37.9MB/s]
# hf_model_0001_1.pt:   2%|▏         | 96.0M/4.98G [00:03<03:21, 24.2MB/s]
#
# hf_model_0002_0.pt:   1%|          | 27.0M/5.00G [00:01<04:21, 19.0MB/s]
#
#
# hf_model_0001_2.pt:   2%|▏         | 80.0M/4.98G [00:02<02:27, 33.1MB/s]
#
# hf_model_0002_0.pt:   1%|          | 28.9M/5.00G [00:01<04:24, 18.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 117M/4.98G [00:05<03:06, 26.1MB/s]
#
# adapter_0.pt:  40%|████      | 16.0M/40.0M [00:05<00:13, 1.78MB/s]3MB/s]
#
#
# hf_model_0001_2.pt:   2%|▏         | 96.0M/4.98G [00:02<02:39, 30.6MB/s]
# hf_model_0001_1.pt:   2%|▏         | 112M/4.98G [00:04<04:01, 20.1MB/s]
#
# hf_model_0002_0.pt:   1%|          | 42.9M/5.00G [00:02<04:27, 18.5MB/s]
#
#
# adapter_0.pt:  80%|████████  | 32.0M/40.0M [00:06<00:01, 5.36MB/s]MB/s]
#
# hf_model_0002_0.pt:   1%|          | 44.8M/5.00G [00:02<04:27, 18.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:   3%|▎         | 128M/4.98G [00:06<03:55, 20.6MB/s]
# hf_model_0001_1.pt:   3%|▎         | 128M/4.98G [00:04<03:10, 25.4MB/s]
#
# hf_model_0002_0.pt:   1%|          | 48.0M/5.00G [00:02<06:11, 13.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:   3%|▎         | 144M/4.98G [00:06<03:21, 24.0MB/s]
#
#
# hf_model_0001_2.pt:   3%|▎         | 128M/4.98G [00:04<03:01, 26.6MB/s]
#
# hf_model_0002_0.pt:   1%|          | 59.8M/5.00G [00:03<04:33, 18.1MB/s]
#
#
#
#
# adapter_0.pt: 100%|██████████| 40.0M/40.0M [00:07<00:00, 5.59MB/s]MB/s]
#
# hf_model_0001_1.pt:   3%|▎         | 144M/4.98G [00:05<03:26, 23.4MB/s]
#
# hf_model_0002_0.pt:   1%|▏         | 63.4M/5.00G [00:03<04:16, 19.3MB/s]
#
#
#
# hf_model_0002_1.pt:   0%|          | 0.00/5.00G [00:00<?, ?B/s]/it]
# hf_model_0001_1.pt:   3%|▎         | 160M/4.98G [00:05<02:50, 28.2MB/s]
#
#
# hf_model_0001_2.pt:   3%|▎         | 144M/4.98G [00:04<02:53, 27.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:   4%|▎         | 176M/4.98G [00:07<02:29, 32.1MB/s]
#
# hf_model_0002_1.pt:   0%|          | 16.0M/5.00G [00:00<01:54, 43.5MB/s]
# hf_model_0001_1.pt:   4%|▎         | 176M/4.98G [00:06<02:32, 31.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:   4%|▍         | 192M/4.98G [00:07<02:16, 35.2MB/s]
#
#
# hf_model_0002_1.pt:   1%|          | 32.0M/5.00G [00:00<01:42, 48.3MB/s][A
#
# hf_model_0002_0.pt:   2%|▏         | 75.6M/5.00G [00:04<04:41, 17.5MB/s]
# hf_model_0001_1.pt:   4%|▍         | 192M/4.98G [00:06<02:15, 35.2MB/s]
#
# hf_model_0002_0.pt:   2%|▏         | 79.4M/5.00G [00:04<04:19, 18.9MB/s]
#
#
# hf_model_0001_2.pt:   4%|▎         | 176M/4.98G [00:05<02:18, 34.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:   4%|▍         | 208M/4.98G [00:08<02:14, 35.4MB/s]
#
# hf_model_0002_0.pt:   2%|▏         | 81.5M/5.00G [00:04<05:47, 14.2MB/s]
# hf_model_0001_1.pt:   4%|▍         | 208M/4.98G [00:06<02:10, 36.7MB/s]
#
#
# hf_model_0002_1.pt:   1%|          | 48.0M/5.00G [00:01<02:17, 36.0MB/s][A
#
#
#
#
# hf_model_0001_0.pt:   5%|▍         | 224M/4.98G [00:08<02:01, 39.0MB/s]
# hf_model_0001_1.pt:   5%|▍         | 224M/4.98G [00:07<01:59, 39.6MB/s]
#
#
# hf_model_0002_1.pt:   1%|▏         | 64.0M/5.00G [00:01<02:03, 40.1MB/s][A
#
# hf_model_0002_0.pt:   2%|▏         | 96.0M/5.00G [00:05<03:52, 21.1MB/s]
#
#
# hf_model_0001_2.pt:   5%|▍         | 224M/4.98G [00:06<01:48, 43.9MB/s]
# hf_model_0001_1.pt:   5%|▍         | 240M/4.98G [00:07<01:54, 41.3MB/s]
#
# hf_model_0002_0.pt:   2%|▏         | 112M/5.00G [00:05<02:51, 28.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:   5%|▍         | 240M/4.98G [00:09<02:43, 29.0MB/s]
#
#
# hf_model_0002_1.pt:   2%|▏         | 80.0M/5.00G [00:02<02:29, 32.9MB/s][A
# hf_model_0002_1.pt:   2%|▏         | 96.0M/5.00G [00:02<02:11, 37.4MB/s][A
#
#
# hf_model_0001_2.pt:   5%|▌         | 256M/4.98G [00:07<01:45, 44.7MB/s]
# hf_model_0001_1.pt:   5%|▌         | 272M/4.98G [00:08<01:45, 44.5MB/s]
#
# hf_model_0002_0.pt:   3%|▎         | 128M/5.00G [00:06<03:19, 24.5MB/s]
#
#
#
#
# hf_model_0002_1.pt:   2%|▏         | 112M/5.00G [00:02<01:59, 41.0MB/s] [A
# hf_model_0001_1.pt:   6%|▌         | 288M/4.98G [00:08<01:44, 44.7MB/s]
#
#
# hf_model_0001_2.pt:   5%|▌         | 272M/4.98G [00:07<01:47, 43.6MB/s]
#
# hf_model_0002_0.pt:   3%|▎         | 139M/5.00G [00:06<02:56, 27.5MB/s]
#
#
#
#
# hf_model_0002_1.pt:   3%|▎         | 128M/5.00G [00:03<01:50, 44.2MB/s]
# hf_model_0001_1.pt:   6%|▌         | 304M/4.98G [00:08<01:42, 45.5MB/s]
#
# hf_model_0002_0.pt:   3%|▎         | 142M/5.00G [00:06<03:08, 25.8MB/s]
#
#
# hf_model_0001_2.pt:   6%|▌         | 288M/4.98G [00:07<01:45, 44.3MB/s]
#
#
#
#
# hf_model_0002_1.pt:   3%|▎         | 144M/5.00G [00:03<01:47, 45.1MB/s]
# hf_model_0001_1.pt:   6%|▋         | 320M/4.98G [00:09<01:37, 47.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:   6%|▌         | 298M/4.98G [00:10<01:55, 40.6MB/s]
#
#
# hf_model_0002_1.pt:   3%|▎         | 160M/5.00G [00:03<01:46, 45.3MB/s]
# hf_model_0001_1.pt:   7%|▋         | 336M/4.98G [00:09<01:35, 48.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:   6%|▌         | 303M/4.98G [00:11<02:30, 31.0MB/s]
#
#
# hf_model_0001_2.pt:   6%|▋         | 320M/4.98G [00:08<01:51, 41.6MB/s]
#
# hf_model_0002_1.pt:   4%|▎         | 176M/5.00G [00:04<01:48, 44.3MB/s]
# hf_model_0001_1.pt:   7%|▋         | 352M/4.98G [00:09<01:35, 48.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:   6%|▌         | 307M/4.98G [00:11<03:20, 23.3MB/s]
#
# hf_model_0002_0.pt:   3%|▎         | 160M/5.00G [00:08<03:48, 21.2MB/s]
#
#
# hf_model_0001_2.pt:   7%|▋         | 336M/4.98G [00:09<01:49, 42.3MB/s]
# hf_model_0001_1.pt:   7%|▋         | 368M/4.98G [00:10<01:34, 48.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:   6%|▋         | 320M/4.98G [00:12<02:54, 26.7MB/s]
#
#
# hf_model_0001_2.pt:   7%|▋         | 352M/4.98G [00:09<01:45, 43.7MB/s]
# hf_model_0001_1.pt:   8%|▊         | 384M/4.98G [00:10<01:32, 49.6MB/s]
#
# hf_model_0002_1.pt:   4%|▍         | 192M/5.00G [00:04<02:13, 36.0MB/s]
#
# hf_model_0002_0.pt:   3%|▎         | 174M/5.00G [00:08<03:26, 23.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:   7%|▋         | 336M/4.98G [00:12<02:19, 33.3MB/s]
# hf_model_0002_1.pt:   4%|▍         | 208M/5.00G [00:05<02:07, 37.4MB/s]
#
#
# hf_model_0001_2.pt:   7%|▋         | 368M/4.98G [00:09<01:59, 38.7MB/s]
#
# hf_model_0002_0.pt:   4%|▎         | 177M/5.00G [00:09<04:53, 16.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:   7%|▋         | 352M/4.98G [00:12<02:13, 34.7MB/s]
# hf_model_0001_1.pt:   8%|▊         | 416M/4.98G [00:11<01:35, 47.9MB/s]
#
# hf_model_0002_1.pt:   4%|▍         | 224M/5.00G [00:05<01:59, 39.9MB/s]
#
#
# hf_model_0002_1.pt:   5%|▍         | 240M/5.00G [00:05<01:47, 44.3MB/s]
# hf_model_0001_1.pt:   9%|▊         | 432M/4.98G [00:11<01:32, 49.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:   7%|▋         | 368M/4.98G [00:13<01:58, 39.0MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 192M/5.00G [00:09<03:49, 20.9MB/s]
#
#
# hf_model_0001_2.pt:   8%|▊         | 400M/4.98G [00:10<01:53, 40.4MB/s]
# hf_model_0002_1.pt:   5%|▌         | 256M/5.00G [00:06<01:44, 45.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:   8%|▊         | 384M/4.98G [00:13<01:51, 41.3MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 195M/5.00G [00:10<04:56, 16.2MB/s]
#
#
# hf_model_0002_1.pt:   5%|▌         | 272M/5.00G [00:06<01:39, 47.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:   8%|▊         | 400M/4.98G [00:13<01:42, 44.7MB/s]
# hf_model_0001_1.pt:   9%|▉         | 464M/4.98G [00:12<01:32, 48.8MB/s]
#
#
# hf_model_0001_2.pt:   9%|▊         | 432M/4.98G [00:11<01:37, 46.5MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 203M/5.00G [00:10<04:38, 17.3MB/s]
# hf_model_0001_1.pt:  10%|▉         | 480M/4.98G [00:12<01:32, 48.7MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 206M/5.00G [00:10<04:25, 18.1MB/s]
# hf_model_0001_1.pt:  10%|▉         | 489M/4.98G [00:12<01:26, 52.0MB/s]
#
#
# hf_model_0001_2.pt:   9%|▉         | 448M/4.98G [00:11<01:37, 46.6MB/s]
#
#
#
#
# hf_model_0002_1.pt:   6%|▌         | 288M/5.00G [00:07<02:26, 32.3MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 208M/5.00G [00:11<06:30, 12.3MB/s]
#
#
# hf_model_0001_2.pt:   9%|▉         | 464M/4.98G [00:11<01:43, 43.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:   9%|▊         | 432M/4.98G [00:14<02:04, 36.4MB/s]
# hf_model_0001_1.pt:  10%|▉         | 494M/4.98G [00:13<02:44, 27.2MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 220M/5.00G [00:11<04:39, 17.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:   9%|▉         | 448M/4.98G [00:15<01:52, 40.3MB/s]
#
# hf_model_0002_0.pt:   4%|▍         | 223M/5.00G [00:11<04:21, 18.3MB/s]
#
#
# hf_model_0001_2.pt:  10%|▉         | 480M/4.98G [00:12<01:58, 38.1MB/s]
# hf_model_0001_1.pt:  10%|█         | 498M/4.98G [00:13<03:24, 21.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:   9%|▉         | 464M/4.98G [00:15<01:43, 43.7MB/s]
#
#
# hf_model_0001_2.pt:  10%|▉         | 496M/4.98G [00:12<01:50, 40.5MB/s]
#
# hf_model_0002_0.pt:   5%|▍         | 226M/5.00G [00:11<05:34, 14.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  10%|▉         | 480M/4.98G [00:15<01:37, 46.1MB/s]
# hf_model_0002_1.pt:   6%|▌         | 304M/5.00G [00:08<03:32, 22.1MB/s]
#
# hf_model_0002_0.pt:   5%|▍         | 235M/5.00G [00:12<04:40, 17.0MB/s]
#
#
# hf_model_0001_2.pt:  10%|█         | 512M/4.98G [00:13<01:58, 37.6MB/s]
# hf_model_0001_1.pt:  11%|█         | 528M/4.98G [00:14<02:20, 31.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  10%|▉         | 496M/4.98G [00:16<01:42, 43.6MB/s]
#
# hf_model_0002_1.pt:   6%|▋         | 320M/5.00G [00:08<02:59, 26.1MB/s]
#
#
# hf_model_0001_2.pt:  11%|█         | 528M/4.98G [00:13<01:49, 40.6MB/s]
# hf_model_0001_1.pt:  11%|█         | 544M/4.98G [00:14<02:01, 36.6MB/s]
#
#
#
#
# hf_model_0002_1.pt:   7%|▋         | 336M/5.00G [00:09<02:37, 29.6MB/s]
#
# hf_model_0002_0.pt:   5%|▍         | 242M/5.00G [00:12<05:48, 13.7MB/s]
#
#
# hf_model_0001_2.pt:  11%|█         | 544M/4.98G [00:13<01:43, 42.6MB/s]
# hf_model_0001_1.pt:  11%|█▏        | 560M/4.98G [00:15<01:55, 38.4MB/s]
#
#
#
#
# hf_model_0002_1.pt:   7%|▋         | 352M/5.00G [00:09<02:16, 34.0MB/s]
#
# hf_model_0002_0.pt:   5%|▌         | 256M/5.00G [00:13<03:46, 21.0MB/s]
#
#
# hf_model_0001_2.pt:  11%|█▏        | 560M/4.98G [00:14<01:43, 42.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  11%|█         | 544M/4.98G [00:17<01:37, 45.5MB/s]
# hf_model_0002_1.pt:   7%|▋         | 368M/5.00G [00:09<02:05, 36.9MB/s]
#
# hf_model_0002_0.pt:   5%|▌         | 268M/5.00G [00:13<03:27, 22.8MB/s]
#
#
# hf_model_0002_1.pt:   8%|▊         | 384M/5.00G [00:10<01:55, 39.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  11%|█▏        | 560M/4.98G [00:17<01:39, 44.3MB/s]
#
# hf_model_0002_0.pt:   5%|▌         | 271M/5.00G [00:13<03:23, 23.2MB/s]
# hf_model_0001_1.pt:  12%|█▏        | 592M/4.98G [00:16<02:05, 34.9MB/s]
#
#
# hf_model_0002_1.pt:   8%|▊         | 400M/5.00G [00:10<01:46, 43.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  12%|█▏        | 576M/4.98G [00:18<01:42, 42.8MB/s]
#
# hf_model_0002_0.pt:   5%|▌         | 274M/5.00G [00:14<04:51, 16.2MB/s]
# hf_model_0001_1.pt:  12%|█▏        | 608M/4.98G [00:16<01:51, 39.0MB/s]
#
#
# hf_model_0002_1.pt:   8%|▊         | 416M/5.00G [00:10<01:45, 43.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  12%|█▏        | 592M/4.98G [00:18<01:38, 44.7MB/s]
#
#
# hf_model_0001_2.pt:  13%|█▎        | 624M/4.98G [00:15<01:30, 48.4MB/s]
# hf_model_0001_1.pt:  13%|█▎        | 624M/4.98G [00:16<01:46, 40.8MB/s]
#
# hf_model_0002_1.pt:   9%|▊         | 432M/5.00G [00:11<01:40, 45.3MB/s]
#
# hf_model_0002_0.pt:   6%|▌         | 285M/5.00G [00:14<04:13, 18.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  12%|█▏        | 608M/4.98G [00:18<01:32, 47.2MB/s]
#
#
# hf_model_0001_2.pt:  13%|█▎        | 640M/4.98G [00:15<01:29, 48.5MB/s]
# hf_model_0002_1.pt:   9%|▉         | 448M/5.00G [00:11<01:51, 40.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 624M/4.98G [00:19<01:40, 43.1MB/s]
# hf_model_0001_1.pt:  13%|█▎        | 656M/4.98G [00:17<01:35, 45.4MB/s]
#
# hf_model_0002_0.pt:   6%|▌         | 288M/5.00G [00:15<06:11, 12.7MB/s]
#
#
# hf_model_0002_1.pt:   9%|▉         | 464M/5.00G [00:12<01:43, 43.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 640M/4.98G [00:19<01:34, 46.0MB/s]
#
# hf_model_0002_0.pt:   6%|▌         | 299M/5.00G [00:15<04:29, 17.5MB/s]
# hf_model_0001_1.pt:  14%|█▎        | 672M/4.98G [00:17<01:44, 41.3MB/s]
#
#
# hf_model_0001_2.pt:  14%|█▎        | 672M/4.98G [00:16<01:37, 44.2MB/s]
#
# hf_model_0002_0.pt:   6%|▌         | 301M/5.00G [00:15<04:27, 17.6MB/s]
#
#
# hf_model_0002_1.pt:  10%|▉         | 496M/5.00G [00:12<01:38, 45.6MB/s]
#
# hf_model_0002_0.pt:   6%|▌         | 304M/5.00G [00:16<06:11, 12.6MB/s]
# hf_model_0001_1.pt:  14%|█▍        | 688M/4.98G [00:18<01:59, 35.8MB/s]
#
#
# hf_model_0002_1.pt:  10%|█         | 512M/5.00G [00:13<01:35, 47.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 656M/4.98G [00:20<02:25, 29.6MB/s]
#
#
# hf_model_0001_2.pt:  14%|█▍        | 687M/4.98G [00:17<02:40, 26.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 660M/4.98G [00:20<02:25, 29.6MB/s]
#
# hf_model_0002_0.pt:   6%|▋         | 316M/5.00G [00:16<04:33, 17.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 664M/4.98G [00:20<02:21, 30.5MB/s]
# hf_model_0002_1.pt:  11%|█         | 528M/5.00G [00:13<01:35, 46.9MB/s]
#
# hf_model_0002_0.pt:   6%|▋         | 319M/5.00G [00:17<04:11, 18.6MB/s]
#
#
# hf_model_0002_1.pt:  11%|█         | 544M/5.00G [00:13<01:34, 47.1MB/s]
# hf_model_0001_1.pt:  14%|█▍        | 720M/4.98G [00:19<01:59, 35.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 668M/4.98G [00:21<03:30, 20.4MB/s]
#
#
# hf_model_0001_2.pt:  14%|█▍        | 704M/4.98G [00:18<02:50, 25.1MB/s]
#
# hf_model_0002_1.pt:  11%|█         | 560M/5.00G [00:14<01:39, 44.6MB/s]
#
#
# hf_model_0001_2.pt:  14%|█▍        | 720M/4.98G [00:18<02:10, 32.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  14%|█▎        | 672M/4.98G [00:21<04:22, 16.4MB/s]
#
# hf_model_0002_0.pt:   7%|▋         | 331M/5.00G [00:18<05:05, 15.3MB/s]
# hf_model_0001_1.pt:  15%|█▍        | 736M/4.98G [00:20<02:20, 30.2MB/s]
#
#
# hf_model_0001_2.pt:  15%|█▍        | 736M/4.98G [00:19<01:52, 37.7MB/s]
#
# hf_model_0002_1.pt:  12%|█▏        | 576M/5.00G [00:14<01:59, 37.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  14%|█▍        | 688M/4.98G [00:22<03:11, 22.4MB/s]
# hf_model_0001_1.pt:  15%|█▌        | 752M/4.98G [00:20<02:06, 33.4MB/s]
#
#
# hf_model_0001_2.pt:  15%|█▌        | 752M/4.98G [00:19<01:46, 39.6MB/s]
# hf_model_0002_1.pt:  12%|█▏        | 592M/5.00G [00:15<01:48, 40.6MB/s]
#
# hf_model_0002_0.pt:   7%|▋         | 336M/5.00G [00:18<06:46, 11.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:  14%|█▍        | 704M/4.98G [00:22<02:26, 29.1MB/s]
#
#
# hf_model_0002_1.pt:  12%|█▏        | 608M/5.00G [00:15<01:40, 43.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:  14%|█▍        | 720M/4.98G [00:22<02:08, 33.2MB/s]
#
# hf_model_0002_0.pt:   7%|▋         | 347M/5.00G [00:19<04:41, 16.5MB/s]
#
#
# hf_model_0001_2.pt:  16%|█▌        | 784M/4.98G [00:20<01:32, 45.6MB/s]
#
# hf_model_0002_1.pt:  12%|█▏        | 624M/5.00G [00:15<01:34, 46.5MB/s]
# hf_model_0001_1.pt:  15%|█▌        | 765M/4.98G [00:21<02:57, 23.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  15%|█▍        | 736M/4.98G [00:23<01:52, 37.6MB/s]
#
#
# hf_model_0002_1.pt:  13%|█▎        | 640M/5.00G [00:15<01:32, 47.1MB/s]
#
# hf_model_0002_0.pt:   7%|▋         | 352M/5.00G [00:19<06:15, 12.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  15%|█▌        | 752M/4.98G [00:23<01:42, 41.2MB/s]
# hf_model_0001_1.pt:  15%|█▌        | 769M/4.98G [00:21<03:45, 18.7MB/s]
#
#
# hf_model_0002_1.pt:  13%|█▎        | 656M/5.00G [00:16<01:31, 47.7MB/s]
#
# hf_model_0002_0.pt:   7%|▋         | 368M/5.00G [00:20<03:26, 22.4MB/s]
# hf_model_0002_1.pt:  13%|█▎        | 672M/5.00G [00:16<01:25, 50.4MB/s]
#
#
# hf_model_0001_2.pt:  17%|█▋        | 832M/4.98G [00:21<01:29, 46.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  15%|█▌        | 768M/4.98G [00:24<01:55, 36.6MB/s]
#
# hf_model_0002_1.pt:  14%|█▍        | 688M/5.00G [00:16<01:23, 51.7MB/s]
# hf_model_0001_1.pt:  16%|█▌        | 800M/4.98G [00:22<02:23, 29.2MB/s]
#
# hf_model_0002_0.pt:   8%|▊         | 382M/5.00G [00:20<03:10, 24.2MB/s]
#
#
# hf_model_0002_1.pt:  14%|█▍        | 704M/5.00G [00:17<01:23, 51.1MB/s]
# hf_model_0001_1.pt:  16%|█▋        | 816M/4.98G [00:22<02:03, 33.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  16%|█▌        | 784M/4.98G [00:24<02:08, 32.7MB/s]
#
#
# hf_model_0001_2.pt:  17%|█▋        | 864M/4.98G [00:21<01:27, 47.0MB/s]
#
# hf_model_0002_1.pt:  14%|█▍        | 720M/5.00G [00:17<01:26, 49.2MB/s]
# hf_model_0001_1.pt:  17%|█▋        | 832M/4.98G [00:23<01:52, 36.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  16%|█▌        | 800M/4.98G [00:24<01:54, 36.3MB/s]
#
# hf_model_0002_0.pt:   8%|▊         | 395M/5.00G [00:21<03:58, 19.3MB/s]
# hf_model_0001_1.pt:  17%|█▋        | 848M/4.98G [00:23<01:43, 40.0MB/s]
#
# hf_model_0002_1.pt:  15%|█▍        | 736M/5.00G [00:18<01:36, 44.1MB/s]
# hf_model_0001_1.pt:  17%|█▋        | 864M/4.98G [00:23<01:33, 43.8MB/s]
#
#
# hf_model_0002_1.pt:  15%|█▌        | 752M/5.00G [00:18<01:37, 43.6MB/s]
# hf_model_0001_1.pt:  18%|█▊        | 880M/4.98G [00:24<01:26, 47.6MB/s]
#
#
# hf_model_0002_1.pt:  15%|█▌        | 768M/5.00G [00:18<01:30, 46.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  16%|█▋        | 816M/4.98G [00:26<02:49, 24.6MB/s]
# hf_model_0002_1.pt:  16%|█▌        | 784M/5.00G [00:18<01:28, 47.8MB/s]
#
#
# hf_model_0001_2.pt:  18%|█▊        | 912M/4.98G [00:23<01:56, 35.0MB/s]
# hf_model_0001_1.pt:  18%|█▊        | 912M/4.98G [00:24<01:19, 51.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  17%|█▋        | 832M/4.98G [00:26<02:23, 28.9MB/s]
#
# hf_model_0002_0.pt:   8%|▊         | 400M/5.00G [00:22<09:12, 8.32MB/s]
#
#
# hf_model_0001_2.pt:  19%|█▊        | 928M/4.98G [00:23<01:44, 38.9MB/s]
#
# hf_model_0002_1.pt:  16%|█▌        | 795M/5.00G [00:19<01:42, 41.1MB/s]
# hf_model_0002_1.pt:  16%|█▌        | 799M/5.00G [00:19<01:52, 37.3MB/s]
#
#
# hf_model_0001_2.pt:  19%|█▉        | 944M/4.98G [00:24<01:41, 39.7MB/s]
# hf_model_0001_1.pt:  19%|█▉        | 944M/4.98G [00:25<01:21, 49.8MB/s]
#
# hf_model_0002_1.pt:  16%|█▌        | 803M/5.00G [00:19<02:37, 26.7MB/s]
# hf_model_0001_1.pt:  19%|█▉        | 960M/4.98G [00:25<01:21, 49.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  17%|█▋        | 848M/4.98G [00:27<03:00, 22.8MB/s]
#
#
# hf_model_0001_2.pt:  19%|█▉        | 960M/4.98G [00:24<01:44, 38.5MB/s]
#
# hf_model_0002_1.pt:  16%|█▋        | 816M/5.00G [00:20<02:19, 30.0MB/s]
# hf_model_0001_1.pt:  20%|█▉        | 976M/4.98G [00:26<01:20, 50.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  17%|█▋        | 864M/4.98G [00:27<02:42, 25.4MB/s]
#
# hf_model_0002_1.pt:  17%|█▋        | 832M/5.00G [00:20<01:54, 36.5MB/s]
# hf_model_0001_1.pt:  20%|█▉        | 992M/4.98G [00:26<01:18, 50.8MB/s]
#
# hf_model_0002_1.pt:  17%|█▋        | 848M/5.00G [00:20<01:36, 42.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  18%|█▊        | 880M/4.98G [00:28<02:34, 26.5MB/s]
# hf_model_0002_1.pt:  17%|█▋        | 864M/5.00G [00:21<01:41, 40.9MB/s]]
#
# hf_model_0002_0.pt:   9%|▊         | 432M/5.00G [00:24<06:46, 11.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  18%|█▊        | 896M/4.98G [00:28<02:13, 30.6MB/s]
# hf_model_0001_1.pt:  21%|██        | 1.02G/4.98G [00:27<01:33, 42.4MB/s]
#
# hf_model_0002_1.pt:  18%|█▊        | 880M/5.00G [00:21<01:34, 43.7MB/s]
# hf_model_0002_1.pt:  18%|█▊        | 896M/5.00G [00:21<01:31, 44.8MB/s]]
#
# hf_model_0002_0.pt:   9%|▉         | 464M/5.00G [00:25<02:43, 27.8MB/s]
#
# hf_model_0002_0.pt:   9%|▉         | 474M/5.00G [00:25<02:06, 35.7MB/s]
# hf_model_0001_1.pt:  21%|██        | 1.06G/4.98G [00:27<01:22, 47.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  18%|█▊        | 912M/4.98G [00:29<02:35, 26.1MB/s]
# hf_model_0001_1.pt:  22%|██▏       | 1.07G/4.98G [00:28<01:22, 47.3MB/s]
#
# hf_model_0002_1.pt:  18%|█▊        | 912M/5.00G [00:22<01:55, 35.4MB/s]
#
#
# hf_model_0001_2.pt:  20%|█▉        | 976M/4.98G [00:27<04:30, 14.8MB/s]
# hf_model_0002_1.pt:  19%|█▊        | 928M/5.00G [00:22<01:44, 38.8MB/s]]
#
# hf_model_0002_0.pt:  10%|▉         | 484M/5.00G [00:26<03:48, 19.8MB/s]
# hf_model_0002_1.pt:  19%|█▉        | 944M/5.00G [00:23<01:33, 43.5MB/s]]
#
# hf_model_0002_0.pt:  10%|▉         | 496M/5.00G [00:26<02:54, 25.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  19%|█▊        | 928M/4.98G [00:30<03:06, 21.7MB/s]
#
#
# hf_model_0001_2.pt:  20%|█▉        | 992M/4.98G [00:27<03:48, 17.4MB/s]
# hf_model_0001_1.pt:  23%|██▎       | 1.12G/4.98G [00:29<01:20, 47.9MB/s]
#
#
# hf_model_0001_2.pt:  20%|██        | 1.01G/4.98G [00:28<03:00, 22.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  19%|█▉        | 944M/4.98G [00:31<02:36, 25.7MB/s]
#
# hf_model_0002_1.pt:  19%|█▉        | 960M/5.00G [00:23<01:45, 38.2MB/s]
#
# hf_model_0002_0.pt:  10%|█         | 510M/5.00G [00:27<03:02, 24.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  19%|█▉        | 960M/4.98G [00:31<02:11, 30.4MB/s]
#
#
# hf_model_0001_2.pt:  21%|██        | 1.02G/4.98G [00:28<02:34, 25.6MB/s]
# hf_model_0002_1.pt:  20%|█▉        | 976M/5.00G [00:24<01:35, 42.1MB/s]]
#
#
#
#
# hf_model_0001_0.pt:  20%|█▉        | 976M/4.98G [00:31<01:55, 34.7MB/s]
#
# hf_model_0002_0.pt:  10%|█         | 513M/5.00G [00:27<03:59, 18.7MB/s]
#
#
# hf_model_0001_2.pt:  21%|██        | 1.04G/4.98G [00:28<02:10, 30.2MB/s]
# hf_model_0002_1.pt:  20%|█▉        | 992M/5.00G [00:24<01:27, 45.6MB/s]]
#
# hf_model_0002_0.pt:  11%|█         | 528M/5.00G [00:28<02:41, 27.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  20%|█▉        | 992M/4.98G [00:31<01:44, 38.2MB/s]
#
#
# hf_model_0002_1.pt:  20%|██        | 1.01G/5.00G [00:24<01:27, 45.8MB/s]
# hf_model_0001_1.pt:  23%|██▎       | 1.17G/4.98G [00:30<01:27, 43.3MB/s]
#
# hf_model_0002_0.pt:  11%|█         | 544M/5.00G [00:28<02:07, 35.0MB/s]
# hf_model_0001_1.pt:  24%|██▍       | 1.18G/4.98G [00:30<01:25, 44.5MB/s]
#
#
# hf_model_0002_1.pt:  20%|██        | 1.02G/5.00G [00:25<01:36, 41.4MB/s]
#
# hf_model_0002_0.pt:  11%|█         | 555M/5.00G [00:28<02:17, 32.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  20%|██        | 1.01G/4.98G [00:32<02:06, 31.5MB/s]
#
# hf_model_0002_0.pt:  11%|█         | 558M/5.00G [00:29<02:31, 29.3MB/s]
# hf_model_0001_1.pt:  24%|██▍       | 1.20G/4.98G [00:31<01:29, 42.0MB/s]
#
#
# hf_model_0001_2.pt:  22%|██▏       | 1.09G/4.98G [00:30<01:49, 35.5MB/s]
#
#
#
#
# hf_model_0002_1.pt:  21%|██        | 1.04G/5.00G [00:25<01:46, 37.0MB/s]
# hf_model_0001_1.pt:  24%|██▍       | 1.22G/4.98G [00:31<01:22, 45.8MB/s]
#
#
# hf_model_0001_2.pt:  22%|██▏       | 1.10G/4.98G [00:30<01:41, 38.3MB/s]
#
# hf_model_0002_0.pt:  11%|█         | 561M/5.00G [00:29<03:30, 21.1MB/s]
#
#
#
#
# hf_model_0002_1.pt:  21%|██        | 1.06G/5.00G [00:26<01:38, 39.9MB/s]
# hf_model_0001_1.pt:  25%|██▍       | 1.23G/4.98G [00:31<01:26, 43.1MB/s]
#
#
# hf_model_0001_2.pt:  23%|██▎       | 1.12G/4.98G [00:30<01:34, 40.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  21%|██        | 1.06G/4.98G [00:33<01:33, 41.8MB/s]
#
# hf_model_0002_1.pt:  21%|██▏       | 1.07G/5.00G [00:26<01:38, 40.1MB/s][A
#
# hf_model_0002_0.pt:  12%|█▏        | 575M/5.00G [00:30<03:15, 22.6MB/s]
#
#
# hf_model_0001_2.pt:  23%|██▎       | 1.14G/4.98G [00:31<01:31, 42.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  22%|██▏       | 1.07G/4.98G [00:33<01:29, 43.6MB/s]
# hf_model_0002_1.pt:  22%|██▏       | 1.09G/5.00G [00:26<01:39, 39.4MB/s]
#
#
# hf_model_0001_2.pt:  23%|██▎       | 1.15G/4.98G [00:31<01:26, 44.3MB/s]
#
# hf_model_0002_0.pt:  12%|█▏        | 578M/5.00G [00:30<04:29, 16.4MB/s]
# hf_model_0001_1.pt:  25%|██▌       | 1.26G/4.98G [00:32<01:25, 43.4MB/s]
#
#
#
#
# hf_model_0002_1.pt:  22%|██▏       | 1.10G/5.00G [00:27<01:31, 42.6MB/s]
#
#
# hf_model_0001_2.pt:  23%|██▎       | 1.17G/4.98G [00:31<01:22, 46.3MB/s]
#
# hf_model_0002_0.pt:  12%|█▏        | 592M/5.00G [00:30<03:03, 24.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  22%|██▏       | 1.10G/4.98G [00:34<01:25, 45.4MB/s]
# hf_model_0001_1.pt:  26%|██▌       | 1.28G/4.98G [00:32<01:23, 44.4MB/s]
#
# hf_model_0002_0.pt:  12%|█▏        | 608M/5.00G [00:31<02:16, 32.3MB/s]
# hf_model_0002_1.pt:  22%|██▏       | 1.12G/5.00G [00:27<01:34, 40.9MB/s]
#
#
# hf_model_0001_2.pt:  24%|██▍       | 1.18G/4.98G [00:32<01:30, 41.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.12G/4.98G [00:35<01:30, 42.6MB/s]
#
# hf_model_0002_1.pt:  23%|██▎       | 1.14G/5.00G [00:27<01:27, 44.2MB/s][A
# hf_model_0001_1.pt:  26%|██▋       | 1.31G/4.98G [00:33<01:18, 46.7MB/s]
#
#
# hf_model_0001_2.pt:  24%|██▍       | 1.20G/4.98G [00:32<01:23, 45.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.14G/4.98G [00:35<01:26, 44.6MB/s]
# hf_model_0002_1.pt:  23%|██▎       | 1.15G/5.00G [00:28<01:24, 45.5MB/s]
#
#
# hf_model_0001_2.pt:  24%|██▍       | 1.22G/4.98G [00:32<01:22, 45.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.15G/4.98G [00:35<01:21, 46.7MB/s]
#
# hf_model_0002_0.pt:  13%|█▎        | 640M/5.00G [00:32<02:18, 31.5MB/s]
# hf_model_0002_1.pt:  23%|██▎       | 1.17G/5.00G [00:28<01:25, 44.9MB/s]
#
#
# hf_model_0001_2.pt:  25%|██▍       | 1.23G/4.98G [00:33<01:19, 47.0MB/s]
# hf_model_0001_1.pt:  27%|██▋       | 1.35G/4.98G [00:34<01:08, 52.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.17G/4.98G [00:36<01:20, 47.1MB/s]
#
# hf_model_0002_1.pt:  24%|██▎       | 1.18G/5.00G [00:28<01:19, 47.9MB/s][A
#
#
# hf_model_0001_2.pt:  25%|██▌       | 1.25G/4.98G [00:33<01:20, 46.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.18G/4.98G [00:36<01:16, 49.3MB/s]
# hf_model_0001_1.pt:  27%|██▋       | 1.36G/4.98G [00:34<01:35, 38.0MB/s]
#
# hf_model_0002_1.pt:  24%|██▍       | 1.20G/5.00G [00:29<01:19, 47.8MB/s][A
#
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.20G/4.98G [00:36<01:14, 50.4MB/s]
#
#
# hf_model_0001_2.pt:  25%|██▌       | 1.26G/4.98G [00:33<01:19, 46.6MB/s]
#
# hf_model_0002_0.pt:  14%|█▍        | 688M/5.00G [00:33<01:39, 43.5MB/s]
# hf_model_0002_1.pt:  24%|██▍       | 1.22G/5.00G [00:29<01:19, 47.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.22G/4.98G [00:36<01:15, 49.9MB/s]
#
#
# hf_model_0001_2.pt:  26%|██▌       | 1.28G/4.98G [00:34<01:30, 40.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  25%|██▍       | 1.23G/4.98G [00:37<01:14, 50.6MB/s]
# hf_model_0001_1.pt:  28%|██▊       | 1.38G/4.98G [00:35<02:16, 26.3MB/s]
#
#
# hf_model_0001_2.pt:  26%|██▌       | 1.30G/4.98G [00:34<01:25, 42.8MB/s]
#
# hf_model_0002_0.pt:  14%|█▍        | 704M/5.00G [00:33<02:12, 32.3MB/s]
# hf_model_0001_1.pt:  28%|██▊       | 1.39G/4.98G [00:36<01:51, 32.3MB/s]
#
#
# hf_model_0002_1.pt:  25%|██▍       | 1.23G/5.00G [00:30<02:02, 30.6MB/s]
#
# hf_model_0002_0.pt:  14%|█▍        | 715M/5.00G [00:34<02:17, 31.1MB/s]
# hf_model_0001_1.pt:  28%|██▊       | 1.41G/4.98G [00:36<01:34, 37.6MB/s]
#
#
#
#
# hf_model_0002_1.pt:  25%|██▍       | 1.25G/5.00G [00:30<01:45, 35.4MB/s]
#
# hf_model_0002_0.pt:  14%|█▍        | 719M/5.00G [00:34<02:26, 29.3MB/s]
#
#
# hf_model_0001_2.pt:  27%|██▋       | 1.33G/4.98G [00:35<01:30, 40.3MB/s]
# hf_model_0001_1.pt:  29%|██▊       | 1.42G/4.98G [00:36<01:24, 42.0MB/s]
#
#
#
#
# hf_model_0002_1.pt:  25%|██▌       | 1.26G/5.00G [00:31<01:39, 37.7MB/s]
# hf_model_0001_1.pt:  29%|██▉       | 1.44G/4.98G [00:36<01:19, 44.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  26%|██▌       | 1.28G/4.98G [00:38<01:32, 40.1MB/s]
#
#
# hf_model_0002_1.pt:  26%|██▌       | 1.28G/5.00G [00:31<01:31, 40.5MB/s]
# hf_model_0001_1.pt:  29%|██▉       | 1.46G/4.98G [00:37<01:17, 45.4MB/s]
#
# hf_model_0002_0.pt:  14%|█▍        | 722M/5.00G [00:35<04:23, 16.3MB/s]
#
#
#
#
# hf_model_0002_1.pt:  26%|██▌       | 1.30G/5.00G [00:31<01:24, 44.1MB/s]
#
#
# hf_model_0001_2.pt:  27%|██▋       | 1.36G/4.98G [00:36<01:35, 37.7MB/s]
# hf_model_0001_1.pt:  30%|██▉       | 1.47G/4.98G [00:37<01:18, 44.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  26%|██▋       | 1.31G/4.98G [00:39<01:22, 44.4MB/s]
#
# hf_model_0002_1.pt:  26%|██▌       | 1.31G/5.00G [00:32<01:23, 44.0MB/s][A
#
#
# hf_model_0001_2.pt:  28%|██▊       | 1.38G/4.98G [00:36<01:38, 36.6MB/s]
# hf_model_0001_1.pt:  30%|██▉       | 1.49G/4.98G [00:38<01:19, 43.7MB/s]
#
#
#
#
# hf_model_0002_1.pt:  27%|██▋       | 1.33G/5.00G [00:32<01:20, 45.4MB/s]
#
# hf_model_0002_0.pt:  15%|█▍        | 747M/5.00G [00:36<03:06, 22.8MB/s]
#
# hf_model_0002_0.pt:  15%|█▍        | 750M/5.00G [00:36<03:04, 23.0MB/s]
# hf_model_0002_1.pt:  27%|██▋       | 1.34G/5.00G [00:32<01:14, 49.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  27%|██▋       | 1.34G/4.98G [00:40<01:24, 43.0MB/s]
#
#
# hf_model_0002_1.pt:  27%|██▋       | 1.36G/5.00G [00:33<01:17, 46.9MB/s]
#
# hf_model_0002_0.pt:  15%|█▌        | 752M/5.00G [00:36<04:24, 16.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  27%|██▋       | 1.36G/4.98G [00:40<01:21, 44.6MB/s]
#
#
# hf_model_0001_2.pt:  28%|██▊       | 1.41G/4.98G [00:37<01:38, 36.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.38G/4.98G [00:40<01:16, 47.1MB/s]
#
# hf_model_0002_0.pt:  15%|█▌        | 763M/5.00G [00:37<03:39, 19.3MB/s]
#
#
# hf_model_0001_2.pt:  29%|██▊       | 1.42G/4.98G [00:38<01:28, 40.0MB/s]
#
# hf_model_0002_0.pt:  15%|█▌        | 766M/5.00G [00:37<03:44, 18.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.39G/4.98G [00:41<01:13, 48.8MB/s]
#
#
# hf_model_0002_1.pt:  28%|██▊       | 1.38G/5.00G [00:33<01:51, 32.4MB/s]
#
# hf_model_0002_0.pt:  15%|█▌        | 768M/5.00G [00:37<04:57, 14.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.41G/4.98G [00:41<01:19, 45.1MB/s]
#
#
# hf_model_0002_1.pt:  28%|██▊       | 1.39G/5.00G [00:34<01:40, 35.8MB/s]
#
# hf_model_0002_0.pt:  16%|█▌        | 784M/5.00G [00:37<02:47, 25.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  29%|██▊       | 1.42G/4.98G [00:41<01:16, 46.5MB/s]
#
#
# hf_model_0002_1.pt:  28%|██▊       | 1.41G/5.00G [00:34<01:30, 39.8MB/s]
#
# hf_model_0002_0.pt:  16%|█▌        | 800M/5.00G [00:38<02:10, 32.2MB/s]
#
#
# hf_model_0001_2.pt:  30%|██▉       | 1.49G/4.98G [00:39<01:09, 50.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  29%|██▉       | 1.44G/4.98G [00:42<01:17, 45.6MB/s]
# hf_model_0001_1.pt:  31%|███       | 1.52G/4.98G [00:40<03:14, 17.7MB/s]
# hf_model_0001_1.pt:  31%|███       | 1.53G/4.98G [00:40<02:53, 19.8MB/s]
#
# hf_model_0002_0.pt:  16%|█▋        | 816M/5.00G [00:38<01:51, 37.4MB/s]
#
#
# hf_model_0001_2.pt:  30%|███       | 1.50G/4.98G [00:39<01:11, 48.9MB/s]
# hf_model_0002_1.pt:  28%|██▊       | 1.42G/5.00G [00:35<01:51, 32.1MB/s]
#
#
# hf_model_0001_2.pt:  31%|███       | 1.52G/4.98G [00:39<01:10, 49.1MB/s]
# hf_model_0001_1.pt:  31%|███       | 1.54G/4.98G [00:41<02:54, 19.8MB/s]
#
# hf_model_0002_1.pt:  29%|██▉       | 1.44G/5.00G [00:35<01:39, 35.7MB/s][A
#
#
# hf_model_0001_2.pt:  31%|███       | 1.54G/4.98G [00:40<01:11, 47.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  29%|██▉       | 1.46G/4.98G [00:43<02:00, 29.3MB/s]
# hf_model_0002_1.pt:  29%|██▉       | 1.46G/5.00G [00:35<01:26, 40.8MB/s]
#
# hf_model_0002_0.pt:  17%|█▋        | 832M/5.00G [00:39<02:50, 24.5MB/s]
#
#
# hf_model_0001_2.pt:  31%|███       | 1.55G/4.98G [00:40<01:09, 49.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  30%|██▉       | 1.47G/4.98G [00:43<01:47, 32.6MB/s]
#
# hf_model_0002_1.pt:  29%|██▉       | 1.47G/5.00G [00:36<01:21, 43.4MB/s][A
# hf_model_0001_1.pt:  31%|███       | 1.55G/4.98G [00:41<02:44, 20.8MB/s]
#
#
# hf_model_0002_1.pt:  30%|██▉       | 1.49G/5.00G [00:36<01:16, 45.8MB/s]
# hf_model_0001_1.pt:  32%|███▏      | 1.57G/4.98G [00:42<02:00, 28.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  30%|██▉       | 1.49G/4.98G [00:44<01:49, 32.0MB/s]
#
#
# hf_model_0001_2.pt:  32%|███▏      | 1.58G/4.98G [00:41<01:07, 49.9MB/s]
# hf_model_0002_1.pt:  30%|███       | 1.50G/5.00G [00:36<01:14, 46.8MB/s]
#
#
# hf_model_0001_2.pt:  32%|███▏      | 1.60G/4.98G [00:41<01:07, 50.4MB/s]
#
#
#
#
# hf_model_0002_1.pt:  30%|███       | 1.52G/5.00G [00:37<01:13, 47.5MB/s]
# hf_model_0001_1.pt:  32%|███▏      | 1.60G/4.98G [00:42<01:33, 36.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.52G/4.98G [00:44<01:25, 40.5MB/s]
#
#
# hf_model_0001_2.pt:  32%|███▏      | 1.62G/4.98G [00:41<01:06, 50.7MB/s]
# hf_model_0001_1.pt:  32%|███▏      | 1.62G/4.98G [00:43<01:22, 40.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.54G/4.98G [00:44<01:20, 42.8MB/s]
#
#
# hf_model_0001_2.pt:  33%|███▎      | 1.63G/4.98G [00:42<01:08, 49.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.55G/4.98G [00:45<01:20, 42.6MB/s]
#
#
# hf_model_0001_2.pt:  33%|███▎      | 1.65G/4.98G [00:42<01:10, 47.2MB/s]
# hf_model_0001_1.pt:  33%|███▎      | 1.63G/4.98G [00:43<01:29, 37.4MB/s]
#
# hf_model_0002_1.pt:  31%|███       | 1.54G/5.00G [00:38<01:50, 31.2MB/s][A
# hf_model_0001_1.pt:  33%|███▎      | 1.65G/4.98G [00:44<01:20, 41.5MB/s]
#
# hf_model_0002_0.pt:  18%|█▊        | 880M/5.00G [00:41<03:16, 21.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.57G/4.98G [00:45<01:27, 39.1MB/s]
# hf_model_0001_1.pt:  33%|███▎      | 1.66G/4.98G [00:44<01:14, 44.4MB/s]
#
#
# hf_model_0001_2.pt:  33%|███▎      | 1.66G/4.98G [00:43<01:27, 37.7MB/s]
#
# hf_model_0002_0.pt:  18%|█▊        | 896M/5.00G [00:42<02:39, 25.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.58G/4.98G [00:46<01:17, 43.7MB/s]
#
#
# hf_model_0002_1.pt:  31%|███       | 1.55G/5.00G [00:38<02:17, 25.2MB/s]
#
# hf_model_0002_0.pt:  18%|█▊        | 912M/5.00G [00:42<02:15, 30.1MB/s]
# hf_model_0001_1.pt:  34%|███▍      | 1.68G/4.98G [00:44<01:18, 42.2MB/s]
#
#
#
#
# hf_model_0002_1.pt:  31%|███       | 1.56G/5.00G [00:39<01:57, 29.2MB/s]
#
# hf_model_0002_0.pt:  19%|█▊        | 928M/5.00G [00:42<01:55, 35.2MB/s]
# hf_model_0001_1.pt:  34%|███▍      | 1.70G/4.98G [00:45<01:12, 45.1MB/s]
#
#
#
#
# hf_model_0002_1.pt:  31%|███▏      | 1.57G/5.00G [00:39<02:22, 24.0MB/s]
# hf_model_0001_1.pt:  34%|███▍      | 1.71G/4.98G [00:45<01:11, 45.5MB/s]
#
# hf_model_0002_0.pt:  19%|█▉        | 939M/5.00G [00:43<02:03, 32.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  33%|███▎      | 1.63G/4.98G [00:47<01:14, 44.8MB/s]
#
#
# hf_model_0001_2.pt:  34%|███▍      | 1.70G/4.98G [00:44<01:51, 29.3MB/s]
#
# hf_model_0002_1.pt:  31%|███▏      | 1.57G/5.00G [00:39<02:56, 19.4MB/s][A
# hf_model_0001_1.pt:  35%|███▍      | 1.73G/4.98G [00:45<01:10, 46.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  33%|███▎      | 1.65G/4.98G [00:47<01:14, 44.6MB/s]
#
#
# hf_model_0002_1.pt:  32%|███▏      | 1.58G/5.00G [00:40<02:15, 25.1MB/s]
#
# hf_model_0002_0.pt:  19%|█▉        | 946M/5.00G [00:43<02:55, 23.1MB/s]
# hf_model_0001_1.pt:  35%|███▌      | 1.74G/4.98G [00:46<01:08, 47.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  33%|███▎      | 1.66G/4.98G [00:47<01:10, 47.1MB/s]
#
#
# hf_model_0002_1.pt:  32%|███▏      | 1.60G/5.00G [00:40<01:48, 31.5MB/s]
#
# hf_model_0002_0.pt:  19%|█▉        | 960M/5.00G [00:44<02:26, 27.5MB/s]
# hf_model_0001_1.pt:  35%|███▌      | 1.76G/4.98G [00:46<01:09, 46.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.68G/4.98G [00:48<01:09, 47.2MB/s]
#
#
# hf_model_0001_2.pt:  35%|███▌      | 1.74G/4.98G [00:45<01:19, 40.6MB/s]
#
# hf_model_0002_0.pt:  20%|█▉        | 976M/5.00G [00:44<02:01, 33.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.70G/4.98G [00:48<01:09, 47.1MB/s]
#
#
# hf_model_0001_2.pt:  35%|███▌      | 1.76G/4.98G [00:45<01:24, 38.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.71G/4.98G [00:48<01:07, 48.3MB/s]
# hf_model_0001_1.pt:  36%|███▌      | 1.78G/4.98G [00:47<01:44, 30.7MB/s]
#
#
# hf_model_0002_1.pt:  32%|███▏      | 1.62G/5.00G [00:41<02:28, 22.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  35%|███▍      | 1.73G/4.98G [00:49<01:07, 47.8MB/s]
# hf_model_0002_1.pt:  33%|███▎      | 1.63G/5.00G [00:41<01:59, 28.3MB/s]
#
#
# hf_model_0001_2.pt:  36%|███▌      | 1.79G/4.98G [00:46<01:15, 42.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  35%|███▌      | 1.74G/4.98G [00:49<01:09, 46.7MB/s]
#
# hf_model_0002_1.pt:  33%|███▎      | 1.65G/5.00G [00:42<01:43, 32.3MB/s][A
#
#
#
#
# hf_model_0001_0.pt:  35%|███▌      | 1.76G/4.98G [00:49<01:08, 46.7MB/s]
# hf_model_0002_1.pt:  33%|███▎      | 1.66G/5.00G [00:42<01:34, 35.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  36%|███▌      | 1.78G/4.98G [00:50<01:08, 46.8MB/s]
#
# hf_model_0002_0.pt:  20%|██        | 1.01G/5.00G [00:46<02:54, 22.9MB/s]
# hf_model_0001_1.pt:  37%|███▋      | 1.82G/4.98G [00:48<01:32, 33.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  36%|███▌      | 1.79G/4.98G [00:50<01:08, 46.6MB/s]
#
# hf_model_0002_0.pt:  20%|██        | 1.02G/5.00G [00:46<02:25, 27.3MB/s]
# hf_model_0002_1.pt:  34%|███▎      | 1.68G/5.00G [00:43<01:48, 30.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  36%|███▋      | 1.81G/4.98G [00:50<01:11, 44.2MB/s]
# hf_model_0002_1.pt:  34%|███▍      | 1.70G/5.00G [00:43<01:34, 35.0MB/s]
#
# hf_model_0002_0.pt:  21%|██        | 1.04G/5.00G [00:47<02:25, 27.2MB/s]
# hf_model_0002_1.pt:  34%|███▍      | 1.71G/5.00G [00:43<01:21, 40.2MB/s]
#
# hf_model_0002_0.pt:  21%|██        | 1.06G/5.00G [00:47<02:01, 32.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  37%|███▋      | 1.82G/4.98G [00:51<01:26, 36.6MB/s]
# hf_model_0002_1.pt:  35%|███▍      | 1.73G/5.00G [00:44<01:25, 38.1MB/s]
#
# hf_model_0002_0.pt:  21%|██▏       | 1.07G/5.00G [00:48<01:49, 35.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  37%|███▋      | 1.84G/4.98G [00:51<01:17, 40.5MB/s]
# hf_model_0001_1.pt:  38%|███▊      | 1.90G/4.98G [00:50<01:07, 45.8MB/s]
#
#
# hf_model_0002_1.pt:  35%|███▍      | 1.74G/5.00G [00:44<01:19, 41.1MB/s]
#
# hf_model_0002_0.pt:  22%|██▏       | 1.09G/5.00G [00:48<01:38, 39.9MB/s]
#
#
# hf_model_0001_2.pt:  36%|███▋      | 1.81G/4.98G [00:49<03:08, 16.8MB/s]
# hf_model_0001_1.pt:  39%|███▊      | 1.92G/4.98G [00:50<01:03, 48.0MB/s]
#
#
#
#
# hf_model_0002_1.pt:  35%|███▌      | 1.76G/5.00G [00:45<01:14, 43.8MB/s]
#
#
# hf_model_0001_2.pt:  37%|███▋      | 1.82G/4.98G [00:49<03:09, 16.7MB/s]
#
#
# hf_model_0001_2.pt:  37%|███▋      | 1.82G/4.98G [00:49<03:02, 17.3MB/s]
# hf_model_0001_1.pt:  39%|███▉      | 1.94G/4.98G [00:50<01:03, 47.9MB/s]
#
#
#
#
# hf_model_0002_1.pt:  36%|███▌      | 1.78G/5.00G [00:45<01:14, 43.4MB/s]
#
# hf_model_0002_0.pt:  22%|██▏       | 1.10G/5.00G [00:49<02:05, 31.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  38%|███▊      | 1.89G/4.98G [00:52<01:09, 44.3MB/s]
# hf_model_0001_1.pt:  39%|███▉      | 1.95G/4.98G [00:51<01:04, 46.7MB/s]
#
#
# hf_model_0001_2.pt:  37%|███▋      | 1.83G/4.98G [00:50<03:40, 14.3MB/s]
#
# hf_model_0002_0.pt:  22%|██▏       | 1.12G/5.00G [00:49<01:48, 35.8MB/s]
# hf_model_0001_1.pt:  40%|███▉      | 1.97G/4.98G [00:51<01:04, 46.8MB/s]
#
#
# hf_model_0002_1.pt:  36%|███▌      | 1.79G/5.00G [00:46<01:31, 35.0MB/s]
#
#
#
#
# hf_model_0001_0.pt:  38%|███▊      | 1.90G/4.98G [00:53<01:18, 39.3MB/s]
#
# hf_model_0002_0.pt:  23%|██▎       | 1.14G/5.00G [00:49<01:38, 39.2MB/s]
#
#
#
#
# hf_model_0001_0.pt:  39%|███▊      | 1.92G/4.98G [00:53<01:09, 44.1MB/s]
#
# hf_model_0002_0.pt:  23%|██▎       | 1.15G/5.00G [00:50<01:33, 41.1MB/s]
#
#
# hf_model_0001_2.pt:  37%|███▋      | 1.86G/4.98G [00:51<02:07, 24.5MB/s]
# hf_model_0001_1.pt:  40%|███▉      | 1.98G/4.98G [00:52<01:24, 35.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  39%|███▉      | 1.94G/4.98G [00:54<01:04, 46.9MB/s]
#
# hf_model_0002_0.pt:  23%|██▎       | 1.17G/5.00G [00:50<01:30, 42.6MB/s]
#
#
# hf_model_0001_2.pt:  38%|███▊      | 1.87G/4.98G [00:51<01:42, 30.3MB/s]
#
#
#
#
# hf_model_0001_0.pt:  39%|███▉      | 1.95G/4.98G [00:54<01:02, 48.1MB/s]
# hf_model_0001_1.pt:  40%|████      | 2.00G/4.98G [00:52<01:17, 38.6MB/s]
#
#
# hf_model_0001_2.pt:  38%|███▊      | 1.89G/4.98G [00:51<01:26, 35.8MB/s]
#
# hf_model_0002_0.pt:  24%|██▎       | 1.18G/5.00G [00:50<01:25, 44.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  40%|███▉      | 1.97G/4.98G [00:54<01:01, 49.2MB/s]
# hf_model_0001_1.pt:  41%|████      | 2.02G/4.98G [00:53<01:13, 40.1MB/s]
#
# hf_model_0002_1.pt:  36%|███▌      | 1.81G/5.00G [00:47<02:25, 21.9MB/s]
#
#
#
#
# hf_model_0002_1.pt:  36%|███▋      | 1.82G/5.00G [00:47<01:59, 26.5MB/s]
# hf_model_0001_1.pt:  41%|████      | 2.03G/4.98G [00:53<01:14, 39.7MB/s]
#
#
# hf_model_0001_2.pt:  38%|███▊      | 1.90G/4.98G [00:52<01:39, 31.0MB/s]
#
# hf_model_0002_0.pt:  24%|██▍       | 1.22G/5.00G [00:51<01:26, 43.6MB/s]
#
#
#
#
# hf_model_0002_1.pt:  37%|███▋      | 1.84G/5.00G [00:48<01:42, 30.9MB/s]
#
#
# hf_model_0001_2.pt:  39%|███▊      | 1.92G/4.98G [00:52<01:26, 35.4MB/s]
# hf_model_0001_1.pt:  41%|████      | 2.05G/4.98G [00:53<01:15, 38.9MB/s]
#
#
#
#
# hf_model_0002_1.pt:  37%|███▋      | 1.86G/5.00G [00:48<01:30, 34.7MB/s]
#
#
# hf_model_0001_2.pt:  39%|███▉      | 1.94G/4.98G [00:52<01:18, 38.7MB/s]
# hf_model_0001_1.pt:  41%|████▏     | 2.06G/4.98G [00:54<01:10, 41.2MB/s]
#
# hf_model_0002_0.pt:  25%|██▍       | 1.23G/5.00G [00:52<02:06, 29.8MB/s]
#
#
# hf_model_0002_1.pt:  37%|███▋      | 1.87G/5.00G [00:48<01:27, 35.6MB/s]
# hf_model_0001_1.pt:  42%|████▏     | 2.08G/4.98G [00:54<01:10, 41.1MB/s]
#
#
#
#
# hf_model_0002_1.pt:  38%|███▊      | 1.89G/5.00G [00:49<01:18, 39.5MB/s]
#
#
# hf_model_0001_2.pt:  40%|███▉      | 1.97G/4.98G [00:53<01:10, 42.9MB/s]
# hf_model_0001_1.pt:  42%|████▏     | 2.10G/4.98G [00:54<01:06, 43.0MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.90G/5.00G [00:49<01:14, 41.8MB/s]
# hf_model_0001_1.pt:  42%|████▏     | 2.11G/4.98G [00:55<01:01, 46.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  41%|████      | 2.05G/4.98G [00:56<01:30, 32.3MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.92G/5.00G [00:49<01:11, 43.4MB/s]
# hf_model_0001_1.pt:  43%|████▎     | 2.13G/4.98G [00:55<01:00, 46.8MB/s]
#
#
# hf_model_0001_2.pt:  40%|███▉      | 1.98G/4.98G [00:54<01:34, 31.8MB/s]
#
#
#
#
# hf_model_0001_0.pt:  41%|████▏     | 2.06G/4.98G [00:57<01:20, 36.0MB/s]
#
# hf_model_0002_1.pt:  39%|███▊      | 1.94G/5.00G [00:50<01:09, 43.8MB/s]
# hf_model_0001_1.pt:  43%|████▎     | 2.14G/4.98G [00:55<01:00, 46.9MB/s]
#
#
#
#
# hf_model_0001_0.pt:  42%|████▏     | 2.08G/4.98G [00:57<01:13, 39.5MB/s]
#
#
# hf_model_0001_2.pt:  40%|████      | 2.00G/4.98G [00:54<01:24, 35.3MB/s]
#
# hf_model_0002_0.pt:  26%|██▌       | 1.30G/5.00G [00:53<01:29, 41.4MB/s]
# hf_model_0001_1.pt:  43%|████▎     | 2.16G/4.98G [00:56<00:57, 49.1MB/s]
#
#
# hf_model_0001_2.pt:  41%|████      | 2.02G/4.98G [00:55<01:17, 38.3MB/s]
#
# hf_model_0002_0.pt:  26%|██▌       | 1.31G/5.00G [00:54<01:26, 42.9MB/s]
#
#
#
#
# hf_model_0002_1.pt:  39%|███▉      | 1.96G/5.00G [00:50<01:15, 40.5MB/s]
# hf_model_0001_1.pt:  44%|████▎     | 2.18G/4.98G [00:56<00:59, 47.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  42%|████▏     | 2.11G/4.98G [00:58<01:06, 43.2MB/s]
#
# hf_model_0002_0.pt:  27%|██▋       | 1.33G/5.00G [00:54<01:21, 44.8MB/s]
# hf_model_0001_1.pt:  44%|████▍     | 2.19G/4.98G [00:56<00:58, 47.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  43%|████▎     | 2.13G/4.98G [00:58<01:03, 44.5MB/s]
#
# hf_model_0002_0.pt:  27%|██▋       | 1.34G/5.00G [00:55<01:24, 43.0MB/s]
#
#
# hf_model_0001_2.pt:  41%|████      | 2.03G/4.98G [00:55<01:40, 29.3MB/s]
# hf_model_0002_1.pt:  39%|███▉      | 1.96G/5.00G [00:51<02:03, 24.7MB/s]
#
# hf_model_0002_0.pt:  27%|██▋       | 1.36G/5.00G [00:55<01:24, 42.9MB/s]
#
#
# hf_model_0002_1.pt:  39%|███▉      | 1.97G/5.00G [00:51<02:38, 19.1MB/s]
#
#
#
#
# hf_model_0001_0.pt:  43%|████▎     | 2.14G/4.98G [00:59<01:23, 33.9MB/s]
# hf_model_0001_1.pt:  45%|████▍     | 2.22G/4.98G [00:57<01:07, 40.8MB/s]
#
# hf_model_0002_1.pt:  40%|███▉      | 1.98G/5.00G [00:52<01:54, 26.4MB/s]
# hf_model_0001_1.pt:  45%|████▌     | 2.24G/4.98G [00:58<01:01, 44.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  43%|████▎     | 2.16G/4.98G [00:59<01:14, 37.6MB/s]
#
# hf_model_0002_0.pt:  28%|██▊       | 1.39G/5.00G [00:55<01:14, 48.4MB/s]
#
#
# hf_model_0002_1.pt:  40%|███▉      | 2.00G/5.00G [00:52<01:17, 38.6MB/s]
# hf_model_0001_1.pt:  45%|████▌     | 2.25G/4.98G [00:58<00:49, 54.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  44%|████▎     | 2.17G/4.98G [00:59<01:02, 45.0MB/s]
#
# hf_model_0002_1.pt:  40%|████      | 2.01G/5.00G [00:52<01:19, 37.6MB/s]
# hf_model_0001_1.pt:  45%|████▌     | 2.26G/4.98G [00:58<00:58, 46.7MB/s]
#
# hf_model_0002_0.pt:  28%|██▊       | 1.41G/5.00G [00:56<01:18, 45.8MB/s]
#
#
# hf_model_0002_1.pt:  40%|████      | 2.02G/5.00G [00:52<01:26, 34.5MB/s]
# hf_model_0001_1.pt:  46%|████▌     | 2.27G/4.98G [00:58<01:05, 41.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:  44%|████▍     | 2.18G/4.98G [01:00<01:34, 29.6MB/s]
#
# hf_model_0002_1.pt:  41%|████      | 2.03G/5.00G [00:53<01:10, 42.1MB/s]
#
#
# hf_model_0001_2.pt:  42%|████▏     | 2.10G/4.98G [00:57<01:26, 33.5MB/s]
#
#
#
#
# hf_model_0001_0.pt:  44%|████▍     | 2.19G/4.98G [01:00<01:26, 32.2MB/s]
#
# hf_model_0002_1.pt:  41%|████      | 2.05G/5.00G [00:53<01:03, 46.1MB/s]
# hf_model_0001_1.pt:  46%|████▌     | 2.29G/4.98G [00:59<01:15, 35.6MB/s]
#
#
#
#
# hf_model_0001_0.pt:  44%|████▍     | 2.21G/4.98G [01:01<01:13, 37.7MB/s]
#
# hf_model_0002_0.pt:  29%|██▉       | 1.46G/5.00G [00:57<01:15, 47.0MB/s]
#
#
# hf_model_0002_1.pt:  41%|████▏     | 2.06G/5.00G [00:53<01:04, 45.4MB/s]
# hf_model_0001_1.pt:  46%|████▋     | 2.30G/4.98G [00:59<01:07, 39.4MB/s]
#
#
# hf_model_0001_2.pt:  43%|████▎     | 2.13G/4.98G [00:58<01:13, 38.7MB/s]
#
# hf_model_0002_0.pt:  29%|██▉       | 1.47G/5.00G [00:57<01:14, 47.4MB/s]
#
#
#
#
# hf_model_0001_0.pt:  45%|████▍     | 2.22G/4.98G [01:01<01:12, 38.0MB/s]
# hf_model_0002_1.pt:  42%|████▏     | 2.08G/5.00G [00:54<01:10, 41.4MB/s]
#
#
# hf_model_0001_2.pt:  43%|████▎     | 2.14G/4.98G [00:58<01:10, 40.0MB/s]
#
# hf_model_0002_0.pt:  30%|██▉       | 1.49G/5.00G [00:58<01:13, 47.7MB/s]
#
#
#
#
# hf_model_0001_0.pt:  45%|████▌     | 2.24G/4.98G [01:01<01:08, 39.8MB/s]
# hf_model_0002_1.pt:  42%|████▏     | 2.10G/5.00G [00:54<01:04, 44.8MB/s]
# ...
#
# hf_model_0003_1.pt:  80%|███████▉  | 3.92G/4.92G [01:41<00:32, 30.4MB/s][A
#
#
#
#
#
#
# hf_model_0003_2.pt:  67%|██████▋   | 3.30G/4.92G [01:33<01:57, 13.8MB/s]
# hf_model_0003_1.pt:  80%|████████  | 3.94G/4.92G [01:42<00:28, 34.4MB/s]
#
#
#
#
#
#
# hf_model_0003_2.pt:  67%|██████▋   | 3.31G/4.92G [01:34<01:31, 17.5MB/s]
# hf_model_0003_1.pt:  80%|████████  | 3.95G/4.92G [01:42<00:25, 37.8MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  67%|██████▋   | 784M/1.17G [00:20<00:12, 30.3MB/s]
#
#
# hf_model_0003_1.pt:  81%|████████  | 3.97G/4.92G [01:42<00:23, 40.5MB/s]
# hf_model_0002_2.pt:  89%|████████▉ | 4.46G/5.00G [01:49<00:12, 42.6MB/s]
#
#
#
# hf_model_0003_1.pt:  81%|████████  | 3.98G/4.92G [01:43<00:20, 45.1MB/s]
# hf_model_0002_2.pt:  90%|████████▉ | 4.48G/5.00G [01:49<00:11, 43.9MB/s]
#
#
#
#
#
# hf_model_0003_1.pt:  81%|████████▏ | 4.00G/4.92G [01:43<00:19, 46.6MB/s][A
#
#
# hf_model_0003_2.pt:  68%|██████▊   | 3.34G/4.92G [01:35<01:13, 21.3MB/s]
# hf_model_0002_2.pt:  90%|████████▉ | 4.50G/5.00G [01:49<00:10, 46.4MB/s]
#
# hf_model_0004_2.pt:  70%|██████▉   | 816M/1.17G [00:21<00:10, 33.6MB/s]
#
#
#
# hf_model_0003_1.pt:  82%|████████▏ | 4.02G/4.92G [01:43<00:18, 48.2MB/s]
#
#
# hf_model_0003_2.pt:  68%|██████▊   | 3.36G/4.92G [01:35<01:00, 25.8MB/s]
#
#
#
#
# hf_model_0003_1.pt:  82%|████████▏ | 4.03G/4.92G [01:43<00:17, 49.8MB/s]
#
# hf_model_0004_2.pt:  71%|███████   | 832M/1.17G [00:22<00:10, 32.9MB/s]
# hf_model_0002_2.pt:  90%|█████████ | 4.51G/5.00G [01:50<00:12, 38.0MB/s]
#
#
# hf_model_0003_2.pt:  69%|██████▊   | 3.38G/4.92G [01:36<00:53, 28.6MB/s]
#
#
#
# hf_model_0003_1.pt:  82%|████████▏ | 4.05G/4.92G [01:44<00:16, 52.2MB/s]
#
# hf_model_0004_2.pt:  73%|███████▎  | 848M/1.17G [00:22<00:08, 36.8MB/s]
# hf_model_0003_1.pt:  83%|████████▎ | 4.06G/4.92G [01:44<00:16, 52.0MB/s]
#
# hf_model_0003_1.pt:  83%|████████▎ | 4.08G/4.92G [01:44<00:15, 53.0MB/s][A
# hf_model_0002_2.pt:  90%|█████████ | 4.52G/5.00G [01:51<00:19, 24.4MB/s]
# hf_model_0002_2.pt:  91%|█████████ | 4.53G/5.00G [01:51<00:19, 24.6MB/s]
#
#
#
#
#
# hf_model_0003_1.pt:  83%|████████▎ | 4.10G/4.92G [01:45<00:16, 50.0MB/s][A
#
#
#
#
#
# hf_model_0004_2.pt:  77%|███████▋  | 896M/1.17G [00:23<00:06, 42.9MB/s]
# hf_model_0003_1.pt:  84%|████████▎ | 4.11G/4.92G [01:45<00:15, 51.2MB/s]
#
#
# hf_model_0003_2.pt:  69%|██████▉   | 3.39G/4.92G [01:37<01:20, 18.9MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  78%|███████▊  | 912M/1.17G [00:24<00:05, 44.5MB/s]
# hf_model_0003_1.pt:  84%|████████▍ | 4.13G/4.92G [01:45<00:15, 49.7MB/s]
#
#
# hf_model_0003_2.pt:  69%|██████▉   | 3.41G/4.92G [01:37<01:04, 23.2MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  79%|███████▉  | 928M/1.17G [00:24<00:05, 46.0MB/s]
# hf_model_0003_1.pt:  84%|████████▍ | 4.14G/4.92G [01:46<00:15, 50.4MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  81%|████████  | 944M/1.17G [00:24<00:04, 47.1MB/s]
#
#
# hf_model_0003_1.pt:  85%|████████▍ | 4.16G/4.92G [01:46<00:15, 49.6MB/s]
# hf_model_0002_2.pt:  92%|█████████▏| 4.58G/5.00G [01:52<00:11, 35.8MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  82%|████████▏ | 960M/1.17G [00:25<00:04, 47.6MB/s]
#
#
# hf_model_0003_1.pt:  85%|████████▍ | 4.18G/4.92G [01:46<00:14, 49.7MB/s]
# hf_model_0003_1.pt:  85%|████████▌ | 4.19G/4.92G [01:46<00:13, 53.3MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  84%|████████▎ | 976M/1.17G [00:25<00:04, 47.5MB/s]
#
#
# hf_model_0003_2.pt:  70%|███████   | 3.46G/4.92G [01:39<00:41, 35.0MB/s]
# hf_model_0003_1.pt:  85%|████████▌ | 4.19G/4.92G [01:47<00:19, 37.3MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  85%|████████▍ | 992M/1.17G [00:25<00:03, 46.3MB/s]
#
#
# hf_model_0003_2.pt:  71%|███████   | 3.47G/4.92G [01:39<00:38, 37.5MB/s]
#
#
#
#
#
# hf_model_0004_2.pt:  86%|████████▋ | 1.01G/1.17G [00:26<00:03, 46.3MB/s]
#
#
# hf_model_0003_1.pt:  85%|████████▌ | 4.20G/4.92G [01:47<00:27, 26.4MB/s]
# hf_model_0002_2.pt:  92%|█████████▏| 4.62G/5.00G [01:54<00:12, 31.2MB/s]
#
#
#
#
#
# hf_model_0003_1.pt:  86%|████████▌ | 4.21G/4.92G [01:48<00:23, 30.6MB/s]
#
#
# hf_model_0003_2.pt:  71%|███████▏  | 3.50G/4.92G [01:40<00:33, 41.7MB/s]
# hf_model_0002_2.pt:  93%|█████████▎| 4.64G/5.00G [01:54<00:10, 34.0MB/s]
#
#
#
# hf_model_0003_1.pt:  86%|████████▌ | 4.22G/4.92G [01:48<00:18, 36.7MB/s]
#
# hf_model_0004_2.pt:  89%|████████▉ | 1.04G/1.17G [00:26<00:02, 46.1MB/s]
#
#
# hf_model_0003_2.pt:  72%|███████▏  | 3.52G/4.92G [01:40<00:37, 37.1MB/s]
# hf_model_0003_1.pt:  86%|████████▋ | 4.24G/4.92G [01:48<00:15, 42.3MB/s]
#
# hf_model_0004_2.pt:  90%|█████████ | 1.06G/1.17G [00:27<00:02, 49.4MB/s]
#
#
#
#
#
#
# hf_model_0003_2.pt:  72%|███████▏  | 3.54G/4.92G [01:40<00:34, 39.7MB/s]
# hf_model_0002_2.pt:  93%|█████████▎| 4.67G/5.00G [01:55<00:08, 40.4MB/s]
#
# hf_model_0003_1.pt:  87%|████████▋ | 4.26G/4.92G [01:49<00:18, 36.5MB/s]
# hf_model_0002_2.pt:  94%|█████████▍| 4.69G/5.00G [01:55<00:07, 43.8MB/s]
#
#
#
#
# hf_model_0003_0.pt:  91%|█████████▏| 4.50G/4.92G [01:50<00:10, 39.4MB/s]
#
#
# hf_model_0003_1.pt:  87%|████████▋ | 4.27G/4.92G [01:49<00:15, 41.9MB/s]
#
# hf_model_0004_2.pt:  93%|█████████▎| 1.09G/1.17G [00:27<00:01, 42.7MB/s]
# hf_model_0002_2.pt:  94%|█████████▍| 4.70G/5.00G [01:55<00:06, 47.0MB/s]
#
#
# hf_model_0003_1.pt:  87%|████████▋ | 4.29G/4.92G [01:49<00:14, 43.8MB/s]
#
# hf_model_0004_2.pt:  95%|█████████▍| 1.10G/1.17G [00:28<00:01, 45.4MB/s]
# hf_model_0003_1.pt:  88%|████████▊ | 4.30G/4.92G [01:50<00:13, 47.0MB/s]
#
# hf_model_0004_2.pt:  96%|█████████▌| 1.12G/1.17G [00:28<00:01, 48.0MB/s]
#
#
# hf_model_0003_2.pt:  73%|███████▎  | 3.58G/4.92G [01:42<00:34, 38.5MB/s]
#
#
#
#
# hf_model_0003_0.pt:  92%|█████████▏| 4.51G/4.92G [01:51<00:14, 28.7MB/s]
# hf_model_0002_2.pt:  95%|█████████▍| 4.74G/5.00G [01:56<00:05, 46.4MB/s]
#
# hf_model_0003_1.pt:  88%|████████▊ | 4.32G/4.92G [01:50<00:12, 48.7MB/s]
#
#
# hf_model_0003_2.pt:  73%|███████▎  | 3.60G/4.92G [01:42<00:31, 41.8MB/s]
#
#
#
#
# hf_model_0003_0.pt:  92%|█████████▏| 4.53G/4.92G [01:52<00:11, 32.8MB/s]
# hf_model_0003_1.pt:  88%|████████▊ | 4.34G/4.92G [01:50<00:11, 49.5MB/s]
#
# hf_model_0004_2.pt:  99%|█████████▊| 1.15G/1.17G [00:29<00:00, 49.1MB/s]
# hf_model_0002_2.pt:  95%|█████████▌| 4.77G/5.00G [01:57<00:04, 50.9MB/s]
#
#
# hf_model_0003_2.pt:  74%|███████▎  | 3.62G/4.92G [01:42<00:31, 41.8MB/s]
#
#
#
#
# hf_model_0003_1.pt:  89%|████████▊ | 4.35G/4.92G [01:51<00:11, 48.5MB/s]
#
# hf_model_0004_2.pt: 100%|█████████▉| 1.17G/1.17G [00:29<00:00, 46.7MB/s]
#
#
# hf_model_0003_2.pt:  74%|███████▍  | 3.63G/4.92G [01:43<00:29, 43.7MB/s]
# hf_model_0002_2.pt:  96%|█████████▌| 4.78G/5.00G [01:57<00:04, 49.3MB/s]
#
#
#
#
# hf_model_0004_2.pt: 100%|██████████| 1.17G/1.17G [00:29<00:00, 39.2MB/s]
#
# hf_model_0002_2.pt:  96%|█████████▌| 4.80G/5.00G [01:57<00:03, 52.2MB/s]
#
#
# hf_model_0003_2.pt:  74%|███████▍  | 3.65G/4.92G [01:43<00:29, 43.3MB/s]
#
# recipe_state.pt:   0%|          | 0.00/80.1M [00:00<?, ?B/s]
#
#
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.58G/4.92G [01:53<00:08, 38.7MB/s]
# hf_model_0002_2.pt:  96%|█████████▋| 4.82G/5.00G [01:58<00:03, 52.7MB/s]
#
#
# hf_model_0003_2.pt:  75%|███████▍  | 3.66G/4.92G [01:43<00:27, 45.2MB/s]
#
# hf_model_0003_1.pt:  89%|████████▉ | 4.38G/4.92G [01:52<00:13, 38.3MB/s]
# hf_model_0002_2.pt:  97%|█████████▋| 4.83G/5.00G [01:58<00:03, 54.6MB/s]
#
#
# hf_model_0003_1.pt:  90%|████████▉ | 4.40G/4.92G [01:52<00:12, 40.7MB/s]
# hf_model_0002_2.pt:  97%|█████████▋| 4.85G/5.00G [01:58<00:02, 52.3MB/s]
#
#
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.59G/4.92G [01:53<00:10, 30.4MB/s]
#
# recipe_state.pt:  40%|███▉      | 32.0M/80.1M [00:01<00:01, 27.8MB/s]
# hf_model_0003_1.pt:  90%|████████▉ | 4.42G/4.92G [01:52<00:12, 41.5MB/s]
#
#
#
#
# hf_model_0003_0.pt:  94%|█████████▎| 4.61G/4.92G [01:54<00:08, 34.9MB/s]
# hf_model_0002_2.pt:  98%|█████████▊| 4.88G/5.00G [01:59<00:02, 50.5MB/s]
#
# hf_model_0003_1.pt:  90%|█████████ | 4.43G/4.92G [01:53<00:11, 42.1MB/s]
#
#
# hf_model_0003_2.pt:  75%|███████▌  | 3.70G/4.92G [01:45<00:39, 31.2MB/s]
#
#
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.62G/4.92G [01:54<00:08, 36.5MB/s]
# hf_model_0003_1.pt:  90%|█████████ | 4.45G/4.92G [01:53<00:10, 45.0MB/s]
#
# recipe_state.pt:  80%|███████▉  | 64.0M/80.1M [00:01<00:00, 38.3MB/s]
#
#
# hf_model_0003_2.pt:  76%|███████▌  | 3.71G/4.92G [01:45<00:34, 35.3MB/s]
#
#
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.64G/4.92G [01:55<00:07, 37.2MB/s]
#
# hf_model_0003_1.pt:  91%|█████████ | 4.46G/4.92G [01:53<00:09, 45.6MB/s]
# hf_model_0002_2.pt:  98%|█████████▊| 4.91G/5.00G [02:00<00:01, 46.7MB/s]
#
#
# hf_model_0003_2.pt:  76%|███████▌  | 3.73G/4.92G [01:45<00:30, 38.4MB/s]
#
#
#
#
# recipe_state.pt: 100%|██████████| 80.1M/80.1M [00:02<00:00, 35.6MB/s]/s]
#
# hf_model_0003_1.pt:  91%|█████████ | 4.48G/4.92G [01:54<00:09, 44.5MB/s]
#
#
# hf_model_0003_2.pt:  76%|███████▌  | 3.74G/4.92G [01:46<00:28, 40.9MB/s]
#
#
#
#
# hf_model_0003_0.pt:  95%|█████████▌| 4.67G/4.92G [01:55<00:05, 43.5MB/s]
# hf_model_0003_1.pt:  91%|█████████▏| 4.50G/4.92G [01:54<00:09, 46.0MB/s]
#
#
#
#
# hf_model_0003_0.pt:  95%|█████████▌| 4.69G/4.92G [01:55<00:04, 47.4MB/s]
#
#
# hf_model_0003_1.pt:  92%|█████████▏| 4.51G/4.92G [01:54<00:08, 47.7MB/s]
#
#
#
#
# hf_model_0003_0.pt:  96%|█████████▌| 4.70G/4.92G [01:56<00:04, 48.3MB/s]
# hf_model_0003_1.pt:  92%|█████████▏| 4.53G/4.92G [01:55<00:07, 49.5MB/s]
#
#
#
#
# hf_model_0003_0.pt:  96%|█████████▌| 4.72G/4.92G [01:56<00:04, 48.5MB/s]
#
#
# hf_model_0003_1.pt:  92%|█████████▏| 4.54G/4.92G [01:55<00:07, 49.6MB/s]
#
#
#
#
# hf_model_0003_0.pt:  96%|█████████▋| 4.74G/4.92G [01:56<00:03, 50.2MB/s]
# hf_model_0002_2.pt: 100%|█████████▉| 4.98G/5.00G [02:01<00:00, 37.0MB/s]
#
#
# hf_model_0003_1.pt:  93%|█████████▎| 4.56G/4.92G [01:55<00:07, 49.8MB/s]
#
#
#
#
# hf_model_0003_0.pt:  97%|█████████▋| 4.75G/4.92G [01:57<00:03, 50.5MB/s]
# hf_model_0002_2.pt: 100%|█████████▉| 4.99G/5.00G [02:02<00:00, 40.7MB/s]
#
#
# hf_model_0003_1.pt:  93%|█████████▎| 4.58G/4.92G [01:55<00:06, 50.4MB/s]
#
#
#
#
# hf_model_0002_2.pt: 100%|██████████| 5.00G/5.00G [02:02<00:00, 40.8MB/s]
# hf_model_0003_1.pt:  93%|█████████▎| 4.59G/4.92G [01:56<00:06, 49.2MB/s]
#
#
#
#
# hf_model_0003_0.pt:  97%|█████████▋| 4.78G/4.92G [01:57<00:02, 47.0MB/s]
#
#
#
# Upload 17 LFS files:  59%|█████▉    | 10/17 [04:06<03:21, 28.80s/it]
#
#
# hf_model_0003_1.pt:  94%|█████████▎| 4.61G/4.92G [01:56<00:06, 47.9MB/s]
#
#
#
#
# hf_model_0003_1.pt:  94%|█████████▍| 4.62G/4.92G [01:56<00:05, 51.2MB/s]
#
#
# hf_model_0003_2.pt:  78%|███████▊  | 3.84G/4.92G [01:48<00:29, 36.3MB/s]
#
#
#
#
# hf_model_0003_0.pt:  98%|█████████▊| 4.82G/4.92G [01:58<00:02, 48.5MB/s]
#
#
# hf_model_0003_1.pt:  94%|█████████▍| 4.64G/4.92G [01:57<00:05, 47.9MB/s]
#
#
#
#
# hf_model_0003_0.pt:  98%|█████████▊| 4.83G/4.92G [01:58<00:01, 47.6MB/s]
#
#
# hf_model_0003_1.pt:  95%|█████████▍| 4.66G/4.92G [01:57<00:05, 50.9MB/s]
#
#
#
#
# hf_model_0003_0.pt:  99%|█████████▊| 4.85G/4.92G [01:59<00:01, 49.3MB/s]
#
#
# hf_model_0003_1.pt:  95%|█████████▌| 4.67G/4.92G [01:57<00:04, 50.5MB/s]
#
#
#
#
# hf_model_0003_1.pt:  95%|█████████▌| 4.69G/4.92G [01:58<00:04, 49.4MB/s]
#
#
#
#
# hf_model_0003_1.pt:  96%|█████████▌| 4.70G/4.92G [01:58<00:04, 47.0MB/s]
#
#
#
#
# hf_model_0003_1.pt:  96%|█████████▌| 4.72G/4.92G [01:58<00:04, 46.5MB/s]
#
#
#
#
# hf_model_0003_0.pt: 100%|██████████| 4.92G/4.92G [02:00<00:00, 40.7MB/s]
#
#
#
# hf_model_0003_2.pt:  79%|███████▉  | 3.90G/4.92G [01:51<00:44, 22.8MB/s]
#
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.75G/4.92G [01:59<00:03, 47.0MB/s][A
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.77G/4.92G [01:59<00:03, 48.3MB/s]
#
#
# hf_model_0003_2.pt:  80%|████████  | 3.94G/4.92G [01:52<00:31, 31.3MB/s]
#
#
# hf_model_0003_2.pt:  80%|████████  | 3.95G/4.92G [01:52<00:27, 35.4MB/s]
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.78G/4.92G [02:00<00:03, 34.1MB/s]
#
#
# hf_model_0003_1.pt:  98%|█████████▊| 4.82G/4.92G [02:01<00:02, 41.4MB/s]f_model_0003_1.pt:  98%|█████████▊| 4.80G/4.92G [02:01<00:03, 37.6MB/s]
#
#
# hf_model_0003_1.pt:  98%|█████████▊| 4.83G/4.92G [02:01<00:01, 42.8MB/s]
#
#
# hf_model_0003_1.pt:  99%|█████████▊| 4.85G/4.92G [02:02<00:01, 43.8MB/s]
#
#
# hf_model_0003_2.pt:  82%|████████▏ | 4.03G/4.92G [01:54<00:20, 42.9MB/s]
#
#
# hf_model_0003_1.pt:  99%|█████████▉| 4.88G/4.92G [02:02<00:00, 41.9MB/s]
#
#
# hf_model_0003_2.pt:  83%|████████▎ | 4.06G/4.92G [01:54<00:20, 42.0MB/s]
#
#
# hf_model_0003_2.pt:  83%|████████▎ | 4.08G/4.92G [01:55<00:19, 43.2MB/s]
#
#
# hf_model_0003_1.pt: 100%|█████████▉| 4.91G/4.92G [02:04<00:00, 35.5MB/s]
#
#
# hf_model_0003_1.pt: 100%|██████████| 4.92G/4.92G [02:04<00:00, 39.6MB/s]
#
#
#
# hf_model_0003_2.pt:  84%|████████▍ | 4.13G/4.92G [01:56<00:18, 41.9MB/s]
#
#
#
# Upload 17 LFS files:  71%|███████   | 12/17 [04:14<01:35, 19.06s/it]
#
#
# hf_model_0003_2.pt:  84%|████████▍ | 4.14G/4.92G [01:56<00:17, 43.2MB/s]
#
#
# hf_model_0003_2.pt:  85%|████████▍ | 4.16G/4.92G [01:57<00:17, 44.4MB/s]
#
#
# hf_model_0003_2.pt:  85%|████████▍ | 4.18G/4.92G [01:57<00:15, 48.5MB/s]
#
#
# hf_model_0003_2.pt:  85%|████████▌ | 4.19G/4.92G [01:57<00:16, 42.8MB/s]
#
#
# hf_model_0003_2.pt:  86%|████████▌ | 4.21G/4.92G [01:58<00:17, 41.5MB/s]
#
#
# hf_model_0003_2.pt:  86%|████████▌ | 4.22G/4.92G [01:58<00:15, 43.6MB/s]
#
#
# hf_model_0003_2.pt:  86%|████████▋ | 4.24G/4.92G [01:58<00:15, 44.9MB/s]
#
#
# hf_model_0003_2.pt:  87%|████████▋ | 4.26G/4.92G [01:59<00:14, 46.2MB/s]
#
#
# hf_model_0003_2.pt:  87%|████████▋ | 4.27G/4.92G [01:59<00:14, 43.5MB/s]
#
#
# hf_model_0003_2.pt:  87%|████████▋ | 4.29G/4.92G [02:00<00:14, 41.9MB/s]
#
#
# hf_model_0003_2.pt:  88%|████████▊ | 4.30G/4.92G [02:00<00:16, 37.4MB/s]
#
#
# hf_model_0003_2.pt:  88%|████████▊ | 4.32G/4.92G [02:01<00:16, 37.1MB/s]
#
#
# hf_model_0003_2.pt:  88%|████████▊ | 4.34G/4.92G [02:01<00:14, 40.3MB/s]
#
#
# hf_model_0003_2.pt:  89%|████████▊ | 4.35G/4.92G [02:01<00:12, 43.8MB/s]
#
#
# hf_model_0003_2.pt:  89%|████████▉ | 4.37G/4.92G [02:01<00:11, 48.1MB/s]
#
#
# hf_model_0003_2.pt:  89%|████████▉ | 4.38G/4.92G [02:02<00:11, 46.9MB/s]
#
#
# hf_model_0003_2.pt:  90%|████████▉ | 4.40G/4.92G [02:02<00:11, 45.3MB/s]
#
#
# hf_model_0003_2.pt:  90%|████████▉ | 4.42G/4.92G [02:03<00:11, 43.6MB/s]
#
#
# hf_model_0003_2.pt:  90%|█████████ | 4.43G/4.92G [02:03<00:10, 44.9MB/s]
#
#
# hf_model_0003_2.pt:  90%|█████████ | 4.45G/4.92G [02:03<00:10, 46.3MB/s]
#
#
# hf_model_0003_2.pt:  91%|█████████ | 4.46G/4.92G [02:04<00:09, 48.8MB/s]
#
#
# hf_model_0003_2.pt:  91%|█████████ | 4.48G/4.92G [02:04<00:09, 47.8MB/s]
#
#
# hf_model_0003_2.pt:  91%|█████████▏| 4.50G/4.92G [02:04<00:08, 49.3MB/s]
#
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.51G/4.92G [02:04<00:08, 50.1MB/s]
#
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.53G/4.92G [02:05<00:08, 46.1MB/s]
#
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.54G/4.92G [02:05<00:07, 46.7MB/s]
#
#
# hf_model_0003_2.pt:  93%|█████████▎| 4.56G/4.92G [02:05<00:07, 50.2MB/s]
#
#
# hf_model_0003_2.pt:  93%|█████████▎| 4.58G/4.92G [02:06<00:06, 49.7MB/s]
#
#
# hf_model_0003_2.pt:  93%|█████████▎| 4.59G/4.92G [02:06<00:07, 43.6MB/s]
#
#
# hf_model_0003_2.pt:  94%|█████████▎| 4.61G/4.92G [02:07<00:06, 45.0MB/s]
#
#
# hf_model_0003_2.pt:  94%|█████████▍| 4.62G/4.92G [02:07<00:07, 39.9MB/s]
#
#
# hf_model_0003_2.pt:  94%|█████████▍| 4.64G/4.92G [02:07<00:06, 43.7MB/s]
#
#
# hf_model_0003_2.pt:  95%|█████████▍| 4.66G/4.92G [02:08<00:05, 44.0MB/s]
#
#
# hf_model_0003_2.pt:  95%|█████████▌| 4.67G/4.92G [02:08<00:05, 45.8MB/s]
#
#
# hf_model_0003_2.pt:  95%|█████████▌| 4.69G/4.92G [02:08<00:04, 48.5MB/s]
#
#
# hf_model_0003_2.pt:  96%|█████████▌| 4.70G/4.92G [02:09<00:04, 44.1MB/s]
#
#
# hf_model_0003_2.pt:  96%|█████████▌| 4.72G/4.92G [02:09<00:04, 48.5MB/s]
#
#
# hf_model_0003_2.pt:  96%|█████████▋| 4.74G/4.92G [02:09<00:03, 47.1MB/s]
#
#
# hf_model_0003_2.pt:  97%|█████████▋| 4.75G/4.92G [02:10<00:05, 29.6MB/s]
#
#
# hf_model_0003_2.pt:  97%|█████████▋| 4.77G/4.92G [02:11<00:05, 27.6MB/s]
#
#
# hf_model_0003_2.pt:  97%|█████████▋| 4.78G/4.92G [02:11<00:04, 32.3MB/s]
#
#
# hf_model_0003_2.pt:  98%|█████████▊| 4.80G/4.92G [02:12<00:03, 36.4MB/s]
#
#
# hf_model_0003_2.pt:  98%|█████████▊| 4.82G/4.92G [02:12<00:02, 40.0MB/s]
#
#
# hf_model_0003_2.pt:  98%|█████████▊| 4.83G/4.92G [02:13<00:02, 28.3MB/s]
#
#
# hf_model_0003_2.pt:  99%|█████████▊| 4.85G/4.92G [02:13<00:02, 29.6MB/s]
#
#
# hf_model_0003_2.pt:  99%|█████████▉| 4.86G/4.92G [02:14<00:01, 34.3MB/s]
#
#
# hf_model_0003_2.pt:  99%|█████████▉| 4.88G/4.92G [02:14<00:00, 37.9MB/s]
#
#
# hf_model_0003_2.pt: 100%|█████████▉| 4.90G/4.92G [02:14<00:00, 40.8MB/s]
#
#
# hf_model_0003_2.pt: 100%|██████████| 4.92G/4.92G [02:15<00:00, 36.3MB/s]
#
#
#
#
# Upload 17 LFS files:  76%|███████▋  | 13/17 [04:33<01:16, 19.09s/it]load 17 LFS files: 100%|██████████| 17/17 [04:33<00:00, 16.09s/it]
# https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3/tree/main/.

# %% [markdown]
# ## Evaluation

# %%
import torch
import pandas as pd
from huggingface_hub import login
from peft import PeftModel, PeftModelForCausalLM
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM 
from collections import defaultdict
from tqdm import tqdm
from pathlib import Path
import pickle

# %%
TEST_DATA_PATH
# Out:
# 'data/resume_critique_model_4_test.jsonl'

# %%
df = pd.read_json(TEST_DATA_PATH, orient="records", lines=True)

# %%
len(df)
# Out:
# 30

# %%
OUTPUT_MODEL_PATH
# Out:
# 'checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_4_2k-adapter-rev_3'

# %%
model = AutoModelForCausalLM.from_pretrained(BASE_MODEL_PATH, torch_dtype=torch.float16, device_map="cuda:0")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:03<00:00,  1.08it/s]

# %%
peft_model = PeftModelForCausalLM.from_pretrained(model, OUTPUT_MODEL_PATH)

# %%
tokenizer = AutoTokenizer.from_pretrained(
	BASE_MODEL_PATH,
	padding_side = "right",
	add_eos_token = True
)
tokenizer.pad_token = tokenizer.eos_token

# %%
gen_params = {
	"temperature": 0.3,
	"max_new_tokens": 300,
    "top_p": 0.95
}

# %%
# eos_list = ["\n\n", ""]

def generate_llm(prompt, gen_params):
	prompt = prompt.split("### Response:\n")[0] + "### Response:\n"
	inputs = tokenizer(prompt, return_tensors = "pt").to("cuda:0")
	generate_ids = model.generate(inputs.input_ids, **gen_params)
	returned = tokenizer.batch_decode(generate_ids, skip_special_tokens = False)[0]
	generated_text = returned.split("### Response:\n")[1]
	generated_text = generated_text.rsplit(".", 1)[0] + "."
	return generated_text

# %%
prompt_ex = df.iloc[0].text
res = generate_llm(prompt_ex, gen_params)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.

# %%
print(res)
# Out:
# 'Introduction': Your work history section contains substantial content, which is a positive aspect of your CV. However, it is essential to present this information in an engaging and impactful way to truly capture the attention of potential employers. This section should not only list job titles and companies but also provide insights into your responsibilities and achievements.
# 'Achiever': Your work history does include substantive content, but it could benefit from a stronger emphasis on accomplishments. Striking a balance between listing tasks and showcasing achievements is crucial; this will help you appear as an 'achiever' rather than just a 'do-er.' By rewriting your duties to highlight measurable outcomes, you can significantly enhance the impact of your CV.
# 'Achievements': ['Developed and implemented comprehensive records management policies and procedures, ensuring compliance and efficiency.', 'Led multiple high-profile projects, resulting in the successful digitization and archival of audio, video, and photographic archives.']
# 'Passive': Your work history contains some passive language that could be more dynamic. Avoiding repetitive or weak language is essential for maintaining the reader's interest. By using active verbs and engaging language, you can create a more compelling narrative that highlights your contributions and impact.
# 'Passive Language': ['Was responsible for managing']
# 'Screen Out: Your CV demonstrates a consistent work history, which is commendable. This consistency is crucial in avoiding potential concerns about gaps or outdated positions.

# %%
responses = defaultdict(list)

# %%
prompts = df.text.tolist()

# %%
gen_params = {
	"temperature": 0.45,
	"max_new_tokens": 300,
    "top_p": 0.90
}

prompts = df.text.tolist()
results = []
for prompt in tqdm(prompts):
	res = generate_llm(prompt, gen_params)
	results.append(res)
responses["0.45"] += results
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 1/30 [00:09<04:41,  9.71s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 2/30 [00:19<04:30,  9.66s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 3/30 [00:28<04:20,  9.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 4/30 [00:38<04:10,  9.64s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 5/30 [00:49<04:12, 10.11s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 6/30 [00:59<03:59,  9.96s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 7/30 [01:08<03:47,  9.88s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 8/30 [01:18<03:37,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 9/30 [01:28<03:27,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 10/30 [01:38<03:17,  9.86s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 11/30 [01:48<03:07,  9.88s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  40%|████      | 12/30 [01:58<02:57,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  43%|████▎     | 13/30 [02:07<02:46,  9.82s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  47%|████▋     | 14/30 [02:17<02:36,  9.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  50%|█████     | 15/30 [02:27<02:26,  9.77s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  53%|█████▎    | 16/30 [02:37<02:16,  9.77s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  57%|█████▋    | 17/30 [02:46<02:06,  9.75s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  60%|██████    | 18/30 [02:56<01:56,  9.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  63%|██████▎   | 19/30 [03:06<01:46,  9.69s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  67%|██████▋   | 20/30 [03:15<01:36,  9.67s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  70%|███████   | 21/30 [03:25<01:26,  9.65s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  73%|███████▎  | 22/30 [03:35<01:17,  9.69s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  77%|███████▋  | 23/30 [03:44<01:07,  9.68s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  80%|████████  | 24/30 [03:54<00:58,  9.68s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  83%|████████▎ | 25/30 [04:04<00:48,  9.70s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  87%|████████▋ | 26/30 [04:14<00:38,  9.73s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 27/30 [04:23<00:29,  9.69s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 28/30 [04:33<00:19,  9.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 29/30 [04:43<00:09,  9.74s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 30/30 [04:52<00:00,  9.76s/it]

# %%
gen_params = {
	"temperature": 0.65,
	"max_new_tokens": 300,
    "top_p": 0.95
}

prompts = df.text.tolist()
results = []
for prompt in tqdm(prompts):
	res = generate_llm(prompt, gen_params)
	results.append(res)
responses["0.60"] += results
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 1/30 [00:09<04:44,  9.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 2/30 [00:19<04:35,  9.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 3/30 [00:29<04:24,  9.80s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 4/30 [00:39<04:15,  9.82s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 5/30 [00:50<04:16, 10.24s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 6/30 [01:00<04:03, 10.13s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 7/30 [01:10<03:51, 10.05s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 8/30 [01:20<03:40, 10.03s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 9/30 [01:30<03:30, 10.02s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 10/30 [01:39<03:18,  9.94s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 11/30 [01:49<03:09,  9.96s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  40%|████      | 12/30 [01:59<02:58,  9.92s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  43%|████▎     | 13/30 [02:09<02:47,  9.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  47%|████▋     | 14/30 [02:19<02:37,  9.82s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  50%|█████     | 15/30 [02:28<02:26,  9.78s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  53%|█████▎    | 16/30 [02:38<02:16,  9.77s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  57%|█████▋    | 17/30 [02:48<02:07,  9.78s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  60%|██████    | 18/30 [02:58<01:57,  9.77s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  63%|██████▎   | 19/30 [03:07<01:47,  9.77s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  67%|██████▋   | 20/30 [03:17<01:37,  9.79s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  70%|███████   | 21/30 [03:27<01:28,  9.78s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  73%|███████▎  | 22/30 [03:37<01:18,  9.76s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  77%|███████▋  | 23/30 [03:46<01:08,  9.76s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  80%|████████  | 24/30 [03:56<00:58,  9.79s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  83%|████████▎ | 25/30 [04:06<00:49,  9.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  87%|████████▋ | 26/30 [04:16<00:39,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 27/30 [04:26<00:29,  9.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 28/30 [04:36<00:19,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 29/30 [04:46<00:09,  9.89s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 30/30 [04:56<00:00,  9.87s/it]

# %%
gen_params = {
	"temperature": 0.75,
	"max_new_tokens": 300,
    "top_p": 0.97
}

prompts = df.text.tolist()
results = []
for prompt in tqdm(prompts):
	res = generate_llm(prompt, gen_params)
	results.append(res)
responses["0.70"] += results
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 1/30 [00:09<04:47,  9.92s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 2/30 [00:19<04:36,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 3/30 [00:29<04:25,  9.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 4/30 [00:39<04:15,  9.85s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 5/30 [00:50<04:16, 10.25s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 6/30 [01:00<04:01, 10.06s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 7/30 [01:09<03:48,  9.92s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 8/30 [01:19<03:36,  9.86s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 9/30 [01:29<03:26,  9.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 10/30 [01:38<03:15,  9.79s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 11/30 [01:48<03:06,  9.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  40%|████      | 12/30 [01:58<02:56,  9.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  43%|████▎     | 13/30 [02:08<02:46,  9.78s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  47%|████▋     | 14/30 [02:18<02:36,  9.76s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  50%|█████     | 15/30 [02:27<02:26,  9.73s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  53%|█████▎    | 16/30 [02:37<02:16,  9.74s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  57%|█████▋    | 17/30 [02:47<02:06,  9.71s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  60%|██████    | 18/30 [02:56<01:56,  9.70s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  63%|██████▎   | 19/30 [03:06<01:46,  9.70s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  67%|██████▋   | 20/30 [03:16<01:37,  9.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  70%|███████   | 21/30 [03:25<01:27,  9.72s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  73%|███████▎  | 22/30 [03:35<01:18,  9.79s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  77%|███████▋  | 23/30 [03:45<01:08,  9.81s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  80%|████████  | 24/30 [03:55<00:58,  9.83s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  83%|████████▎ | 25/30 [04:05<00:49,  9.87s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  87%|████████▋ | 26/30 [04:15<00:39,  9.91s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 27/30 [04:25<00:29,  9.88s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 28/30 [04:35<00:19,  9.89s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 29/30 [04:45<00:09,  9.90s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 30/30 [04:55<00:00,  9.83s/it]

# %%
Path("data/results_model_4_rev_3.pkl").write_bytes(pickle.dumps(responses))
# Out:
# 144710
