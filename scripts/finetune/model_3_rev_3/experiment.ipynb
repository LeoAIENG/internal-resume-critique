# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Fri Feb 14 06:26:36 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off | 00000000:0A:00.0 Off |                    0 |
# | N/A   30C    P0              54W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          Off | 00000000:0B:00.0 Off |                    0 |
# | N/A   29C    P0              57W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100-SXM4-80GB          Off | 00000000:0C:00.0 Off |                    0 |
# | N/A   29C    P0              51W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100-SXM4-80GB          Off | 00000000:0D:00.0 Off |                    0 |
# | N/A   29C    P0              49W / 500W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch==2.5.1
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 2.5 MB/s eta 0:00:0000:0100:01
# Collecting torchao==0.6.1
#   Downloading torchao-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 104.3 MB/s eta 0:00:00
# Collecting torchvision==0.20.1
#   Downloading torchvision-0.20.1-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 137.8 MB/s eta 0:00:0000:01
# Collecting torchtune==0.4.0
#   Downloading torchtune-0.4.0-py3-none-any.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.9/686.9 KB 95.3 MB/s eta 0:00:00
# Collecting wandb==0.19.0
#   Downloading wandb-0.19.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 90.0 MB/s eta 0:00:0000:0100:01
# Collecting python-dotenv==1.0.1
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 8.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.6.1.9
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.4 MB/s eta 0:00:0000:0100:01
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 100.4 MB/s eta 0:00:0000:01
# Collecting nvidia-cuda-runtime-cu12==12.4.127
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 88.6 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.4.127
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.8 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 105.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.5.147
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.4.127
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 26.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Collecting fsspec
#   Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 KB 46.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.3.1.170
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 15.3 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.1.0
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 15.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.21.5
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 16.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.5.1->-r requirements.txt (line 1)) (3.0.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.2.1.3
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 14.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.5.1->-r requirements.txt (line 1)) (4.12.2)
# Collecting nvidia-cuda-cupti-cu12==12.4.127
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 144.9 MB/s eta 0:00:0000:0100:01
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 155.6 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 128.7 MB/s eta 0:00:0000:0100:01
# Collecting safetensors
#   Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 KB 79.6 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 21.2 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 111.9 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 108.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 KB 80.2 MB/s eta 0:00:00
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 KB 74.6 MB/s eta 0:00:00
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /home/ubuntu/.local/lib/python3.10/site-packages (from torchtune==0.4.0->-r requirements.txt (line 4)) (7.0.0)
# Collecting blobfile>=2
#   Downloading blobfile-3.0.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 KB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (59.6.0)
# Requirement already satisfied: platformdirs in /home/ubuntu/.local/lib/python3.10/site-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (4.3.6)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (2.25.1)
# Collecting sentry-sdk>=2.0.0
#   Downloading sentry_sdk-2.21.0-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.1/324.1 KB 67.1 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 KB 61.9 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (5.4.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/lib/python3/dist-packages (from wandb==0.19.0->-r requirements.txt (line 5)) (8.0.3)
# Collecting pydantic<3,>=2.6
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 KB 74.4 MB/s eta 0:00:00
# Collecting gitpython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 KB 49.0 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.25.3 in /usr/lib/python3/dist-packages (from blobfile>=2->torchtune==0.4.0->-r requirements.txt (line 4)) (1.26.5)
# Collecting pycryptodomex>=3.8
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 130.8 MB/s eta 0:00:00
# Collecting lxml>=4.9
#   Downloading lxml-5.3.1-cp310-cp310-manylinux_2_28_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 157.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.0->-r requirements.txt (line 5)) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 18.0 MB/s eta 0:00:00
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 121.8 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk>=2.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (2020.6.20)
# Collecting urllib3<3,>=1.25.3
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 KB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (24.2)
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 KB 48.6 MB/s eta 0:00:00
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 KB 30.9 MB/s eta 0:00:00
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-19.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 57.7 MB/s eta 0:00:0000:0100:01
# Collecting requests<3,>=2.0.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 16.9 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.11.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 122.5 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 149.8 MB/s eta 0:00:0000:0100:01
# Collecting fsspec[http]<=2024.9.0,>=2023.1.0
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 KB 46.3 MB/s eta 0:00:00
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 KB 36.5 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 KB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.0.0->wandb==0.19.0->-r requirements.txt (line 5)) (3.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 32.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting regex>=2022.1.18
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 17.1 MB/s eta 0:00:0000:01
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 KB 2.7 MB/s eta 0:00:0000:01
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 KB 64.2 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 KB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (21.2.0)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.18.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 KB 55.9 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pandas->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 KB 65.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets->torchtune==0.4.0->-r requirements.txt (line 4)) (2022.1)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=dc283f53500226cd822ed766156239e98d70ff9479cdd3fc8b45d55c08d5d4ae
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: torchao, sentencepiece, mpmath, antlr4-python3-runtime, xxhash, urllib3, tzdata, tqdm, sympy, smmap, setproctitle, safetensors, regex, python-dotenv, pydantic-core, pycryptodomex, pyarrow, protobuf, propcache, pillow, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, multidict, lxml, fsspec, frozenlist, filelock, docker-pycreds, dill, charset-normalizer, async-timeout, annotated-types, aiohappyeyeballs, yarl, triton, sentry-sdk, requests, pydantic, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, gitdb, blobfile, aiosignal, tiktoken, nvidia-cusolver-cu12, huggingface-hub, gitpython, aiohttp, wandb, torch, torchvision, datasets, torchtune
# Successfully installed aiohappyeyeballs-2.4.6 aiohttp-3.11.12 aiosignal-1.3.2 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 async-timeout-5.0.1 blobfile-3.0.0 charset-normalizer-3.4.1 datasets-3.2.0 dill-0.3.8 docker-pycreds-0.4.0 filelock-3.17.0 frozenlist-1.5.0 fsspec-2024.9.0 gitdb-4.0.12 gitpython-3.1.44 huggingface-hub-0.28.1 lxml-5.3.1 mpmath-1.3.0 multidict-6.1.0 multiprocess-0.70.16 networkx-3.4.2 numpy-2.2.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 omegaconf-2.3.0 pandas-2.2.3 pillow-11.1.0 propcache-0.2.1 protobuf-5.29.3 pyarrow-19.0.0 pycryptodomex-3.21.0 pydantic-2.10.6 pydantic-core-2.27.2 python-dotenv-1.0.1 regex-2024.11.6 requests-2.32.3 safetensors-0.5.2 sentencepiece-0.2.0 sentry-sdk-2.21.0 setproctitle-1.3.4 smmap-5.0.2 sympy-1.13.1 tiktoken-0.9.0 torch-2.5.1 torchao-0.6.1 torchtune-0.4.0 torchvision-0.20.1 tqdm-4.67.1 triton-3.1.0 tzdata-2025.1 urllib3-2.3.0 wandb-0.19.0 xxhash-3.5.0 yarl-1.18.3

# %%
from IPython import get_ipython
from IPython.core.magic import register_cell_magic

ipython = get_ipython()
@register_cell_magic
def pybash(line, cell):
    ipython.run_cell_magic('bash', '', cell.format(**globals()))

# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# ## Configuration

# %%
import os

# %%
## CONFIG
NUM_GPUS = 4
HF_TOKEN = os.environ["HF_TOKEN_R"]
IGNORE_PATTERNS = "original/consolidated*"
CONFIG_FILE = "llama_3_1_8b_lora_distributed.yaml"

## MODEL
ORGANIZATION = "multimodalai"
BASE_MODEL_HF_ID = "meta-llama/Llama-3.1-8B"
CLIENT = "resume-critique"
MODEL = "llama3_1_8b"
MODEL_NUMBER = "3"
REV_N = "3"
FT_METHOD = "tt_lora"
MODEL_TYPE = "adapter"

## DATA
DATA_SIZE = "2k"
TRAINING_DATA = "resume_critique_model_3_v2.jsonl"

MDATA_ID = f"model_{MODEL_NUMBER}_{DATA_SIZE}"
REV = f"rev_{REV_N}"
FT_MODEL_NAME = f"{CLIENT}-{MODEL}-{FT_METHOD}-{MDATA_ID}-{MODEL_TYPE}-{REV}"
FT_MODEL_HF_ID = f"multimodalai/{FT_MODEL_NAME}"

## PATH
BASE_MODEL_PATH = "base_model/"
TOKENIZER_PATH = f"{BASE_MODEL_PATH}/original/tokenizer.model"
OUTPUT_MODEL_PATH = f"checkpoint/{ORGANIZATION}/{FT_MODEL_NAME}"
TRAINING_DATA_PATH = f"data/{TRAINING_DATA}"
CONFIG_FILE_PATH = f"config/{CONFIG_FILE}"

## TRACKING
WANDB_GROUP_NAME = CLIENT
RUN_WANDB_NAME = f"run-{FT_MODEL_NAME}"
LOGS_PATH = "logs/"

# %%
# !mkdir -p {OUTPUT_MODEL_PATH}
# !mkdir -p {LOGS_PATH}

# %% [markdown]
# ## Download Base Model

# %%
# %%pybash
# tune download {BASE_MODEL_HF_ID} --output-dir {BASE_MODEL_PATH} --ignore-patterns {IGNORE_PATTERNS} --hf-token {HF_TOKEN}
# Out:
# Ignoring files matching the following patterns: original/consolidated*
# Fetching 16 files: 100%|██████████| 16/16 [01:58<00:00,  7.41s/it]
# Successfully downloaded model repo and wrote to the following locations:
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/special_tokens_map.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/.gitattributes
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/tokenizer.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/LICENSE
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/model.safetensors.index.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/tokenizer_config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/model-00004-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/README.md
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/original
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/USE_POLICY.md
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/generation_config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/config.json
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/model-00003-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/.cache
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/model-00001-of-00004.safetensors
# /home/ubuntu/internal-foundry-fine-tune/resume-critique/model_3_rev_3/base_model/model-00002-of-00004.safetensors

# %% [markdown]
# ## Fine-Tune

# %%
# %%pybash
# tune run \
#     --nproc_per_node {NUM_GPUS} \
#     lora_finetune_distributed \
#     --config {CONFIG_FILE_PATH} \
#     tokenizer.path={TOKENIZER_PATH} \
#     checkpointer.checkpoint_dir={BASE_MODEL_PATH} \
#     checkpointer.output_dir={OUTPUT_MODEL_PATH} \
#     dataset.data_files={TRAINING_DATA_PATH} \
#     metric_logger.group={WANDB_GROUP_NAME} \
#     metric_logger.name={RUN_WANDB_NAME} \
# 	output_dir={OUTPUT_MODEL_PATH} \
# 	metric_logger.log_dir={LOGS_PATH}
# Out:
# Running with torchrun...
# W0214 06:30:45.825000 9921 torch/distributed/run.py:793]
# W0214 06:30:45.825000 9921 torch/distributed/run.py:793] *****************************************
# W0214 06:30:45.825000 9921 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0214 06:30:45.825000 9921 torch/distributed/run.py:793] *****************************************
# INFO:torchtune.utils._logging:Running LoRAFinetuneRecipeDistributed with resolved config:
#
# batch_size: 8
# checkpointer:
#   _component_: torchtune.training.FullModelHFCheckpointer
#   checkpoint_dir: base_model/
#   checkpoint_files:
#   - model-00001-of-00004.safetensors
#   - model-00002-of-00004.safetensors
#   - model-00003-of-00004.safetensors
#   - model-00004-of-00004.safetensors
#   model_type: LLAMA3
#   output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
#   recipe_checkpoint: null
# compile: false
# dataset:
#   _component_: torchtune.datasets.alpaca_dataset
#   data_files: data/resume_critique_model_3_v2.jsonl
#   packed: false
#   source: json
# device: cuda
# dtype: bf16
# enable_activation_checkpointing: true
# enable_activation_offloading: false
# epochs: 3
# gradient_accumulation_steps: 4
# log_every_n_steps: 1
# log_peak_memory_stats: true
# loss:
#   _component_: torchtune.modules.loss.CEWithChunkedOutputLoss
# lr_scheduler:
#   _component_: torchtune.training.lr_schedulers.get_cosine_schedule_with_warmup
#   num_warmup_steps: 30
# max_steps_per_epoch: null
# metric_logger:
#   _component_: torchtune.training.metric_logging.WandBLogger
#   group: resume-critique
#   log_dir: logs/
#   name: run-resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
# model:
#   _component_: torchtune.models.llama3_1.lora_llama3_1_8b
#   apply_lora_to_mlp: true
#   apply_lora_to_output: true
#   lora_alpha: 16
#   lora_attn_modules:
#   - q_proj
#   - k_proj
#   - v_proj
#   lora_dropout: 0.05
#   lora_rank: 8
# optimizer:
#   _component_: torch.optim.AdamW
#   fused: true
#   lr: 0.0003
#   weight_decay: 0.01
# output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
# profiler:
#   _component_: torchtune.training.setup_torch_profiler
#   active_steps: 2
#   cpu: true
#   cuda: true
#   enabled: false
#   num_cycles: 1
#   output_dir: checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/profiling_outputs
#   profile_memory: false
#   record_shapes: true
#   wait_steps: 5
#   warmup_steps: 3
#   with_flops: false
#   with_stack: false
# resume_from_checkpoint: false
# save_adapter_weights_only: false
# seed: 42
# shuffle: true
# tokenizer:
#   _component_: torchtune.models.llama3.llama3_tokenizer
#   max_seq_len: 4096
#   path: base_model//original/tokenizer.model
#
# DEBUG:torchtune.utils._logging:Setting manual seed to local seed 42. Local seed is seed + rank = 42 + 0
# INFO:torchtune.utils._logging:Hint: enable_activation_checkpointing is True, but enable_activation_offloading isn't. Enabling activation offloading should reduce memory further.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: leonardo-mm (multimodalcompany). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.0
# wandb: Run data is saved locally in logs/wandb/run-20250214_063050-8rwofot5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run run-resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
# wandb: ⭐️ View project at https://wandb.ai/multimodalcompany/torchtune
# wandb: 🚀 View run at https://wandb.ai/multimodalcompany/torchtune/runs/8rwofot5
# INFO:torchtune.utils._logging:Logging base_model/torchtune_config.yaml to W&B under Files
# INFO:torchtune.utils._logging:FSDP is enabled. Instantiating model and loading checkpoint on Rank 0 ...
# INFO:torchtune.utils._logging:Instantiating model and loading checkpoint took 6.59 secs
# INFO:torchtune.utils._logging:Memory stats after model init:
# 	GPU peak memory allocation: 4.76 GiB
# 	GPU peak memory reserved: 4.86 GiB
# 	GPU peak memory active: 4.76 GiB
# INFO:torchtune.utils._logging:Optimizer is initialized.
# INFO:torchtune.utils._logging:Loss is initialized.
# Generating train split: 1868 examples [00:00, 15174.24 examples/s]
# INFO:torchtune.utils._logging:Dataset and Sampler are initialized.
# INFO:torchtune.utils._logging:Learning rate scheduler is initialized.
# WARNING:torchtune.utils._logging: Profiling disabled.
# INFO:torchtune.utils._logging: Profiler config after instantiation: {'enabled': False}
# 1|14|Loss: 2.2967488765716553: 100%|██████████| 14/14 [07:46<00:00, 33.61s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 10.80 secs
# INFO:torchtune.utils._logging:Retrieving optimizer state dict...
# INFO:torchtune.utils._logging:Getting optimizer state dict took 11.03 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0001_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0002_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0003_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0004_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.08 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/recipe_state.pt
# INFO:torchtune.utils._logging:Saving checkpoint took 28.79 secs
#
# 1|14|Loss: 2.2967488765716553: 100%|██████████| 14/14 [08:40<00:00, 37.21s/it]
#
#   7%|▋         | 1/14 [00:36<07:51, 36.29s/it]
# 2|15|Loss: 2.21815824508667:   7%|▋         | 1/14 [00:36<07:51, 36.29s/it]
# 2|15|Loss: 2.21815824508667:  14%|█▍        | 2/14 [01:05<06:23, 31.96s/it]
# 2|16|Loss: 2.1570348739624023:  14%|█▍        | 2/14 [01:05<06:23, 31.96s/it]
# 2|16|Loss: 2.1570348739624023:  21%|██▏       | 3/14 [01:42<06:18, 34.42s/it]
# 2|17|Loss: 2.1218574047088623:  21%|██▏       | 3/14 [01:42<06:18, 34.42s/it]
# 2|17|Loss: 2.1218574047088623:  29%|██▊       | 4/14 [02:17<05:45, 34.59s/it]
# 2|18|Loss: 2.1591365337371826:  29%|██▊       | 4/14 [02:17<05:45, 34.59s/it]
# 2|18|Loss: 2.1591365337371826:  36%|███▌      | 5/14 [02:47<04:55, 32.84s/it]
# 2|19|Loss: 2.1079070568084717:  36%|███▌      | 5/14 [02:47<04:55, 32.84s/it]
# 2|19|Loss: 2.1079070568084717:  43%|████▎     | 6/14 [03:26<04:39, 34.95s/it]
# 2|20|Loss: 2.045311212539673:  43%|████▎     | 6/14 [03:26<04:39, 34.95s/it]
# 2|20|Loss: 2.045311212539673:  50%|█████     | 7/14 [04:05<04:14, 36.36s/it]
# 2|21|Loss: 2.1422834396362305:  50%|█████     | 7/14 [04:05<04:14, 36.36s/it]
# 2|21|Loss: 2.1422834396362305:  57%|█████▋    | 8/14 [04:37<03:30, 35.13s/it]
# 2|22|Loss: 2.0810821056365967:  57%|█████▋    | 8/14 [04:37<03:30, 35.13s/it]
# 2|22|Loss: 2.0810821056365967:  64%|██████▍   | 9/14 [05:12<02:55, 35.08s/it]
# 2|23|Loss: 2.000671863555908:  64%|██████▍   | 9/14 [05:12<02:55, 35.08s/it]
# 2|23|Loss: 2.000671863555908:  71%|███████▏  | 10/14 [05:47<02:19, 34.80s/it]
# 2|24|Loss: 2.089876890182495:  71%|███████▏  | 10/14 [05:47<02:19, 34.80s/it]
# 2|24|Loss: 2.089876890182495:  79%|███████▊  | 11/14 [06:15<01:38, 32.83s/it]
# 2|25|Loss: 2.0572879314422607:  79%|███████▊  | 11/14 [06:15<01:38, 32.83s/it]
# 2|25|Loss: 2.0572879314422607:  86%|████████▌ | 12/14 [06:49<01:06, 33.33s/it]
# 2|26|Loss: 2.0459742546081543:  86%|████████▌ | 12/14 [06:49<01:06, 33.33s/it]
# 2|26|Loss: 2.0459742546081543:  93%|█████████▎| 13/14 [07:26<00:34, 34.23s/it]
# 2|27|Loss: 2.089535713195801:  93%|█████████▎| 13/14 [07:26<00:34, 34.23s/it]
# 2|27|Loss: 2.089535713195801: 100%|██████████| 14/14 [07:59<00:00, 33.88s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 10.54 secs
# INFO:torchtune.utils._logging:Retrieving optimizer state dict...
# INFO:torchtune.utils._logging:Getting optimizer state dict took 10.76 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0001_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0002_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0003_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0004_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.08 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/recipe_state.pt
# INFO:torchtune.utils._logging:Saving checkpoint took 28.83 secs
# 2|28|Loss: 2.053286552429199: 100%|██████████| 14/14 [08:53<00:00, 38.10s/it]
# 3|42|Loss: 1.9899321794509888: 100%|██████████| 14/14 [07:49<00:00, 32.97s/it]INFO:torchtune.utils._logging:Saving checkpoint. This may take some time. Retrieving full model state dict...
# INFO:torchtune.utils._logging:Getting full model state dict took 10.56 secs
# INFO:torchtune.utils._logging:Model checkpoint of size 4.98 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0001_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 5.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0002_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 4.92 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0003_2.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.17 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/hf_model_0004_2.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_2.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.04 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoint/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/adapter_config.json
# INFO:torchtune.utils._logging:Saving final epoch checkpoint.
# INFO:torchtune.utils._logging:The full model checkpoint, including all weights and configurations, has been saved successfully.You can now use this checkpoint for further training or inference.
# INFO:torchtune.utils._logging:Saving checkpoint took 28.30 secs
# 3|42|Loss: 1.9899321794509888: 100%|██████████| 14/14 [08:45<00:00, 37.56s/it]
# wandb:
# wandb:
# wandb: Run history:
# wandb:               global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██
# wandb:                      loss ▇██▇██▇▆▆▆▆▆▅▅▄▄▃▄▃▂▃▂▃▃▂▃▂▂���▂▁▁▂▃▂▂▂▂▁▂
# wandb:                        lr ▁▁▂▂▂▂▃▃▃▃���▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇█████▇▆▅▅▄▃▂▁▁
# wandb:        peak_memory_active █▂▃▅▂█▃█▃▆▄██▆▇▄▂█▃█▄██▃█��▆▅█▁▁████▇▅▆▂█
# wandb:         peak_memory_alloc █▂▃▅▂█▃��▃▆▄██▆▇▄▂█▃█▄██▃█▃▆▅█▁▁████▇▅▆▂█
# wandb:      peak_memory_reserved ▄▄▄▄▄█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: tokens_per_second_per_gpu ▅▆▇▇▇▅▅▅▇▅▆▅▅▆▁█▄▆▇▅▅▅▆█▅▅▆▁▅▅█▆▆▅▅▆▅▆���▆
# wandb:
# wandb: Run summary:
# wandb:               global_step 42
# wandb:                      loss 1.98993
# wandb:                        lr 0
# wandb:        peak_memory_active 40.13208
# wandb:         peak_memory_alloc 40.13208
# wandb:      peak_memory_reserved 52.13672
# wandb: tokens_per_second_per_gpu 1052.00635
# wandb:
# wandb: 🚀 View run run-resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3 at: https://wandb.ai/multimodalcompany/torchtune/runs/8rwofot5
# wandb: ⭐️ View project at: https://wandb.ai/multimodalcompany/torchtune
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb: Find logs at: logs/wandb/run-20250214_063050-8rwofot5/logs

# %% [markdown]
# ## Save Model HF

# %%
HF_TOKEN = os.environ["HF_TOKEN_W"]

# %%
# %%pybash
# huggingface-cli login --token {HF_TOKEN}
# huggingface-cli repo create -y --organization {ORGANIZATION} {FT_MODEL_NAME}
# huggingface-cli upload {FT_MODEL_HF_ID} {OUTPUT_MODEL_PATH}
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `leo-mm-write-token-2` has been saved to /home/ubuntu/.cache/huggingface/stored_tokens
# Your token has been saved to /home/ubuntu/.cache/huggingface/token
# Login successful.
# The current active token is: `leo-mm-write-token-2`
# git version 2.34.1
# Looks like you do not have git-lfs installed, please install. You can install from https://git-lfs.github.com/. Then run `git lfs install` (you only have to do this once).
#
# You are about to create multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
#
# Your repo now lives at:
#   https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Start hashing 19 files.
# Finished hashing 19 files.
# adapter_0.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
# adapter_1.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
# adapter_2.pt:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
#
# adapter_model.bin:   0%|          | 0.00/40.0M [00:00<?, ?B/s]
#
#
#
# hf_model_0001_0.pt:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# adapter_0.pt:  13%|█▎        | 5.18M/40.0M [00:00<00:00, 51.7MB/s][A
# adapter_1.pt:  14%|█▎        | 5.47M/40.0M [00:00<00:00, 54.7MB/s]
#
#
# adapter_model.bin:  15%|█▍        | 5.87M/40.0M [00:00<00:00, 58.6MB/s]
#
#
#
# hf_model_0001_0.pt:   0%|          | 6.24M/4.98G [00:00<01:19, 62.4MB/s]
#
# adapter_0.pt:  40%|████      | 16.0M/40.0M [00:00<00:00, 38.8MB/s]
#
#
# adapter_model.bin:  40%|████      | 16.0M/40.0M [00:00<00:00, 31.0MB/s]
#
# adapter_2.pt:  25%|██▌       | 10.0M/40.0M [00:00<00:01, 17.0MB/s]
#
#
#
# hf_model_0001_0.pt:   0%|          | 16.0M/4.98G [00:00<03:26, 24.0MB/s]
# adapter_0.pt:  80%|████████  | 32.0M/40.0M [00:00<00:00, 44.0MB/s]
#
#
#
# hf_model_0001_0.pt:   1%|          | 30.3M/4.98G [00:00<01:48, 45.4MB/s]
#
# adapter_2.pt:  40%|████      | 16.0M/40.0M [00:01<00:01, 14.2MB/s]
# adapter_1.pt:  80%|████████  | 32.0M/40.0M [00:01<00:00, 28.9MB/s]
#
#
#
# hf_model_0001_0.pt:   1%|          | 37.7M/4.98G [00:01<02:54, 28.3MB/s]
#
#
# adapter_model.bin:  80%|████████  | 32.0M/40.0M [00:01<00:00, 24.2MB/s]
#
# adapter_2.pt:  67%|██████▋   | 27.0M/40.0M [00:01<00:00, 19.8MB/s]
#
# adapter_1.pt: 100%|██████████| 40.0M/40.0M [00:01<00:00, 23.3MB/s]
# adapter_0.pt: 100%|██████████| 40.0M/40.0M [00:01<00:00, 22.7MB/s]
# adapter_model.bin: 100%|██████████| 40.0M/40.0M [00:01<00:00, 21.6MB/s]
#
#
#
#
# hf_model_0001_1.pt:   0%|          | 0.00/4.98G [00:00<?, ?B/s]21.7MB/s]
#
#
#
#
# Upload 17 LFS files:   6%|▌         | 1/17 [00:02<00:32,  2.02s/it]
#
# adapter_2.pt:  80%|████████  | 32.0M/40.0M [00:02<00:00, 12.5MB/s]
# hf_model_0001_2.pt:   0%|          | 14.2M/4.98G [00:00<00:36, 136MB/s]
#
#
# hf_model_0002_0.pt:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# adapter_2.pt: 100%|██████████| 40.0M/40.0M [00:02<00:00, 16.9MB/s]0MB/s]
# hf_model_0001_1.pt:   0%|          | 16.0M/4.98G [00:00<02:52, 28.8MB/s]
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 80.0M/4.98G [00:02<02:22, 34.5MB/s]
#
#
#
#
# Upload 17 LFS files:  18%|█▊        | 3/17 [00:02<00:10,  1.32it/s]
#
# hf_model_0002_1.pt:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
#
#
# hf_model_0002_0.pt:   0%|          | 16.0M/5.00G [00:00<03:03, 27.1MB/s]
#
# hf_model_0002_1.pt:   0%|          | 10.6M/5.00G [00:00<00:46, 106MB/s]
# hf_model_0001_2.pt:   1%|          | 27.8M/4.98G [00:00<02:33, 32.3MB/s]
#
#
#
# hf_model_0001_1.pt:   1%|          | 41.3M/4.98G [00:01<01:52, 43.8MB/s]
#
#
# hf_model_0002_0.pt:   1%|          | 32.0M/5.00G [00:01<02:55, 28.3MB/s]
# hf_model_0001_1.pt:   1%|          | 46.7M/4.98G [00:01<02:46, 29.6MB/s]
#
#
#
# hf_model_0001_0.pt:   2%|▏         | 112M/4.98G [00:03<02:21, 34.5MB/s]
# hf_model_0001_2.pt:   1%|          | 48.0M/4.98G [00:01<02:57, 27.7MB/s]
#
# hf_model_0002_1.pt:   0%|          | 21.3M/5.00G [00:01<04:39, 17.8MB/s]
#
#
# hf_model_0001_1.pt:   1%|          | 50.6M/4.98G [00:01<04:00, 20.5MB/s]
#
#
#
# hf_model_0001_0.pt:   3%|▎         | 128M/4.98G [00:03<02:16, 35.5MB/s]
#
# hf_model_0002_1.pt:   1%|          | 32.0M/5.00G [00:01<03:28, 23.9MB/s]
# hf_model_0001_1.pt:   1%|▏         | 64.0M/4.98G [00:02<03:03, 26.8MB/s]
#
#
#
# hf_model_0001_0.pt:   3%|▎         | 144M/4.98G [00:04<02:05, 38.5MB/s]
#
# hf_model_0002_1.pt:   1%|          | 42.6M/5.00G [00:01<03:07, 26.5MB/s]
# hf_model_0001_2.pt:   2%|▏         | 80.0M/4.98G [00:02<02:17, 35.6MB/s]
#
# hf_model_0002_1.pt:   1%|          | 46.7M/5.00G [00:01<03:15, 25.4MB/s]
#
#
#
# hf_model_0001_1.pt:   2%|▏         | 80.0M/4.98G [00:02<02:57, 27.5MB/s][A
# hf_model_0001_2.pt:   2%|▏         | 96.0M/4.98G [00:02<02:03, 39.4MB/s]
#
# hf_model_0002_1.pt:   1%|          | 50.0M/5.00G [00:02<04:30, 18.3MB/s]
#
#
# hf_model_0001_1.pt:   2%|▏         | 96.0M/4.98G [00:03<02:26, 33.2MB/s]
# hf_model_0001_2.pt:   2%|▏         | 112M/4.98G [00:03<02:00, 40.3MB/s]
#
#
#
# hf_model_0001_0.pt:   4%|▎         | 176M/4.98G [00:05<02:15, 35.3MB/s]
#
#
# hf_model_0002_0.pt:   2%|▏         | 80.0M/5.00G [00:03<03:19, 24.7MB/s]
# hf_model_0001_1.pt:   2%|▏         | 112M/4.98G [00:03<02:34, 31.4MB/s] [A
#
# hf_model_0002_1.pt:   1%|▏         | 64.0M/5.00G [00:02<04:19, 19.0MB/s]
#
#
# hf_model_0002_0.pt:   2%|▏         | 96.0M/5.00G [00:03<02:47, 29.4MB/s]
#
#
#
# hf_model_0001_0.pt:   4%|▍         | 192M/4.98G [00:05<02:27, 32.5MB/s]
# hf_model_0001_2.pt:   3%|▎         | 144M/4.98G [00:03<01:48, 44.7MB/s]
#
#
#
# hf_model_0001_1.pt:   3%|▎         | 128M/4.98G [00:03<02:13, 36.2MB/s]
#
# hf_model_0002_1.pt:   2%|▏         | 80.0M/5.00G [00:03<03:10, 25.8MB/s]
# hf_model_0001_2.pt:   3%|▎         | 160M/4.98G [00:04<01:44, 46.0MB/s]
#
#
#
# hf_model_0001_1.pt:   3%|▎         | 144M/4.98G [00:04<01:59, 40.4MB/s]
#
# hf_model_0002_1.pt:   2%|▏         | 96.0M/5.00G [00:03<02:32, 32.1MB/s]
#
#
#
# hf_model_0001_0.pt:   4%|▍         | 207M/4.98G [00:06<02:45, 28.9MB/s]
#
#
# hf_model_0001_1.pt:   3%|▎         | 160M/4.98G [00:04<01:53, 42.4MB/s]
# hf_model_0001_2.pt:   4%|▎         | 176M/4.98G [00:04<02:11, 36.4MB/s]
#
#
#
# hf_model_0001_0.pt:   4%|▍         | 211M/4.98G [00:06<03:51, 20.6MB/s]
#
#
# hf_model_0002_0.pt:   3%|▎         | 128M/5.00G [00:04<02:37, 30.9MB/s]
# hf_model_0001_1.pt:   4%|▎         | 176M/4.98G [00:05<02:00, 39.9MB/s]
# hf_model_0001_2.pt:   4%|▍         | 190M/4.98G [00:05<02:07, 37.5MB/s]
#
#
#
# hf_model_0001_0.pt:   5%|▍         | 224M/4.98G [00:07<02:59, 26.5MB/s]
#
#
# hf_model_0002_0.pt:   3%|▎         | 144M/5.00G [00:04<02:18, 35.0MB/s]
#
# hf_model_0002_1.pt:   2%|▏         | 112M/5.00G [00:04<03:30, 23.2MB/s]
#
#
#
# hf_model_0001_0.pt:   5%|▍         | 240M/4.98G [00:07<02:20, 33.8MB/s]
# hf_model_0001_2.pt:   4%|▍         | 195M/4.98G [00:05<02:59, 26.6MB/s]
#
# hf_model_0002_1.pt:   3%|▎         | 128M/5.00G [00:04<02:51, 28.4MB/s]
#
#
# hf_model_0002_0.pt:   3%|▎         | 160M/5.00G [00:05<02:29, 32.3MB/s]
#
#
#
# hf_model_0001_0.pt:   5%|▌         | 256M/4.98G [00:07<02:00, 39.1MB/s]
# hf_model_0001_1.pt:   4%|▍         | 192M/4.98G [00:05<02:45, 29.0MB/s]
# hf_model_0001_1.pt:   4%|▍         | 208M/4.98G [00:06<02:25, 32.8MB/s]
#
#
# hf_model_0002_0.pt:   4%|▎         | 176M/5.00G [00:06<02:35, 31.0MB/s]
#
#
#
# hf_model_0001_0.pt:   5%|▌         | 272M/4.98G [00:08<02:18, 33.9MB/s]
#
# hf_model_0002_1.pt:   3%|▎         | 144M/5.00G [00:05<03:14, 25.0MB/s]
#
#
# hf_model_0002_0.pt:   4%|▍         | 192M/5.00G [00:06<02:11, 36.5MB/s]
# hf_model_0001_2.pt:   5%|▍         | 240M/4.98G [00:06<01:59, 39.6MB/s]
#
# hf_model_0001_1.pt:   5%|▍         | 224M/4.98G [00:06<02:11, 36.2MB/s]
#
#
#
# hf_model_0001_0.pt:   6%|▌         | 288M/4.98G [00:08<02:01, 38.7MB/s]
# hf_model_0001_2.pt:   5%|▌         | 256M/4.98G [00:06<01:50, 42.6MB/s]
#
#
# hf_model_0002_0.pt:   4%|▍         | 208M/5.00G [00:06<02:01, 39.6MB/s]
#
# hf_model_0001_1.pt:   5%|▍         | 240M/4.98G [00:06<01:59, 39.5MB/s]
#
#
#
# hf_model_0001_0.pt:   6%|▌         | 304M/4.98G [00:08<01:53, 41.3MB/s]
# hf_model_0001_1.pt:   5%|▌         | 256M/4.98G [00:07<01:49, 42.9MB/s]
#
#
#
# hf_model_0001_0.pt:   6%|▋         | 320M/4.98G [00:09<01:47, 43.4MB/s]
#
#
# hf_model_0002_0.pt:   4%|▍         | 224M/5.00G [00:07<02:08, 37.1MB/s]
#
# hf_model_0002_1.pt:   3%|▎         | 161M/5.00G [00:06<04:11, 19.3MB/s]
# hf_model_0001_2.pt:   6%|▌         | 288M/4.98G [00:07<01:41, 46.4MB/s]
#
#
#
# hf_model_0001_1.pt:   5%|▌         | 272M/4.98G [00:07<01:52, 41.8MB/s]
#
#
# hf_model_0002_0.pt:   5%|▍         | 240M/5.00G [00:07<01:57, 40.6MB/s]
#
#
#
# hf_model_0001_0.pt:   7%|▋         | 352M/4.98G [00:09<01:40, 46.2MB/s]
#
#
# hf_model_0002_0.pt:   5%|▌         | 256M/5.00G [00:07<01:45, 45.0MB/s]
#
# hf_model_0001_1.pt:   6%|▌         | 288M/4.98G [00:08<02:06, 37.0MB/s]
#
#
#
# hf_model_0001_0.pt:   7%|▋         | 368M/4.98G [00:10<01:34, 48.9MB/s]
#
# hf_model_0002_1.pt:   4%|▍         | 192M/5.00G [00:07<02:52, 27.9MB/s]
#
#
# hf_model_0001_1.pt:   6%|▌         | 304M/4.98G [00:08<01:56, 40.0MB/s]
#
#
#
# hf_model_0001_0.pt:   8%|▊         | 384M/4.98G [00:10<01:33, 49.4MB/s]
#
# hf_model_0002_1.pt:   4%|▍         | 208M/5.00G [00:07<02:23, 33.4MB/s]
#
#
# hf_model_0001_1.pt:   6%|▋         | 320M/4.98G [00:08<01:49, 42.7MB/s]
#
#
#
# hf_model_0001_0.pt:   8%|▊         | 400M/4.98G [00:10<01:31, 50.3MB/s]
#
#
# hf_model_0002_0.pt:   6%|▌         | 304M/5.00G [00:08<01:42, 45.6MB/s]
#
#
#
# hf_model_0001_1.pt:   7%|▋         | 336M/4.98G [00:09<01:43, 44.9MB/s]
#
# hf_model_0002_1.pt:   4%|▍         | 224M/5.00G [00:08<02:38, 30.1MB/s]
#
#
# hf_model_0001_1.pt:   7%|▋         | 352M/4.98G [00:09<01:40, 46.1MB/s]
#
#
#
# hf_model_0001_0.pt:   9%|▊         | 432M/4.98G [00:11<01:34, 48.2MB/s]
#
# hf_model_0002_1.pt:   5%|▍         | 240M/5.00G [00:08<02:20, 33.8MB/s]
#
#
# hf_model_0002_0.pt:   7%|▋         | 336M/5.00G [00:09<01:37, 47.6MB/s]
#
#
#
# hf_model_0001_0.pt:   9%|▉         | 448M/4.98G [00:11<01:27, 51.8MB/s]
# hf_model_0001_2.pt:   6%|▌         | 304M/4.98G [00:09<04:48, 16.2MB/s]
#
#
# hf_model_0002_0.pt:   7%|▋         | 352M/5.00G [00:09<01:33, 49.9MB/s]
#
# hf_model_0002_1.pt:   5%|▌         | 256M/5.00G [00:09<02:14, 35.4MB/s]
#
#
#
# hf_model_0001_1.pt:   7%|▋         | 368M/4.98G [00:10<02:09, 35.6MB/s]
# hf_model_0001_2.pt:   6%|▋         | 320M/4.98G [00:10<03:44, 20.8MB/s]
#
#
# hf_model_0002_0.pt:   7%|▋         | 368M/5.00G [00:10<01:33, 49.3MB/s]
#
# hf_model_0002_1.pt:   5%|▌         | 272M/5.00G [00:09<02:01, 38.8MB/s]
#
#
#
# hf_model_0001_1.pt:   8%|▊         | 384M/4.98G [00:10<01:59, 38.5MB/s]
# hf_model_0001_2.pt:   7%|▋         | 336M/4.98G [00:10<03:03, 25.3MB/s]
#
#
# hf_model_0002_0.pt:   8%|▊         | 384M/5.00G [00:10<01:33, 49.3MB/s]
#
# hf_model_0002_1.pt:   6%|▌         | 288M/5.00G [00:09<01:51, 42.1MB/s]
#
#
#
# hf_model_0001_1.pt:   8%|▊         | 400M/4.98G [00:10<01:48, 42.1MB/s]
#
#
# hf_model_0002_0.pt:   8%|▊         | 400M/5.00G [00:10<01:34, 48.6MB/s]
#
# hf_model_0002_1.pt:   6%|▌         | 304M/5.00G [00:10<01:45, 44.5MB/s]
#
#
#
# hf_model_0001_1.pt:   8%|▊         | 416M/4.98G [00:11<01:44, 43.5MB/s]
# hf_model_0001_2.pt:   7%|▋         | 352M/4.98G [00:11<03:08, 24.5MB/s]
#
#
# hf_model_0002_0.pt:   8%|▊         | 416M/5.00G [00:11<01:34, 48.5MB/s]
#
#
#
# hf_model_0001_0.pt:  11%|█         | 528M/4.98G [00:13<01:30, 49.0MB/s]
#
#
# hf_model_0002_0.pt:   9%|▊         | 432M/5.00G [00:11<01:28, 51.7MB/s]
# hf_model_0001_1.pt:   9%|▊         | 432M/4.98G [00:11<01:57, 38.8MB/s]
#
# hf_model_0002_1.pt:   6%|▋         | 320M/5.00G [00:11<02:18, 33.9MB/s]
#
#
#
# hf_model_0001_0.pt:  11%|█         | 544M/4.98G [00:13<01:31, 48.6MB/s]
#
#
# hf_model_0002_0.pt:   9%|▉         | 448M/5.00G [00:11<01:29, 50.6MB/s]
# hf_model_0001_1.pt:   9%|▉         | 448M/4.98G [00:12<01:52, 40.4MB/s]
#
# hf_model_0002_1.pt:   7%|▋         | 336M/5.00G [00:11<02:10, 35.9MB/s]
#
#
#
# hf_model_0001_1.pt:   9%|▉         | 464M/4.98G [00:12<01:44, 43.3MB/s]
#
#
# hf_model_0002_0.pt:   9%|▉         | 464M/5.00G [00:12<01:40, 45.0MB/s]
# hf_model_0001_2.pt:   8%|▊         | 400M/4.98G [00:12<02:22, 32.1MB/s]
#
#
#
# hf_model_0001_1.pt:  10%|▉         | 480M/4.98G [00:12<01:39, 45.3MB/s]
#
#
# hf_model_0002_0.pt:  10%|▉         | 480M/5.00G [00:12<01:40, 44.9MB/s]
# hf_model_0001_2.pt:   8%|▊         | 416M/4.98G [00:12<02:05, 36.2MB/s]
#
#
#
# hf_model_0001_0.pt:  12%|█▏        | 592M/4.98G [00:14<01:28, 49.5MB/s]
#
#
# hf_model_0001_1.pt:  10%|▉         | 496M/4.98G [00:13<01:40, 44.6MB/s]
# hf_model_0001_2.pt:   9%|▊         | 432M/4.98G [00:12<01:52, 40.6MB/s]
#
#
#
# hf_model_0001_1.pt:  10%|█         | 512M/4.98G [00:13<01:35, 46.6MB/s]
#
#
# hf_model_0002_0.pt:  10%|█         | 512M/5.00G [00:13<01:36, 46.3MB/s]
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 624M/4.98G [00:15<01:26, 50.1MB/s]
# hf_model_0001_1.pt:  11%|█         | 528M/4.98G [00:13<01:35, 46.4MB/s]
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 640M/4.98G [00:15<01:36, 45.2MB/s]
# hf_model_0001_1.pt:  11%|█         | 544M/4.98G [00:13<01:32, 47.9MB/s]
#
# hf_model_0002_1.pt:   7%|▋         | 352M/5.00G [00:13<04:28, 17.3MB/s]
#
#
#
# hf_model_0001_0.pt:  13%|█▎        | 656M/4.98G [00:16<01:32, 46.6MB/s]
# hf_model_0001_1.pt:  11%|█▏        | 560M/4.98G [00:14<01:31, 48.3MB/s]
#
#
#
# hf_model_0001_0.pt:  14%|█▎        | 672M/4.98G [00:16<01:32, 46.6MB/s]
# hf_model_0001_2.pt:  10%|▉         | 496M/4.98G [00:14<01:41, 44.0MB/s]
#
# hf_model_0001_1.pt:  12%|█▏        | 576M/4.98G [00:14<01:37, 45.3MB/s]
#
#
# hf_model_0002_0.pt:  11%|█         | 528M/5.00G [00:14<03:06, 24.0MB/s]
# hf_model_0001_2.pt:  10%|█         | 512M/4.98G [00:14<01:38, 45.2MB/s]
#
# hf_model_0001_1.pt:  12%|█▏        | 592M/4.98G [00:15<01:38, 44.7MB/s]
#
#
# hf_model_0002_0.pt:  11%|█         | 544M/5.00G [00:14<02:39, 28.0MB/s]
# hf_model_0001_2.pt:  11%|█         | 528M/4.98G [00:15<01:37, 45.7MB/s]
#
#
# hf_model_0001_1.pt:  12%|█▏        | 608M/4.98G [00:15<01:39, 43.7MB/s]
# hf_model_0001_2.pt:  11%|█         | 544M/4.98G [00:15<01:32, 47.8MB/s]
#
#
#
# hf_model_0001_0.pt:  14%|█▍        | 688M/4.98G [00:17<02:32, 28.1MB/s]
#
#
# hf_model_0001_1.pt:  13%|█▎        | 624M/4.98G [00:15<01:35, 45.4MB/s]
# hf_model_0001_2.pt:  11%|█▏        | 560M/4.98G [00:15<01:32, 47.6MB/s]
#
#
#
# hf_model_0001_0.pt:  14%|█▍        | 704M/4.98G [00:17<02:13, 31.9MB/s]
#
#
# hf_model_0001_1.pt:  13%|█▎        | 640M/4.98G [00:16<01:33, 46.4MB/s]
# hf_model_0001_2.pt:  12%|█▏        | 576M/4.98G [00:16<01:34, 46.7MB/s]
#
#
#
# hf_model_0001_1.pt:  13%|█▎        | 656M/4.98G [00:16<01:31, 47.1MB/s]
#
#
# hf_model_0002_0.pt:  12%|█▏        | 608M/5.00G [00:16<01:50, 39.8MB/s]
# hf_model_0001_2.pt:  12%|█▏        | 592M/4.98G [00:16<01:32, 47.6MB/s]
#
#
#
# hf_model_0001_0.pt:  15%|█▍        | 736M/4.98G [00:18<02:04, 34.1MB/s]
#
#
# hf_model_0002_0.pt:  12%|█▏        | 624M/5.00G [00:16<02:06, 34.5MB/s]
# hf_model_0001_2.pt:  12%|█▏        | 608M/4.98G [00:16<01:50, 39.4MB/s]
#
#
#
# hf_model_0001_1.pt:  14%|█▎        | 672M/4.98G [00:17<02:07, 33.8MB/s]
#
# hf_model_0002_1.pt:   8%|▊         | 400M/5.00G [00:16<05:36, 13.7MB/s]
# hf_model_0001_2.pt:  13%|█▎        | 624M/4.98G [00:17<01:43, 42.0MB/s]
#
#
# hf_model_0002_0.pt:  13%|█▎        | 640M/5.00G [00:17<01:58, 36.9MB/s]
#
#
#
# hf_model_0001_1.pt:  14%|█▍        | 688M/4.98G [00:17<02:07, 33.5MB/s]
#
#
# hf_model_0002_0.pt:  13%|█▎        | 656M/5.00G [00:17<01:48, 40.0MB/s]
#
#
#
# hf_model_0001_0.pt:  16%|█▌        | 784M/4.98G [00:19<01:38, 42.7MB/s]
# hf_model_0001_2.pt:  13%|█▎        | 640M/4.98G [00:17<01:44, 41.3MB/s]
#
# hf_model_0001_1.pt:  14%|█▍        | 704M/4.98G [00:18<01:56, 36.6MB/s]
#
#
#
# hf_model_0001_0.pt:  16%|█▌        | 800M/4.98G [00:20<01:32, 45.2MB/s]
# hf_model_0001_2.pt:  13%|█▎        | 656M/4.98G [00:18<01:39, 43.6MB/s]
#
# hf_model_0001_1.pt:  14%|█▍        | 720M/4.98G [00:18<01:46, 39.8MB/s]
#
#
#
# hf_model_0001_0.pt:  16%|█▋        | 816M/4.98G [00:20<01:28, 47.2MB/s]
# hf_model_0001_2.pt:  14%|█▎        | 672M/4.98G [00:18<01:33, 45.9MB/s]
#
# hf_model_0002_1.pt:   9%|▉         | 448M/5.00G [00:17<03:05, 24.6MB/s]
#
#
# hf_model_0002_0.pt:  13%|█▎        | 672M/5.00G [00:18<02:26, 29.5MB/s]
#
#
#
# hf_model_0001_1.pt:  15%|█▍        | 736M/4.98G [00:18<01:43, 41.0MB/s]
# hf_model_0001_2.pt:  14%|█▍        | 688M/4.98G [00:18<01:32, 46.5MB/s]
#
#
# hf_model_0001_1.pt:  15%|█▌        | 752M/4.98G [00:19<01:37, 43.4MB/s]
# hf_model_0001_2.pt:  14%|█▍        | 704M/4.98G [00:19<01:31, 46.8MB/s]
#
#
#
#
#
# hf_model_0002_0.pt:  14%|█▍        | 704M/5.00G [00:19<02:01, 35.4MB/s]
#
# hf_model_0002_1.pt:   9%|▉         | 464M/5.00G [00:18<03:13, 23.5MB/s]
# hf_model_0001_1.pt:  15%|█▌        | 768M/4.98G [00:19<01:33, 45.0MB/s]
#
# hf_model_0002_1.pt:  10%|▉         | 480M/5.00G [00:18<02:43, 27.7MB/s]
#
#
# hf_model_0001_1.pt:  16%|█▌        | 784M/4.98G [00:19<01:31, 46.1MB/s]
# hf_model_0001_1.pt:  16%|█▌        | 800M/4.98G [00:20<01:28, 47.4MB/s]
# hf_model_0001_2.pt:  15%|█▌        | 752M/4.98G [00:19<01:26, 48.9MB/s]
#
# hf_model_0002_1.pt:  10%|▉         | 496M/5.00G [00:19<02:37, 28.7MB/s]
#
#
#
# hf_model_0001_1.pt:  16%|█▋        | 816M/4.98G [00:20<01:27, 47.7MB/s]
# hf_model_0001_2.pt:  15%|█▌        | 768M/4.98G [00:20<01:25, 48.9MB/s]
#
#
# hf_model_0002_0.pt:  15%|█▍        | 736M/5.00G [00:20<02:22, 30.0MB/s]
#
# hf_model_0002_1.pt:  10%|█         | 512M/5.00G [00:19<02:21, 31.8MB/s]
#
#
#
# hf_model_0001_1.pt:  17%|█▋        | 832M/4.98G [00:20<01:25, 48.5MB/s]
# hf_model_0001_2.pt:  16%|█▌        | 784M/4.98G [00:20<01:26, 48.6MB/s]
#
#
# hf_model_0002_0.pt:  15%|█▌        | 752M/5.00G [00:20<02:05, 33.9MB/s]
#
# hf_model_0002_1.pt:  11%|█         | 528M/5.00G [00:20<02:02, 36.4MB/s]
#
#
#
# hf_model_0001_1.pt:  17%|█▋        | 848M/4.98G [00:20<01:23, 49.6MB/s]
#
#
# hf_model_0002_0.pt:  15%|█▌        | 768M/5.00G [00:20<01:53, 37.4MB/s]
#
# hf_model_0002_1.pt:  11%|█         | 544M/5.00G [00:20<01:54, 39.0MB/s]
#
#
#
# hf_model_0001_0.pt:  18%|█▊        | 912M/4.98G [00:23<01:44, 38.9MB/s]
#
#
# hf_model_0002_0.pt:  16%|█▌        | 784M/5.00G [00:21<01:41, 41.6MB/s]
#
# hf_model_0002_1.pt:  11%|█         | 560M/5.00G [00:20<01:47, 41.3MB/s]
# hf_model_0001_2.pt:  16%|█▌        | 800M/4.98G [00:21<02:05, 33.3MB/s]
#
#
#
# hf_model_0001_1.pt:  17%|█▋        | 864M/4.98G [00:21<01:54, 35.9MB/s]
#
#
# hf_model_0002_0.pt:  16%|█▌        | 800M/5.00G [00:21<01:37, 43.2MB/s]
#
# hf_model_0002_1.pt:  12%|█▏        | 576M/5.00G [00:21<01:40, 43.8MB/s]
#
#
#
# hf_model_0001_1.pt:  18%|█▊        | 880M/4.98G [00:22<01:44, 39.0MB/s]
#
#
# hf_model_0002_0.pt:  16%|█▋        | 816M/5.00G [00:21<01:34, 44.4MB/s]
#
# hf_model_0002_1.pt:  12%|█▏        | 592M/5.00G [00:21<01:35, 46.3MB/s]
#
#
#
# hf_model_0001_0.pt:  19%|█▉        | 960M/4.98G [00:24<01:32, 43.6MB/s]
# hf_model_0001_1.pt:  18%|█▊        | 896M/4.98G [00:22<01:38, 41.6MB/s]
#
#
#
# hf_model_0001_0.pt:  20%|█▉        | 976M/4.98G [00:24<01:26, 46.2MB/s]
#
# hf_model_0001_1.pt:  18%|█▊        | 912M/4.98G [00:22<01:47, 38.0MB/s]
# hf_model_0001_2.pt:  17%|█▋        | 832M/4.98G [00:22<02:28, 28.0MB/s]
#
#
#
# hf_model_0001_0.pt:  20%|█▉        | 992M/4.98G [00:24<01:24, 47.3MB/s]
#
# hf_model_0002_1.pt:  12%|█▏        | 624M/5.00G [00:22<01:40, 43.5MB/s]
#
#
# hf_model_0002_0.pt:  17%|█▋        | 832M/5.00G [00:22<02:19, 29.8MB/s]
#
#
#
# hf_model_0001_0.pt:  20%|██        | 1.01G/4.98G [00:25<01:21, 49.0MB/s]
# hf_model_0001_1.pt:  19%|█▊        | 928M/4.98G [00:23<01:45, 38.5MB/s]
#
# hf_model_0002_1.pt:  13%|█▎        | 640M/5.00G [00:22<01:42, 42.5MB/s]
#
#
# hf_model_0002_0.pt:  17%|█▋        | 848M/5.00G [00:23<02:01, 34.0MB/s]
#
#
#
# hf_model_0001_1.pt:  19%|█▉        | 944M/4.98G [00:23<01:40, 40.2MB/s]]
#
# hf_model_0002_1.pt:  13%|█▎        | 656M/5.00G [00:22<01:38, 44.1MB/s]
#
#
# hf_model_0001_1.pt:  19%|█▉        | 960M/4.98G [00:23<01:34, 42.5MB/s]
#
# hf_model_0002_1.pt:  13%|█▎        | 672M/5.00G [00:23<01:33, 46.2MB/s]
# hf_model_0001_2.pt:  17%|█▋        | 864M/4.98G [00:24<02:40, 25.7MB/s]
#
#
# hf_model_0002_0.pt:  18%|█▊        | 880M/5.00G [00:23<01:51, 37.0MB/s]
#
#
#
# hf_model_0001_0.pt:  21%|██        | 1.04G/4.98G [00:26<01:45, 37.2MB/s]
#
# hf_model_0001_1.pt:  20%|█▉        | 976M/4.98G [00:24<01:33, 42.8MB/s]
# hf_model_0001_2.pt:  18%|█▊        | 880M/4.98G [00:24<02:16, 30.0MB/s]
#
#
# hf_model_0002_0.pt:  18%|█▊        | 896M/5.00G [00:24<01:41, 40.2MB/s]
#
# hf_model_0001_1.pt:  20%|█▉        | 992M/4.98G [00:24<01:31, 43.4MB/s]
# hf_model_0001_2.pt:  18%|█▊        | 896M/4.98G [00:24<01:58, 34.5MB/s]
#
#
#
# hf_model_0001_0.pt:  21%|██        | 1.06G/4.98G [00:26<01:57, 33.3MB/s]
#
# hf_model_0001_1.pt:  20%|██        | 1.01G/4.98G [00:24<01:26, 45.7MB/s][A
# hf_model_0001_1.pt:  21%|██        | 1.02G/4.98G [00:25<01:25, 46.4MB/s][A
#
# hf_model_0002_1.pt:  15%|█▍        | 736M/5.00G [00:24<01:33, 45.4MB/s]
# hf_model_0001_2.pt:  19%|█▊        | 928M/4.98G [00:25<01:35, 42.2MB/s]
#
#
#
# hf_model_0001_0.pt:  22%|██▏       | 1.07G/4.98G [00:27<02:01, 32.1MB/s]
#
#
#
# hf_model_0001_1.pt:  21%|██        | 1.04G/4.98G [00:25<01:24, 46.4MB/s]
# hf_model_0001_2.pt:  19%|█▉        | 944M/4.98G [00:25<01:36, 41.9MB/s]
#
#
# hf_model_0001_1.pt:  21%|██        | 1.06G/4.98G [00:25<01:22, 47.7MB/s][A
# hf_model_0001_2.pt:  19%|█▉        | 960M/4.98G [00:25<01:31, 43.9MB/s]
#
# hf_model_0002_1.pt:  15%|█▌        | 752M/5.00G [00:25<02:05, 33.8MB/s]
#
#
#
# hf_model_0001_1.pt:  22%|██▏       | 1.07G/4.98G [00:26<01:16, 51.0MB/s]
#
#
# hf_model_0002_0.pt:  19%|█▊        | 928M/5.00G [00:26<02:44, 24.7MB/s]
# hf_model_0001_2.pt:  20%|█▉        | 976M/4.98G [00:26<01:28, 45.0MB/s]
#
# hf_model_0001_1.pt:  22%|██▏       | 1.09G/4.98G [00:26<01:17, 50.1MB/s][A
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.12G/4.98G [00:28<01:54, 33.7MB/s]
#
#
# hf_model_0002_0.pt:  19%|█▉        | 944M/5.00G [00:26<02:22, 28.5MB/s]
# hf_model_0001_1.pt:  22%|██▏       | 1.10G/4.98G [00:26<01:20, 48.0MB/s]
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.14G/4.98G [00:28<01:40, 38.1MB/s]
# hf_model_0001_2.pt:  20%|█▉        | 992M/4.98G [00:26<01:50, 36.0MB/s]
#
#
# hf_model_0002_0.pt:  19%|█▉        | 960M/5.00G [00:26<02:05, 32.1MB/s]
#
# hf_model_0001_1.pt:  23%|██▎       | 1.12G/4.98G [00:27<01:18, 49.1MB/s][A
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.15G/4.98G [00:29<01:34, 40.5MB/s]
# hf_model_0001_2.pt:  20%|██        | 1.01G/4.98G [00:27<01:41, 39.2MB/s]
#
#
# hf_model_0001_1.pt:  23%|██▎       | 1.14G/4.98G [00:27<01:13, 52.4MB/s][A
#
# hf_model_0002_1.pt:  16%|█▋        | 816M/5.00G [00:26<01:40, 41.7MB/s]
# hf_model_0001_2.pt:  21%|██        | 1.02G/4.98G [00:27<01:34, 41.6MB/s]
#
# hf_model_0001_1.pt:  23%|██▎       | 1.15G/4.98G [00:27<01:21, 47.0MB/s][A
#
#
#
# hf_model_0001_0.pt:  23%|██▎       | 1.17G/4.98G [00:30<02:05, 30.4MB/s]
#
# hf_model_0002_1.pt:  17%|█▋        | 848M/5.00G [00:27<01:32, 44.7MB/s]
# hf_model_0001_1.pt:  23%|██▎       | 1.17G/4.98G [00:28<01:29, 42.6MB/s]
#
#
# hf_model_0002_0.pt:  20%|█▉        | 992M/5.00G [00:28<02:34, 26.0MB/s]
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.18G/4.98G [00:30<01:50, 34.2MB/s]
#
# hf_model_0002_1.pt:  17%|█▋        | 864M/5.00G [00:27<01:25, 48.2MB/s]
# hf_model_0001_1.pt:  24%|██▍       | 1.18G/4.98G [00:28<01:24, 44.7MB/s]
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.20G/4.98G [00:30<01:40, 37.5MB/s]
#
#
# hf_model_0002_0.pt:  20%|██        | 1.01G/5.00G [00:28<02:13, 30.0MB/s]
#
# hf_model_0001_1.pt:  24%|██▍       | 1.20G/4.98G [00:29<01:23, 45.2MB/s][A
#
#
#
# hf_model_0001_0.pt:  24%|██▍       | 1.22G/4.98G [00:31<01:32, 40.7MB/s]
#
#
# hf_model_0002_0.pt:  20%|██        | 1.02G/5.00G [00:28<02:02, 32.4MB/s]
# hf_model_0001_1.pt:  24%|██▍       | 1.22G/4.98G [00:29<01:22, 45.8MB/s]
#
#
#
# hf_model_0001_0.pt:  25%|██▍       | 1.23G/4.98G [00:31<01:27, 42.6MB/s]
#
#
# hf_model_0002_0.pt:  21%|██        | 1.04G/5.00G [00:29<01:50, 35.9MB/s]
#
# hf_model_0001_1.pt:  25%|██▍       | 1.23G/4.98G [00:29<01:20, 46.2MB/s][A
#
#
# hf_model_0002_0.pt:  21%|██        | 1.06G/5.00G [00:29<01:41, 39.0MB/s]
#
# hf_model_0001_1.pt:  25%|██▌       | 1.25G/4.98G [00:30<01:20, 46.4MB/s][A
# hf_model_0001_2.pt:  22%|██▏       | 1.09G/4.98G [00:30<02:28, 26.2MB/s]
#
# hf_model_0002_1.pt:  19%|█▊        | 928M/5.00G [00:29<01:37, 41.8MB/s]
#
#
# hf_model_0001_1.pt:  25%|██▌       | 1.26G/4.98G [00:30<01:19, 47.0MB/s]
# hf_model_0001_2.pt:  22%|██▏       | 1.10G/4.98G [00:30<02:06, 30.5MB/s]
#
# hf_model_0001_1.pt:  26%|██▌       | 1.28G/4.98G [00:30<01:12, 50.7MB/s][A
#
#
#
# hf_model_0001_0.pt:  25%|██▌       | 1.25G/4.98G [00:32<02:28, 25.0MB/s]
#
#
# hf_model_0002_0.pt:  22%|██▏       | 1.09G/5.00G [00:30<01:41, 38.4MB/s]
# hf_model_0001_2.pt:  23%|██▎       | 1.12G/4.98G [00:30<01:51, 34.7MB/s]
#
# hf_model_0001_1.pt:  26%|██▌       | 1.30G/4.98G [00:30<01:12, 50.6MB/s][A
#
#
#
# hf_model_0001_0.pt:  25%|██▌       | 1.26G/4.98G [00:32<02:07, 29.2MB/s]
#
#
# hf_model_0002_0.pt:  22%|██▏       | 1.10G/5.00G [00:30<01:35, 40.7MB/s]
# hf_model_0001_2.pt:  23%|██▎       | 1.14G/4.98G [00:31<01:44, 36.9MB/s]
#
# hf_model_0001_1.pt:  26%|██▋       | 1.31G/4.98G [00:31<01:10, 51.8MB/s][A
#
#
# hf_model_0002_0.pt:  22%|██▏       | 1.12G/5.00G [00:31<01:28, 44.1MB/s]
#
#
#
# hf_model_0001_0.pt:  26%|██▌       | 1.28G/4.98G [00:33<02:00, 30.8MB/s]
#
# hf_model_0001_1.pt:  27%|██▋       | 1.33G/4.98G [00:31<01:15, 48.6MB/s][A
#
#
# hf_model_0002_0.pt:  23%|██▎       | 1.14G/5.00G [00:31<01:28, 43.7MB/s]
#
#
#
# hf_model_0001_0.pt:  26%|██▌       | 1.30G/4.98G [00:33<01:46, 34.6MB/s]
# hf_model_0001_2.pt:  23%|██▎       | 1.15G/4.98G [00:31<02:04, 30.8MB/s]
#
# hf_model_0002_1.pt:  20%|██        | 1.01G/5.00G [00:31<01:29, 44.5MB/s]
#
#
# hf_model_0002_0.pt:  23%|██▎       | 1.15G/5.00G [00:31<01:25, 44.8MB/s]
#
#
#
# hf_model_0001_1.pt:  27%|██▋       | 1.34G/4.98G [00:32<01:29, 40.6MB/s]
#
# hf_model_0002_1.pt:  20%|██        | 1.02G/5.00G [00:31<01:25, 46.4MB/s]
# hf_model_0001_2.pt:  23%|██▎       | 1.17G/4.98G [00:32<01:54, 33.3MB/s]
#
#
# hf_model_0002_0.pt:  23%|██▎       | 1.17G/5.00G [00:32<01:20, 47.3MB/s]
#
#
#
# hf_model_0001_1.pt:  27%|██▋       | 1.36G/4.98G [00:32<01:25, 42.5MB/s]
#
# hf_model_0002_1.pt:  21%|██        | 1.03G/5.00G [00:31<01:34, 42.1MB/s]
#
#
#
# hf_model_0001_1.pt:  28%|██▊       | 1.38G/4.98G [00:32<01:21, 44.2MB/s]
#
#
# hf_model_0002_0.pt:  24%|██▎       | 1.18G/5.00G [00:32<01:46, 35.8MB/s]
# hf_model_0001_2.pt:  24%|██▍       | 1.18G/4.98G [00:32<02:18, 27.3MB/s]
#
# hf_model_0001_1.pt:  28%|██▊       | 1.39G/4.98G [00:33<01:16, 46.8MB/s]
#
#
#
# hf_model_0001_0.pt:  27%|██▋       | 1.36G/4.98G [00:35<01:23, 43.4MB/s]
#
#
# hf_model_0002_0.pt:  24%|██▍       | 1.20G/5.00G [00:33<01:35, 39.6MB/s]
# hf_model_0001_1.pt:  28%|██▊       | 1.41G/4.98G [00:33<01:22, 43.3MB/s]
# hf_model_0001_2.pt:  24%|██▍       | 1.22G/4.98G [00:33<01:45, 35.7MB/s]
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.38G/4.98G [00:35<01:36, 37.3MB/s]
#
# hf_model_0001_1.pt:  29%|██▊       | 1.42G/4.98G [00:33<01:15, 47.0MB/s]
#
#
# hf_model_0002_0.pt:  24%|██▍       | 1.22G/5.00G [00:33<01:47, 35.2MB/s]
# hf_model_0001_2.pt:  25%|██▍       | 1.23G/4.98G [00:33<01:37, 38.2MB/s]
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.39G/4.98G [00:36<01:31, 39.3MB/s]
#
# hf_model_0001_1.pt:  29%|██▉       | 1.44G/4.98G [00:34<01:14, 47.7MB/s]
#
#
# hf_model_0002_0.pt:  25%|██▍       | 1.23G/5.00G [00:34<01:33, 40.5MB/s]
#
#
#
# hf_model_0001_0.pt:  28%|██▊       | 1.41G/4.98G [00:36<01:21, 44.0MB/s]
# hf_model_0001_1.pt:  29%|██▉       | 1.46G/4.98G [00:34<01:14, 47.5MB/s]
#
# hf_model_0002_1.pt:  21%|██▏       | 1.07G/5.00G [00:33<02:21, 27.8MB/s]
#
#
# hf_model_0002_0.pt:  25%|██▍       | 1.25G/5.00G [00:34<01:29, 42.0MB/s]
#
#
#
# hf_model_0001_1.pt:  30%|██▉       | 1.47G/4.98G [00:34<01:12, 48.6MB/s]
# hf_model_0001_2.pt:  25%|██▌       | 1.26G/4.98G [00:34<01:36, 38.5MB/s]
#
#
# hf_model_0002_0.pt:  25%|██▌       | 1.26G/5.00G [00:34<01:24, 44.1MB/s]
#
# hf_model_0002_1.pt:  22%|██▏       | 1.09G/5.00G [00:34<02:08, 30.4MB/s]
#
#
#
# hf_model_0001_1.pt:  30%|██▉       | 1.49G/4.98G [00:35<01:13, 47.7MB/s]
# hf_model_0001_2.pt:  26%|██▌       | 1.28G/4.98G [00:35<01:29, 41.1MB/s]
#
#
# hf_model_0002_0.pt:  26%|██▌       | 1.28G/5.00G [00:35<01:22, 45.2MB/s]
#
#
#
# hf_model_0001_0.pt:  29%|██▉       | 1.46G/4.98G [00:37<01:12, 48.6MB/s]
#
# hf_model_0001_1.pt:  30%|███       | 1.50G/4.98G [00:35<01:13, 46.9MB/s]
# hf_model_0001_2.pt:  26%|██▌       | 1.30G/4.98G [00:35<01:29, 41.3MB/s]
#
#
#
# hf_model_0001_0.pt:  30%|██▉       | 1.47G/4.98G [00:37<01:12, 48.2MB/s]
#
# hf_model_0002_1.pt:  22%|██▏       | 1.12G/5.00G [00:34<01:40, 38.7MB/s]
#
#
# hf_model_0002_0.pt:  26%|██▌       | 1.30G/5.00G [00:35<01:34, 39.1MB/s]
#
# hf_model_0001_1.pt:  31%|███       | 1.52G/4.98G [00:35<01:14, 46.3MB/s]
#
#
#
# hf_model_0001_0.pt:  30%|██▉       | 1.49G/4.98G [00:37<01:13, 47.7MB/s]
# hf_model_0001_1.pt:  31%|███       | 1.54G/4.98G [00:36<01:11, 48.4MB/s]
#
# hf_model_0002_1.pt:  23%|██▎       | 1.14G/5.00G [00:35<01:55, 33.4MB/s]
#
#
#
# hf_model_0001_1.pt:  31%|███       | 1.54G/4.98G [00:36<01:07, 50.8MB/s]
#
#
# hf_model_0002_0.pt:  26%|██▌       | 1.31G/5.00G [00:36<01:56, 31.7MB/s]
# hf_model_0001_2.pt:  27%|██▋       | 1.33G/4.98G [00:36<01:37, 37.4MB/s]
#
# hf_model_0001_1.pt:  31%|███       | 1.55G/4.98G [00:36<01:33, 36.5MB/s]
#
#
# hf_model_0002_0.pt:  27%|██▋       | 1.33G/5.00G [00:36<01:43, 35.5MB/s]
# hf_model_0001_2.pt:  27%|██▋       | 1.34G/4.98G [00:36<01:30, 40.3MB/s]
#
# hf_model_0002_1.pt:  23%|██▎       | 1.17G/5.00G [00:36<01:37, 39.4MB/s]
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.52G/4.98G [00:38<01:31, 37.9MB/s]
#
#
# hf_model_0002_0.pt:  27%|██▋       | 1.34G/5.00G [00:36<01:33, 39.0MB/s]
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.54G/4.98G [00:39<01:22, 41.9MB/s]
# hf_model_0001_2.pt:  27%|██▋       | 1.36G/4.98G [00:37<01:26, 41.6MB/s]
#
# hf_model_0002_1.pt:  24%|██▎       | 1.18G/5.00G [00:36<01:32, 41.2MB/s]
#
#
# hf_model_0001_1.pt:  31%|███       | 1.55G/4.98G [00:37<02:48, 20.4MB/s]
# hf_model_0001_2.pt:  28%|██▊       | 1.38G/4.98G [00:37<01:21, 44.4MB/s]
#
#
#
# hf_model_0001_0.pt:  31%|███       | 1.55G/4.98G [00:39<01:17, 44.0MB/s]
#
# hf_model_0002_1.pt:  24%|██▍       | 1.20G/5.00G [00:36<01:27, 43.4MB/s]
# hf_model_0001_2.pt:  28%|██▊       | 1.39G/4.98G [00:37<01:18, 46.0MB/s]
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.57G/4.98G [00:39<01:14, 45.7MB/s]
#
# hf_model_0001_1.pt:  32%|███▏      | 1.57G/4.98G [00:37<02:17, 24.8MB/s]
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.58G/4.98G [00:39<00:58, 57.5MB/s]
#
# hf_model_0002_1.pt:  25%|██▍       | 1.23G/5.00G [00:37<01:04, 58.2MB/s]
#
#
# hf_model_0001_1.pt:  32%|███▏      | 1.58G/4.98G [00:38<01:52, 30.2MB/s]
#
# hf_model_0002_1.pt:  25%|██▍       | 1.24G/5.00G [00:37<01:19, 47.6MB/s]
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.59G/4.98G [00:40<01:14, 45.3MB/s]
#
#
# hf_model_0002_0.pt:  28%|██▊       | 1.39G/5.00G [00:38<01:31, 39.5MB/s]
#
# hf_model_0001_1.pt:  32%|███▏      | 1.60G/4.98G [00:38<01:39, 34.0MB/s]
# hf_model_0001_2.pt:  29%|██▊       | 1.42G/4.98G [00:38<01:20, 44.4MB/s]
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.60G/4.98G [00:40<01:25, 39.3MB/s]
#
#
# hf_model_0001_1.pt:  32%|███▏      | 1.62G/4.98G [00:38<01:23, 40.2MB/s]
#
#
# hf_model_0002_0.pt:  28%|██▊       | 1.42G/5.00G [00:38<01:23, 42.6MB/s]
# hf_model_0001_1.pt:  33%|███▎      | 1.63G/4.98G [00:39<01:18, 42.4MB/s]
#
#
# hf_model_0001_1.pt:  33%|███▎      | 1.65G/4.98G [00:39<01:14, 44.9MB/s]
# hf_model_0001_2.pt:  29%|██▉       | 1.46G/4.98G [00:39<01:35, 36.9MB/s]
#
#
# hf_model_0002_0.pt:  29%|██▉       | 1.46G/5.00G [00:39<01:15, 47.1MB/s]
# hf_model_0001_2.pt:  30%|██▉       | 1.47G/4.98G [00:39<01:25, 40.8MB/s]
#
#
# hf_model_0002_0.pt:  29%|██▉       | 1.47G/5.00G [00:39<01:13, 47.8MB/s]
#
#
#
# hf_model_0001_0.pt:  32%|███▏      | 1.62G/4.98G [00:42<02:49, 19.8MB/s]
#
# hf_model_0001_1.pt:  33%|███▎      | 1.66G/4.98G [00:40<01:34, 35.1MB/s]
# hf_model_0001_2.pt:  30%|██▉       | 1.49G/4.98G [00:40<01:22, 42.2MB/s]
#
#
# hf_model_0002_0.pt:  30%|██▉       | 1.49G/5.00G [00:40<01:15, 46.4MB/s]
#
# hf_model_0002_1.pt:  26%|██▌       | 1.28G/5.00G [00:39<02:33, 24.3MB/s]
#
#
#
# hf_model_0001_0.pt:  33%|███▎      | 1.63G/4.98G [00:42<02:17, 24.4MB/s]
# hf_model_0001_1.pt:  34%|███▍      | 1.68G/4.98G [00:40<01:29, 36.7MB/s]
#
#
# hf_model_0002_0.pt:  30%|███       | 1.50G/5.00G [00:40<01:13, 47.6MB/s]
# hf_model_0001_2.pt:  31%|███       | 1.52G/4.98G [00:40<01:16, 45.2MB/s]
#
#
#
# hf_model_0001_1.pt:  34%|███▍      | 1.70G/4.98G [00:40<01:29, 36.8MB/s]
#
# hf_model_0002_1.pt:  26%|██▌       | 1.30G/5.00G [00:40<02:25, 25.4MB/s]
# hf_model_0001_2.pt:  31%|███       | 1.54G/4.98G [00:41<01:14, 46.3MB/s]
#
#
#
# hf_model_0001_0.pt:  33%|███▎      | 1.66G/4.98G [00:43<01:42, 32.3MB/s]
#
#
# hf_model_0001_1.pt:  34%|███▍      | 1.71G/4.98G [00:41<01:21, 40.2MB/s]
#
# hf_model_0002_1.pt:  26%|██▌       | 1.31G/5.00G [00:40<02:01, 30.2MB/s]
# hf_model_0001_2.pt:  31%|███       | 1.55G/4.98G [00:41<01:11, 48.2MB/s]
#
#
# hf_model_0001_1.pt:  35%|███▍      | 1.73G/4.98G [00:41<01:16, 42.2MB/s]
#
# hf_model_0002_1.pt:  27%|██▋       | 1.33G/5.00G [00:40<01:45, 34.8MB/s]
# hf_model_0001_2.pt:  32%|███▏      | 1.57G/4.98G [00:41<01:10, 48.3MB/s]
#
#
# hf_model_0001_1.pt:  35%|███▌      | 1.74G/4.98G [00:41<01:14, 43.3MB/s]
#
# hf_model_0002_1.pt:  27%|██▋       | 1.34G/5.00G [00:41<01:46, 34.4MB/s]
# hf_model_0001_2.pt:  32%|███▏      | 1.58G/4.98G [00:42<01:09, 48.6MB/s]
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.68G/4.98G [00:44<02:12, 24.9MB/s]
#
#
# hf_model_0001_1.pt:  35%|███▌      | 1.76G/4.98G [00:42<01:11, 44.8MB/s]
# hf_model_0001_2.pt:  32%|███▏      | 1.60G/4.98G [00:42<01:08, 49.3MB/s]
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.70G/4.98G [00:44<01:49, 29.9MB/s]
#
# hf_model_0002_1.pt:  27%|██▋       | 1.36G/5.00G [00:41<01:38, 37.0MB/s]
#
#
# hf_model_0001_1.pt:  36%|███▌      | 1.78G/4.98G [00:42<01:10, 45.6MB/s]
# hf_model_0001_2.pt:  32%|███▏      | 1.62G/4.98G [00:42<01:09, 48.6MB/s]
#
# hf_model_0002_1.pt:  28%|██▊       | 1.38G/5.00G [00:42<01:31, 39.5MB/s]
#
#
# hf_model_0002_0.pt:  32%|███▏      | 1.60G/5.00G [00:42<01:14, 45.8MB/s]
#
#
#
# hf_model_0001_0.pt:  34%|███▍      | 1.71G/4.98G [00:44<01:42, 31.8MB/s]
# hf_model_0001_1.pt:  36%|███▌      | 1.79G/4.98G [00:42<01:07, 47.3MB/s]
#
#
#
# hf_model_0001_0.pt:  35%|███▍      | 1.73G/4.98G [00:45<01:28, 36.9MB/s]
#
# hf_model_0002_1.pt:  28%|██▊       | 1.39G/5.00G [00:42<01:40, 35.8MB/s]
#
#
# hf_model_0002_0.pt:  32%|███▏      | 1.62G/5.00G [00:43<01:23, 40.4MB/s]
# hf_model_0001_2.pt:  33%|███▎      | 1.63G/4.98G [00:43<01:59, 28.0MB/s]
#
# hf_model_0002_1.pt:  28%|██▊       | 1.41G/5.00G [00:43<01:32, 38.7MB/s]
#
#
# hf_model_0001_1.pt:  36%|███▋      | 1.81G/4.98G [00:43<01:40, 31.7MB/s]
#
#
#
# hf_model_0001_0.pt:  35%|███▌      | 1.74G/4.98G [00:45<01:42, 31.6MB/s]
#
# hf_model_0002_1.pt:  28%|██▊       | 1.42G/5.00G [00:43<01:26, 41.5MB/s]
#
#
# hf_model_0002_0.pt:  33%|███▎      | 1.65G/5.00G [00:43<01:15, 44.2MB/s]
# hf_model_0001_1.pt:  37%|███▋      | 1.82G/4.98G [00:44<01:29, 35.1MB/s]
#
#
#
# hf_model_0001_0.pt:  35%|███▌      | 1.76G/4.98G [00:46<01:30, 35.6MB/s]
#
# hf_model_0002_1.pt:  29%|██▉       | 1.44G/5.00G [00:43<01:20, 44.2MB/s]
#
#
# hf_model_0002_0.pt:  33%|███▎      | 1.66G/5.00G [00:44<01:13, 45.5MB/s]
# hf_model_0001_2.pt:  33%|███▎      | 1.65G/4.98G [00:44<02:02, 27.1MB/s]
#
#
#
# hf_model_0001_0.pt:  36%|███▌      | 1.78G/4.98G [00:46<01:22, 39.0MB/s]
#
# hf_model_0001_1.pt:  37%|███▋      | 1.84G/4.98G [00:44<01:32, 33.8MB/s]
#
#
# hf_model_0002_0.pt:  34%|███▎      | 1.68G/5.00G [00:44<01:19, 41.9MB/s]
# hf_model_0001_2.pt:  33%|███▎      | 1.66G/4.98G [00:44<01:53, 29.1MB/s]
#
#
# hf_model_0002_0.pt:  34%|███▍      | 1.70G/5.00G [00:44<01:12, 45.4MB/s]
#
# hf_model_0002_1.pt:  29%|██▉       | 1.47G/5.00G [00:44<01:28, 40.0MB/s]
#
#
#
# hf_model_0001_0.pt:  36%|███▌      | 1.79G/4.98G [00:47<01:40, 31.6MB/s]
# hf_model_0001_1.pt:  37%|███▋      | 1.86G/4.98G [00:45<01:36, 32.2MB/s]
#
#
# hf_model_0002_0.pt:  34%|███▍      | 1.71G/5.00G [00:45<01:10, 46.3MB/s]
# hf_model_0001_1.pt:  38%|███▊      | 1.87G/4.98G [00:45<01:25, 36.4MB/s]
#
# hf_model_0002_1.pt:  30%|██▉       | 1.49G/5.00G [00:44<01:26, 40.8MB/s]
#
#
#
# hf_model_0001_0.pt:  36%|███▋      | 1.81G/4.98G [00:47<01:30, 34.8MB/s]
# hf_model_0001_2.pt:  34%|███▍      | 1.71G/4.98G [00:45<01:15, 43.4MB/s]
#
#
# hf_model_0001_1.pt:  38%|███▊      | 1.89G/4.98G [00:45<01:17, 39.9MB/s]
#
#
#
# hf_model_0001_0.pt:  37%|███▋      | 1.82G/4.98G [00:47<01:22, 38.2MB/s]
#
# hf_model_0002_1.pt:  30%|███       | 1.50G/5.00G [00:45<01:28, 39.4MB/s]
# hf_model_0001_1.pt:  38%|███▊      | 1.90G/4.98G [00:46<01:10, 43.3MB/s]
#
#
# hf_model_0002_0.pt:  35%|███▍      | 1.74G/5.00G [00:46<01:13, 44.4MB/s]
#
#
#
# hf_model_0001_0.pt:  37%|███▋      | 1.84G/4.98G [00:48<01:19, 39.4MB/s]
#
# hf_model_0001_1.pt:  39%|███▊      | 1.92G/4.98G [00:46<01:07, 45.1MB/s]
#
#
# hf_model_0002_0.pt:  35%|███▌      | 1.76G/5.00G [00:46<01:10, 46.1MB/s]
# hf_model_0001_2.pt:  35%|███▌      | 1.74G/4.98G [00:46<01:17, 41.7MB/s]
#
#
#
# hf_model_0001_0.pt:  37%|███▋      | 1.86G/4.98G [00:48<01:15, 41.6MB/s]
#
# hf_model_0001_1.pt:  39%|███▉      | 1.94G/4.98G [00:46<01:06, 45.8MB/s]
#
#
# hf_model_0002_0.pt:  36%|███▌      | 1.78G/5.00G [00:46<01:11, 45.1MB/s]
# hf_model_0001_2.pt:  35%|███▌      | 1.76G/4.98G [00:46<01:14, 43.4MB/s]
#
#
#
# hf_model_0001_0.pt:  38%|███▊      | 1.87G/4.98G [00:48<01:12, 42.9MB/s]
#
# hf_model_0001_1.pt:  39%|███▉      | 1.95G/4.98G [00:47<01:05, 45.9MB/s]
# hf_model_0001_2.pt:  36%|███▌      | 1.78G/4.98G [00:47<01:09, 46.1MB/s]
#
#
# hf_model_0002_0.pt:  36%|███▌      | 1.79G/5.00G [00:47<01:09, 45.9MB/s]
#
# hf_model_0002_1.pt:  31%|███▏      | 1.57G/5.00G [00:46<01:09, 49.2MB/s]
#
#
#
# hf_model_0001_0.pt:  38%|███▊      | 1.89G/4.98G [00:49<01:07, 46.0MB/s]
# hf_model_0001_1.pt:  40%|███▉      | 1.97G/4.98G [00:47<01:05, 46.2MB/s]
# hf_model_0001_2.pt:  36%|███▌      | 1.80G/4.98G [00:47<01:01, 51.6MB/s]
#
# hf_model_0002_1.pt:  32%|███▏      | 1.58G/5.00G [00:46<01:09, 49.1MB/s]
#
#
# hf_model_0002_0.pt:  36%|███▌      | 1.81G/5.00G [00:47<01:09, 46.1MB/s]
#
#
#
# hf_model_0001_1.pt:  40%|███▉      | 1.98G/4.98G [00:47<01:05, 45.6MB/s]
#
# hf_model_0002_1.pt:  32%|███▏      | 1.60G/5.00G [00:47<01:09, 48.8MB/s]
#
#
# hf_model_0002_0.pt:  36%|███▋      | 1.82G/5.00G [00:47<01:07, 46.8MB/s]
#
#
#
# hf_model_0001_0.pt:  39%|███▊      | 1.92G/4.98G [00:49<01:08, 44.5MB/s]
#
# hf_model_0001_1.pt:  40%|████      | 2.00G/4.98G [00:48<01:09, 42.9MB/s]
#
#
# hf_model_0002_0.pt:  37%|███▋      | 1.84G/5.00G [00:48<01:10, 44.9MB/s]
#
#
#
# hf_model_0001_0.pt:  39%|███▉      | 1.94G/4.98G [00:50<01:06, 45.7MB/s]
# hf_model_0001_2.pt:  36%|███▋      | 1.81G/4.98G [00:48<01:57, 27.0MB/s]
#
# hf_model_0002_1.pt:  33%|███▎      | 1.63G/5.00G [00:47<01:07, 50.0MB/s]
#
#
# hf_model_0001_1.pt:  41%|████      | 2.02G/4.98G [00:48<01:06, 44.5MB/s]
#
#
#
# hf_model_0001_0.pt:  39%|███▉      | 1.95G/4.98G [00:50<01:04, 47.0MB/s]
# hf_model_0001_2.pt:  37%|███▋      | 1.82G/4.98G [00:48<01:37, 32.4MB/s]
#
# hf_model_0002_1.pt:  33%|███▎      | 1.65G/5.00G [00:48<01:05, 50.8MB/s]
#
#
#
# hf_model_0001_0.pt:  40%|███▉      | 1.97G/4.98G [00:50<01:00, 49.4MB/s]
#
#
# hf_model_0002_0.pt:  37%|███▋      | 1.87G/5.00G [00:48<01:06, 47.4MB/s]
#
# hf_model_0002_1.pt:  33%|███▎      | 1.66G/5.00G [00:48<01:00, 55.6MB/s]
# hf_model_0001_1.pt:  41%|████      | 2.03G/4.98G [00:49<01:11, 41.1MB/s]
#
#
#
# hf_model_0001_0.pt:  40%|███▉      | 1.98G/4.98G [00:51<01:00, 49.3MB/s]
#
#
# hf_model_0001_1.pt:  41%|████      | 2.05G/4.98G [00:49<01:04, 45.6MB/s]
# hf_model_0001_2.pt:  37%|███▋      | 1.86G/4.98G [00:49<01:14, 41.7MB/s]
#
#
#
# hf_model_0001_0.pt:  40%|████      | 2.00G/4.98G [00:51<00:59, 49.8MB/s]
#
#
# hf_model_0002_0.pt:  38%|███▊      | 1.90G/5.00G [00:49<01:03, 48.4MB/s]
# hf_model_0001_1.pt:  41%|████▏     | 2.06G/4.98G [00:49<01:04, 45.3MB/s]
#
#
# hf_model_0002_0.pt:  38%|███▊      | 1.92G/5.00G [00:49<01:01, 49.7MB/s]
#
#
#
# hf_model_0001_0.pt:  41%|████      | 2.02G/4.98G [00:51<00:59, 49.4MB/s]
# hf_model_0001_1.pt:  42%|████▏     | 2.08G/4.98G [00:50<01:02, 46.5MB/s]
#
# hf_model_0002_1.pt:  33%|███▎      | 1.66G/5.00G [00:49<02:19, 23.8MB/s]
#
#
# hf_model_0002_0.pt:  39%|███▊      | 1.94G/5.00G [00:50<01:01, 49.5MB/s]
#
#
#
# hf_model_0001_0.pt:  41%|████      | 2.03G/4.98G [00:52<01:02, 46.9MB/s]
# hf_model_0001_1.pt:  42%|████▏     | 2.10G/4.98G [00:50<01:01, 46.8MB/s]
#
# hf_model_0002_1.pt:  34%|███▎      | 1.68G/5.00G [00:49<02:05, 26.5MB/s]
#
#
#
# hf_model_0001_0.pt:  41%|████      | 2.05G/4.98G [00:52<00:57, 50.7MB/s]
#
#
# hf_model_0002_0.pt:  39%|███▉      | 1.95G/5.00G [00:50<01:06, 45.6MB/s]
#
#
#
# hf_model_0001_0.pt:  41%|████▏     | 2.06G/4.98G [00:52<00:57, 50.8MB/s]
# hf_model_0001_2.pt:  39%|███▊      | 1.92G/4.98G [00:50<01:17, 39.6MB/s]
#
# hf_model_0001_1.pt:  42%|████▏     | 2.11G/4.98G [00:50<01:15, 37.9MB/s]
# hf_model_0001_2.pt:  39%|███▉      | 1.94G/4.98G [00:51<01:09, 43.8MB/s]
#
#
#
# hf_model_0001_0.pt:  42%|████▏     | 2.08G/4.98G [00:53<00:55, 52.0MB/s]
#
# hf_model_0001_1.pt:  43%|████▎     | 2.13G/4.98G [00:51<01:16, 37.2MB/s]
# hf_model_0001_2.pt:  39%|███▉      | 1.95G/4.98G [00:51<01:05, 46.0MB/s]
#
#
# hf_model_0002_0.pt:  39%|███▉      | 1.97G/5.00G [00:51<01:32, 32.6MB/s]
#
#
#
# hf_model_0001_0.pt:  42%|████▏     | 2.10G/4.98G [00:53<00:56, 50.9MB/s]
#
# hf_model_0001_1.pt:  43%|████▎     | 2.14G/4.98G [00:51<01:10, 40.0MB/s]
#
#
# hf_model_0002_0.pt:  40%|███▉      | 1.98G/5.00G [00:51<01:23, 35.9MB/s]
#
#
#
# hf_model_0001_0.pt:  42%|████▏     | 2.11G/4.98G [00:53<00:56, 50.4MB/s]
#
# hf_model_0002_1.pt:  35%|███▍      | 1.74G/5.00G [00:51<01:23, 38.9MB/s]
#
#
# hf_model_0002_0.pt:  40%|████      | 2.00G/5.00G [00:51<01:16, 39.2MB/s]
#
#
#
# hf_model_0001_1.pt:  43%|████▎     | 2.16G/4.98G [00:52<01:10, 40.0MB/s]
#
# hf_model_0002_1.pt:  35%|███▌      | 1.76G/5.00G [00:51<01:21, 39.6MB/s]
#
#
# hf_model_0002_0.pt:  40%|████      | 2.02G/5.00G [00:52<01:12, 41.0MB/s]
#
#
#
# hf_model_0001_1.pt:  44%|████▎     | 2.18G/4.98G [00:52<01:05, 42.8MB/s]
#
#
# hf_model_0002_0.pt:  41%|████      | 2.03G/5.00G [00:52<01:05, 45.3MB/s]
#
# hf_model_0002_1.pt:  36%|███▌      | 1.78G/5.00G [00:52<01:16, 42.1MB/s]
# hf_model_0001_1.pt:  44%|████▍     | 2.19G/4.98G [00:52<01:04, 43.1MB/s]
#
#
# hf_model_0002_0.pt:  41%|████      | 2.05G/5.00G [00:52<01:02, 47.3MB/s]
#
#
#
# hf_model_0001_0.pt:  43%|████▎     | 2.16G/4.98G [00:54<01:12, 38.9MB/s]
#
# hf_model_0002_1.pt:  36%|███▌      | 1.79G/5.00G [00:52<01:13, 43.5MB/s]
# hf_model_0001_1.pt:  44%|████▍     | 2.21G/4.98G [00:53<01:02, 44.4MB/s]
#
#
# hf_model_0002_0.pt:  41%|████▏     | 2.06G/5.00G [00:53<01:02, 47.1MB/s]
#
#
#
# hf_model_0001_0.pt:  44%|████▎     | 2.18G/4.98G [00:55<01:07, 41.5MB/s]
#
# hf_model_0002_1.pt:  36%|███▌      | 1.81G/5.00G [00:52<01:11, 44.7MB/s]
# hf_model_0001_1.pt:  45%|████▍     | 2.22G/4.98G [00:53<01:04, 42.5MB/s]
#
#
# hf_model_0002_0.pt:  42%|████▏     | 2.08G/5.00G [00:53<01:01, 47.3MB/s]
#
# hf_model_0002_1.pt:  36%|███▋      | 1.82G/5.00G [00:52<01:06, 47.5MB/s]
# hf_model_0001_1.pt:  45%|████▌     | 2.24G/4.98G [00:53<01:01, 44.6MB/s]
#
#
#
# hf_model_0001_0.pt:  44%|████▍     | 2.19G/4.98G [00:55<01:16, 36.3MB/s]
#
#
# hf_model_0002_0.pt:  42%|████▏     | 2.10G/5.00G [00:53<01:00, 47.8MB/s]
#
# hf_model_0002_1.pt:  37%|███▋      | 1.84G/5.00G [00:53<01:04, 48.9MB/s]
# hf_model_0001_1.pt:  45%|████▌     | 2.26G/4.98G [00:54<00:56, 47.8MB/s]
#
# hf_model_0002_1.pt:  37%|███▋      | 1.86G/5.00G [00:53<01:04, 48.5MB/s]
#
#
# hf_model_0002_0.pt:  42%|████▏     | 2.11G/5.00G [00:54<01:00, 47.5MB/s]
#
#
#
# hf_model_0001_1.pt:  46%|████▌     | 2.27G/4.98G [00:54<00:55, 48.7MB/s]
# hf_model_0001_2.pt:  41%|████      | 2.05G/4.98G [00:54<01:13, 39.7MB/s]
#
#
# hf_model_0002_0.pt:  43%|████▎     | 2.13G/5.00G [00:54<00:58, 48.8MB/s]
#
# hf_model_0002_1.pt:  37%|███▋      | 1.87G/5.00G [00:53<01:04, 48.8MB/s]
#
#
#
# hf_model_0001_1.pt:  46%|████▌     | 2.29G/4.98G [00:54<00:54, 48.9MB/s]
# hf_model_0001_2.pt:  41%|████▏     | 2.06G/4.98G [00:54<01:14, 39.1MB/s]
#
#
# hf_model_0002_0.pt:  43%|████▎     | 2.14G/5.00G [00:54<00:57, 50.1MB/s]
#
#
#
# hf_model_0001_1.pt:  46%|████▋     | 2.30G/4.98G [00:55<00:55, 48.5MB/s]
# hf_model_0001_2.pt:  42%|████▏     | 2.08G/4.98G [00:55<01:09, 41.5MB/s]
#
#
# hf_model_0002_0.pt:  43%|████▎     | 2.16G/5.00G [00:55<00:57, 49.3MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.89G/5.00G [00:54<01:22, 37.9MB/s]
#
#
#
# hf_model_0001_1.pt:  47%|████▋     | 2.32G/4.98G [00:55<00:54, 48.3MB/s]
#
#
# hf_model_0002_0.pt:  44%|████▎     | 2.18G/5.00G [00:55<00:57, 49.5MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.90G/5.00G [00:54<01:17, 39.9MB/s]
#
#
#
# hf_model_0001_1.pt:  47%|████▋     | 2.34G/4.98G [00:55<00:54, 48.8MB/s]
# hf_model_0001_2.pt:  42%|████▏     | 2.10G/4.98G [00:55<01:17, 36.9MB/s]
#
#
# hf_model_0002_0.pt:  44%|████▍     | 2.19G/5.00G [00:55<00:56, 49.7MB/s]
#
#
#
# hf_model_0001_0.pt:  46%|████▌     | 2.29G/4.98G [00:58<00:59, 45.5MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.92G/5.00G [00:55<01:27, 35.4MB/s]
# hf_model_0001_2.pt:  42%|████▏     | 2.11G/4.98G [00:56<01:12, 39.3MB/s]_1.pt:  47%|████▋     | 2.35G/4.98G [00:56<00:54, 47.8MB/s]
#
#
# hf_model_0002_0.pt:  44%|████▍     | 2.21G/5.00G [00:56<00:55, 50.0MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.92G/5.00G [00:55<01:29, 34.5MB/s]
# hf_model_0001_2.pt:  43%|████▎     | 2.13G/4.98G [00:56<01:08, 41.8MB/s]
#
#
#
# hf_model_0001_1.pt:  48%|████▊     | 2.37G/4.98G [00:56<01:00, 42.9MB/s]
#
#
# hf_model_0002_0.pt:  44%|████▍     | 2.22G/5.00G [00:56<01:00, 46.3MB/s]
#
# hf_model_0002_1.pt:  38%|███▊      | 1.92G/5.00G [00:55<02:03, 24.9MB/s]
# hf_model_0001_2.pt:  43%|████▎     | 2.14G/4.98G [00:56<01:05, 43.2MB/s]
#
#
#
# hf_model_0001_1.pt:  48%|████▊     | 2.38G/4.98G [00:56<00:58, 44.1MB/s]
#
#
# hf_model_0002_0.pt:  45%|████▍     | 2.24G/5.00G [00:56<00:58, 46.9MB/s]
#
# hf_model_0002_1.pt:  39%|███▊      | 1.94G/5.00G [00:56<01:46, 28.8MB/s]
# hf_model_0001_1.pt:  48%|████▊     | 2.40G/4.98G [00:57<00:58, 43.9MB/s]
#
#
# hf_model_0002_0.pt:  45%|████▌     | 2.26G/5.00G [00:57<01:03, 43.4MB/s]
#
#
#
# hf_model_0001_0.pt:  47%|████▋     | 2.34G/4.98G [00:59<01:10, 37.3MB/s]
# hf_model_0001_1.pt:  49%|████▊     | 2.42G/4.98G [00:57<00:56, 45.1MB/s]
#
# hf_model_0002_1.pt:  39%|███▉      | 1.95G/5.00G [00:56<01:50, 27.5MB/s]
#
#
#
# hf_model_0001_0.pt:  47%|████▋     | 2.35G/4.98G [00:59<01:05, 40.2MB/s]
# hf_model_0001_2.pt:  44%|████▍     | 2.19G/4.98G [00:57<00:59, 47.1MB/s]
#
#
# hf_model_0001_1.pt:  49%|████▉     | 2.43G/4.98G [00:57<00:55, 45.7MB/s]
#
# hf_model_0002_1.pt:  39%|███▉      | 1.97G/5.00G [00:57<01:33, 32.4MB/s]
#
#
#
# hf_model_0001_0.pt:  48%|████▊     | 2.37G/4.98G [01:00<01:00, 43.3MB/s]
# hf_model_0001_2.pt:  44%|████▍     | 2.21G/4.98G [00:58<01:00, 45.7MB/s]
#
#
# hf_model_0002_0.pt:  46%|████▌     | 2.29G/5.00G [00:58<01:03, 42.6MB/s]
#
# hf_model_0001_1.pt:  49%|████▉     | 2.45G/4.98G [00:58<00:54, 46.8MB/s]
#
#
#
# hf_model_0001_0.pt:  48%|████▊     | 2.38G/4.98G [01:00<00:56, 45.5MB/s]
# hf_model_0001_2.pt:  45%|████▍     | 2.22G/4.98G [00:58<00:56, 49.1MB/s]
#
#
# hf_model_0002_0.pt:  46%|████▌     | 2.30G/5.00G [00:58<01:00, 44.6MB/s]
#
# hf_model_0001_1.pt:  50%|████▉     | 2.46G/4.98G [00:58<00:53, 47.1MB/s]
#
#
#
# hf_model_0001_0.pt:  48%|████▊     | 2.40G/4.98G [01:00<00:55, 46.3MB/s]
#
# hf_model_0001_1.pt:  50%|████▉     | 2.48G/4.98G [00:58<00:52, 47.6MB/s]
#
#
# hf_model_0002_0.pt:  46%|████▋     | 2.32G/5.00G [00:58<01:06, 40.2MB/s]
#
#
#
# hf_model_0001_1.pt:  50%|█████     | 2.50G/4.98G [00:59<00:52, 47.7MB/s]
#
#
# hf_model_0002_0.pt:  47%|████▋     | 2.34G/5.00G [00:59<01:02, 42.8MB/s]
#
#
#
# hf_model_0001_1.pt:  50%|█████     | 2.51G/4.98G [00:59<00:49, 49.6MB/s]
#
#
# hf_model_0001_1.pt:  51%|█████     | 2.53G/4.98G [00:59<00:47, 51.1MB/s]
#
#
#
# hf_model_0001_1.pt:  51%|█████     | 2.54G/4.98G [01:00<00:47, 51.4MB/s]
#
#
# hf_model_0002_0.pt:  47%|████▋     | 2.37G/5.00G [01:00<01:10, 37.2MB/s]
#
#
#
# hf_model_0001_0.pt:  50%|████▉     | 2.46G/4.98G [01:02<01:06, 38.0MB/s]
#
# hf_model_0001_1.pt:  51%|█████▏    | 2.56G/4.98G [01:00<00:48, 49.8MB/s]
#
#
# hf_model_0002_0.pt:  48%|████▊     | 2.38G/5.00G [01:00<01:04, 40.7MB/s]
#
#
#
# hf_model_0001_0.pt:  50%|████▉     | 2.48G/4.98G [01:02<01:00, 41.4MB/s]
#
# hf_model_0002_1.pt:  41%|████      | 2.05G/5.00G [01:00<01:52, 26.3MB/s]
#
#
# hf_model_0001_1.pt:  52%|█████▏    | 2.58G/4.98G [01:00<00:50, 47.2MB/s]
#
#
#
# hf_model_0001_0.pt:  50%|█████     | 2.50G/4.98G [01:03<00:57, 42.8MB/s]
#
#
# hf_model_0002_0.pt:  48%|████▊     | 2.42G/5.00G [01:01<00:58, 44.5MB/s]
#
# hf_model_0001_1.pt:  52%|█████▏    | 2.59G/4.98G [01:01<00:49, 48.0MB/s]
#
#
#
# hf_model_0001_0.pt:  50%|█████     | 2.51G/4.98G [01:03<00:55, 44.7MB/s]
#
# hf_model_0001_1.pt:  52%|█████▏    | 2.61G/4.98G [01:01<00:50, 46.5MB/s]
#
#
#
# hf_model_0001_0.pt:  51%|█████     | 2.53G/4.98G [01:03<00:56, 43.3MB/s]
#
# hf_model_0001_1.pt:  53%|█████▎    | 2.62G/4.98G [01:01<00:49, 47.1MB/s]
#
#
# hf_model_0002_0.pt:  49%|████▊     | 2.43G/5.00G [01:01<01:18, 32.8MB/s]
#
#
#
# hf_model_0001_0.pt:  51%|█████     | 2.54G/4.98G [01:04<00:55, 43.8MB/s]
#
# hf_model_0001_1.pt:  53%|█████▎    | 2.64G/4.98G [01:02<00:52, 44.9MB/s]
#
#
# ...
#
# hf_model_0002_2.pt:  79%|███████▉  | 3.95G/5.00G [01:47<00:24, 42.7MB/s]
#
#
#
# hf_model_0003_1.pt:  76%|███████▋  | 3.76G/4.92G [01:43<00:29, 39.8MB/s]
# hf_model_0004_2.pt: 100%|█████████▉| 1.17G/1.17G [00:28<00:00, 49.1MB/s]
#
# hf_model_0004_2.pt: 100%|██████████| 1.17G/1.17G [00:29<00:00, 40.3MB/s]
#
#
#
# hf_model_0003_0.pt:  81%|████████▏ | 4.00G/4.92G [01:44<00:26, 34.2MB/s]
#
#
#
# hf_model_0003_1.pt:  77%|███████▋  | 3.78G/4.92G [01:44<00:30, 37.8MB/s]
#
# hf_model_0003_2.pt:  74%|███████▍  | 3.63G/4.92G [01:32<00:30, 42.6MB/s]odel_0002_2.pt:  79%|███████▉  | 3.97G/5.00G [01:48<00:30, 33.5MB/s]
# recipe_state.pt:   0%|          | 0.00/80.1M [00:00<?, ?B/s]
#
# hf_model_0003_2.pt:  74%|███████▍  | 3.65G/4.92G [01:32<00:23, 54.5MB/s]odel_0002_2.pt:  80%|███████▉  | 3.98G/5.00G [01:48<00:21, 48.4MB/s]
#
#
# hf_model_0003_0.pt:  82%|████████▏ | 4.02G/4.92G [01:44<00:23, 37.6MB/s]
#
#
#
# hf_model_0003_1.pt:  77%|███████▋  | 3.79G/4.92G [01:44<00:28, 39.4MB/s]
# hf_model_0002_2.pt:  80%|███████▉  | 3.99G/5.00G [01:48<00:24, 40.4MB/s]
#
#
#
# hf_model_0003_1.pt:  77%|███████▋  | 3.81G/4.92G [01:44<00:26, 42.3MB/s]
#
#
# hf_model_0002_2.pt:  80%|████████  | 4.02G/5.00G [01:49<00:19, 51.0MB/s]
#
# hf_model_0003_2.pt:  74%|███████▍  | 3.66G/4.92G [01:33<00:41, 30.6MB/s]
# recipe_state.pt:  40%|███▉      | 32.0M/80.1M [00:00<00:01, 34.6MB/s]
#
#
#
# hf_model_0003_1.pt:  78%|███████▊  | 3.82G/4.92G [01:45<00:24, 44.5MB/s]
#
#
# hf_model_0003_0.pt:  82%|████████▏ | 4.05G/4.92G [01:45<00:22, 38.0MB/s]
# recipe_state.pt:  60%|█████▉    | 48.0M/80.1M [00:01<00:00, 41.9MB/s]
#
#
#
# hf_model_0003_1.pt:  78%|███████▊  | 3.84G/4.92G [01:45<00:23, 46.6MB/s]
#
#
# hf_model_0002_2.pt:  80%|████████  | 4.02G/5.00G [01:49<00:29, 32.8MB/s]
# recipe_state.pt:  80%|███████▉  | 64.0M/80.1M [00:01<00:00, 46.2MB/s]
#
#
#
# hf_model_0003_1.pt:  78%|███████▊  | 3.86G/4.92G [01:45<00:23, 45.8MB/s]
#
#
# hf_model_0003_0.pt:  83%|████████▎ | 4.08G/4.92G [01:45<00:19, 42.8MB/s]
# recipe_state.pt: 100%|█████████▉| 80.0M/80.1M [00:01<00:00, 47.9MB/s]
#
# recipe_state.pt: 100%|██████████| 80.1M/80.1M [00:01<00:00, 41.7MB/s]/s]odel_0002_2.pt:  81%|████████  | 4.03G/5.00G [01:50<00:34, 28.0MB/s]
#
#
#
#
# hf_model_0003_1.pt:  79%|███████▉  | 3.87G/4.92G [01:46<00:22, 46.7MB/s]
#
#
# hf_model_0003_0.pt:  83%|████████▎ | 4.10G/4.92G [01:46<00:18, 44.3MB/s]
#
# hf_model_0002_2.pt:  81%|████████  | 4.05G/5.00G [01:50<00:28, 33.2MB/s]
#
#
# hf_model_0003_0.pt:  84%|████████▎ | 4.11G/4.92G [01:46<00:17, 45.4MB/s]
#
#
#
# hf_model_0003_1.pt:  79%|███████▉  | 3.89G/4.92G [01:46<00:23, 43.3MB/s]
#
# hf_model_0002_2.pt:  81%|████████▏ | 4.06G/5.00G [01:50<00:29, 31.4MB/s]
#
#
# hf_model_0003_0.pt:  84%|████████▍ | 4.13G/4.92G [01:46<00:16, 46.5MB/s]
#
#
#
# hf_model_0002_2.pt:  82%|████████▏ | 4.08G/5.00G [01:50<00:19, 46.4MB/s]
#
# hf_model_0003_2.pt:  76%|███████▌  | 3.71G/4.92G [01:35<00:35, 34.3MB/s]
#
#
#
# hf_model_0002_2.pt:  82%|████████▏ | 4.09G/5.00G [01:51<00:23, 39.4MB/s]
#
#
# hf_model_0003_0.pt:  84%|████████▍ | 4.14G/4.92G [01:47<00:17, 43.4MB/s]
#
# hf_model_0002_2.pt:  82%|████████▏ | 4.10G/5.00G [01:51<00:26, 34.5MB/s]
#
#
# hf_model_0003_0.pt:  85%|████████▍ | 4.16G/4.92G [01:47<00:16, 45.1MB/s]
#
#
#
# hf_model_0003_1.pt:  80%|████████  | 3.94G/4.92G [01:47<00:22, 43.8MB/s]
#
# hf_model_0002_2.pt:  82%|████████▏ | 4.11G/5.00G [01:51<00:23, 38.4MB/s]
#
#
#
# hf_model_0003_1.pt:  80%|████████  | 3.95G/4.92G [01:47<00:21, 44.0MB/s]
#
# hf_model_0003_2.pt:  76%|███████▋  | 3.76G/4.92G [01:36<00:28, 41.2MB/s]
#
#
# hf_model_0002_2.pt:  83%|████████▎ | 4.13G/5.00G [01:52<00:20, 42.4MB/s]
#
#
#
# hf_model_0003_1.pt:  81%|████████  | 3.97G/4.92G [01:48<00:21, 43.8MB/s]
#
# hf_model_0003_2.pt:  77%|███████▋  | 3.78G/4.92G [01:36<00:26, 42.5MB/s]
#
#
# hf_model_0003_0.pt:  85%|████████▌ | 4.19G/4.92G [01:48<00:18, 39.0MB/s]
#
#
#
# hf_model_0003_1.pt:  81%|████████  | 3.98G/4.92G [01:48<00:20, 45.5MB/s]
#
# hf_model_0002_2.pt:  83%|████████▎ | 4.14G/5.00G [01:52<00:24, 35.3MB/s]
#
#
# hf_model_0003_0.pt:  86%|████████▌ | 4.21G/4.92G [01:48<00:17, 41.3MB/s]
#
#
#
#
# hf_model_0003_2.pt:  77%|███████▋  | 3.81G/4.92G [01:37<00:23, 47.3MB/s]
#
#
# hf_model_0003_0.pt:  86%|████████▌ | 4.22G/4.92G [01:49<00:16, 43.2MB/s]
#
#
# hf_model_0002_2.pt:  83%|████████▎ | 4.16G/5.00G [01:53<00:24, 33.9MB/s]
#
# hf_model_0003_2.pt:  78%|███████▊  | 3.82G/4.92G [01:37<00:24, 44.7MB/s]
#
#
# hf_model_0002_2.pt:  84%|████████▎ | 4.18G/5.00G [01:53<00:21, 38.3MB/s]
#
#
#
#
# hf_model_0003_2.pt:  78%|███████▊  | 3.84G/4.92G [01:38<00:23, 45.4MB/s]
#
#
# hf_model_0003_0.pt:  87%|████████▋ | 4.26G/4.92G [01:49<00:14, 45.1MB/s]
#
#
# hf_model_0002_2.pt:  84%|████████▍ | 4.19G/5.00G [01:54<00:23, 34.2MB/s]
#
#
# hf_model_0003_0.pt:  87%|████████▋ | 4.27G/4.92G [01:50<00:14, 44.4MB/s]
#
#
#
#
# hf_model_0003_2.pt:  78%|███████▊  | 3.86G/4.92G [01:39<00:32, 32.9MB/s]
#
#
# hf_model_0003_0.pt:  87%|████████▋ | 4.29G/4.92G [01:50<00:13, 44.9MB/s]
#
#
#
#
# hf_model_0003_2.pt:  79%|███████▉  | 3.87G/4.92G [01:39<00:27, 37.7MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  88%|████████▊ | 4.30G/4.92G [01:50<00:13, 45.0MB/s]
#
# hf_model_0003_2.pt:  79%|███████▉  | 3.89G/4.92G [01:39<00:25, 40.4MB/s]
#
#
# hf_model_0003_0.pt:  88%|████████▊ | 4.32G/4.92G [01:51<00:13, 45.2MB/s]
#
#
#
#
# hf_model_0003_2.pt:  79%|███████▉  | 3.90G/4.92G [01:40<00:23, 42.6MB/s]
#
#
# hf_model_0003_0.pt:  88%|████████▊ | 4.34G/4.92G [01:51<00:12, 48.3MB/s]
#
#
#
#
# hf_model_0003_2.pt:  80%|███████▉  | 3.92G/4.92G [01:40<00:22, 45.2MB/s]
#
#
# hf_model_0003_0.pt:  89%|████████▊ | 4.35G/4.92G [01:51<00:11, 48.2MB/s]
#
#
#
#
# hf_model_0003_2.pt:  80%|████████  | 3.94G/4.92G [01:40<00:20, 47.0MB/s]
#
#
# hf_model_0003_0.pt:  89%|████████▉ | 4.37G/4.92G [01:52<00:11, 47.0MB/s]
#
# hf_model_0003_2.pt:  80%|████████  | 3.95G/4.92G [01:41<00:20, 46.2MB/s]
#
#
# hf_model_0003_0.pt:  89%|████████▉ | 4.38G/4.92G [01:52<00:12, 43.4MB/s]
#
# hf_model_0003_2.pt:  81%|████████  | 3.97G/4.92G [01:41<00:20, 47.0MB/s]
#
#
#
#
# hf_model_0003_2.pt:  81%|████████  | 3.98G/4.92G [01:41<00:19, 47.4MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  90%|████████▉ | 4.40G/4.92G [01:53<00:14, 36.3MB/s]
#
# hf_model_0003_2.pt:  81%|████████▏ | 4.00G/4.92G [01:41<00:18, 48.5MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  90%|████████▉ | 4.42G/4.92G [01:53<00:12, 39.0MB/s]
#
# hf_model_0003_2.pt:  82%|████████▏ | 4.02G/4.92G [01:42<00:19, 47.2MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  90%|█████████ | 4.43G/4.92G [01:54<00:12, 39.6MB/s]
#
# hf_model_0003_2.pt:  82%|████████▏ | 4.03G/4.92G [01:42<00:20, 42.6MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  90%|█████████ | 4.45G/4.92G [01:54<00:11, 42.3MB/s]
#
#
#
#
# hf_model_0003_2.pt:  82%|████████▏ | 4.05G/4.92G [01:43<00:19, 44.6MB/s]
#
#
# hf_model_0003_0.pt:  91%|█████████ | 4.46G/4.92G [01:54<00:09, 45.4MB/s]
#
#
#
#
# hf_model_0003_2.pt:  83%|████████▎ | 4.06G/4.92G [01:43<00:20, 41.6MB/s]
#
#
# hf_model_0003_0.pt:  91%|█████████ | 4.48G/4.92G [01:55<00:10, 41.1MB/s]
#
# hf_model_0002_2.pt:  84%|████████▍ | 4.21G/5.00G [01:59<01:36, 8.16MB/s]
#
#
# hf_model_0002_2.pt:  84%|████████▍ | 4.22G/5.00G [01:59<01:08, 11.3MB/s]
#
# hf_model_0003_2.pt:  83%|████████▎ | 4.10G/4.92G [01:44<00:17, 46.0MB/s]
#
#
#
#
# hf_model_0003_2.pt:  84%|████████▎ | 4.11G/4.92G [01:44<00:17, 46.0MB/s]
#
#
#
#
# hf_model_0002_2.pt:  85%|████████▍ | 4.23G/5.00G [02:00<01:16, 10.1MB/s]
#
#
# hf_model_0003_0.pt:  92%|█████████▏| 4.51G/4.92G [01:56<00:15, 26.2MB/s]
#
#
#
#
# hf_model_0002_2.pt:  85%|████████▍ | 4.24G/5.00G [02:00<01:00, 12.5MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  92%|█████████▏| 4.53G/4.92G [01:57<00:13, 27.9MB/s]
#
# hf_model_0002_2.pt:  85%|████████▌ | 4.26G/5.00G [02:01<00:43, 17.0MB/s]
#
#
#
#
# hf_model_0002_2.pt:  85%|████████▌ | 4.27G/5.00G [02:01<00:33, 21.7MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  92%|█████████▏| 4.54G/4.92G [01:57<00:12, 28.8MB/s]
#
# hf_model_0003_2.pt:  85%|████████▌ | 4.19G/4.92G [01:46<00:15, 46.3MB/s]
#
#
# hf_model_0002_2.pt:  86%|████████▌ | 4.29G/5.00G [02:02<00:28, 25.1MB/s]
#
# hf_model_0003_2.pt:  86%|████████▌ | 4.21G/4.92G [01:46<00:15, 46.7MB/s]
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.56G/4.92G [01:58<00:12, 29.4MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.58G/4.92G [01:58<00:10, 33.5MB/s]
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.58G/4.92G [01:58<00:09, 35.7MB/s]
#
#
# hf_model_0002_2.pt:  86%|████████▋ | 4.32G/5.00G [02:03<00:26, 25.7MB/s]
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.59G/4.92G [01:59<00:15, 21.5MB/s]
#
# hf_model_0002_2.pt:  87%|████████▋ | 4.34G/5.00G [02:03<00:22, 30.0MB/s]
#
#
#
#
# hf_model_0003_2.pt:  86%|████████▋ | 4.24G/4.92G [01:48<00:23, 28.7MB/s]
#
#
# hf_model_0003_0.pt:  93%|█████████▎| 4.59G/4.92G [01:59<00:20, 15.6MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  94%|█████████▎| 4.60G/4.92G [02:00<00:18, 17.2MB/s]
#
# hf_model_0003_2.pt:  87%|████████▋ | 4.26G/4.92G [01:48<00:21, 31.4MB/s]
#
#
# hf_model_0003_0.pt:  94%|█████████▎| 4.60G/4.92G [02:00<00:16, 18.8MB/s]
#
#
#
#
#
# hf_model_0002_2.pt:  87%|████████▋ | 4.35G/5.00G [02:04<00:28, 22.5MB/s]
#
#
#
#
# hf_model_0003_2.pt:  87%|████████▋ | 4.27G/4.92G [01:49<00:21, 30.5MB/s]
#
#
# hf_model_0003_0.pt:  94%|█████████▎| 4.61G/4.92G [02:00<00:21, 14.3MB/s]
#
# hf_model_0002_2.pt:  87%|████████▋ | 4.37G/5.00G [02:05<00:24, 26.3MB/s]
#
#
#
# hf_model_0003_1.pt:  91%|█████████ | 4.46G/4.92G [02:01<00:12, 37.3MB/s]
#
# hf_model_0002_2.pt:  88%|████████▊ | 4.38G/5.00G [02:05<00:20, 30.3MB/s]
#
#
#
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.61G/4.92G [02:01<00:41, 7.32MB/s]
#
#
#
# hf_model_0003_1.pt:  91%|█████████▏| 4.50G/4.92G [02:01<00:10, 40.9MB/s]
#
# hf_model_0003_2.pt:  88%|████████▊ | 4.32G/4.92G [01:50<00:17, 35.0MB/s]
#
#
# hf_model_0002_2.pt:  88%|████████▊ | 4.40G/5.00G [02:06<00:21, 28.3MB/s]
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.63G/4.92G [02:02<00:14, 19.8MB/s]
#
#
#
# hf_model_0003_1.pt:  92%|█████████▏| 4.51G/4.92G [02:02<00:09, 42.8MB/s]
#
# hf_model_0003_2.pt:  88%|████████▊ | 4.34G/4.92G [01:50<00:15, 38.5MB/s]
#
#
#
# hf_model_0002_2.pt:  88%|████████▊ | 4.42G/5.00G [02:06<00:18, 31.0MB/s]
#
# hf_model_0003_2.pt:  89%|████████▊ | 4.35G/4.92G [01:51<00:13, 41.0MB/s]
#
#
# hf_model_0002_2.pt:  89%|████████▊ | 4.43G/5.00G [02:06<00:16, 33.7MB/s]
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.64G/4.92G [02:02<00:18, 15.4MB/s]
#
#
#
# hf_model_0003_1.pt:  92%|█████████▏| 4.54G/4.92G [02:02<00:08, 41.9MB/s]
#
# hf_model_0003_2.pt:  89%|████████▉ | 4.37G/4.92G [01:51<00:12, 43.0MB/s]
#
#
#
# hf_model_0003_1.pt:  93%|█████████▎| 4.56G/4.92G [02:03<00:08, 44.2MB/s]
#
# hf_model_0002_2.pt:  89%|████████▉ | 4.45G/5.00G [02:07<00:15, 34.6MB/s]
#
# hf_model_0003_2.pt:  90%|████████▉ | 4.40G/4.92G [01:52<00:11, 46.8MB/s]
#
#
#
# hf_model_0003_1.pt:  93%|█████████▎| 4.58G/4.92G [02:03<00:07, 44.6MB/s]
#
#
# hf_model_0003_0.pt:  94%|█████████▍| 4.64G/4.92G [02:03<00:28, 9.72MB/s]
#
#
# hf_model_0003_0.pt:  95%|█████████▍| 4.66G/4.92G [02:03<00:13, 19.4MB/s]
#
#
#
# hf_model_0003_1.pt:  93%|█████████▎| 4.59G/4.92G [02:03<00:07, 43.6MB/s]
#
# hf_model_0003_2.pt:  90%|████████▉ | 4.42G/4.92G [01:52<00:12, 40.3MB/s]
#
#
# hf_model_0002_2.pt:  89%|████████▉ | 4.46G/5.00G [02:08<00:20, 26.3MB/s]
#
#
#
# hf_model_0003_1.pt:  94%|█████████▎| 4.61G/4.92G [02:04<00:07, 43.7MB/s]
#
# hf_model_0003_2.pt:  90%|█████████ | 4.43G/4.92G [01:52<00:10, 44.8MB/s]
#
#
# hf_model_0002_2.pt:  90%|████████▉ | 4.48G/5.00G [02:08<00:17, 30.2MB/s]
#
# hf_model_0003_2.pt:  90%|█████████ | 4.45G/4.92G [01:53<00:11, 42.3MB/s]
#
#
#
# hf_model_0002_2.pt:  90%|████████▉ | 4.50G/5.00G [02:08<00:14, 34.2MB/s]
#
#
# hf_model_0003_0.pt:  96%|█████████▌| 4.70G/4.92G [02:05<00:06, 33.9MB/s]
#
# hf_model_0002_2.pt:  90%|█████████ | 4.51G/5.00G [02:09<00:13, 37.4MB/s]
#
#
#
# hf_model_0003_1.pt:  94%|█████████▍| 4.64G/4.92G [02:05<00:07, 37.9MB/s]
#
#
# hf_model_0003_0.pt:  96%|█████████▌| 4.72G/4.92G [02:05<00:05, 38.8MB/s]
#
# hf_model_0002_2.pt:  91%|█████████ | 4.53G/5.00G [02:09<00:11, 40.0MB/s]
#
#
# hf_model_0003_0.pt:  96%|█████████▋| 4.74G/4.92G [02:05<00:04, 41.5MB/s]
#
#
#
# hf_model_0003_1.pt:  95%|█████████▍| 4.66G/4.92G [02:05<00:06, 40.4MB/s]
#
# hf_model_0002_2.pt:  91%|█████████ | 4.54G/5.00G [02:10<00:10, 42.0MB/s]
#
#
# hf_model_0003_0.pt:  97%|█████████▋| 4.75G/4.92G [02:05<00:03, 43.0MB/s]
#
#
#
# hf_model_0002_2.pt:  91%|█████████ | 4.56G/5.00G [02:10<00:10, 43.8MB/s]
#
#
# hf_model_0003_0.pt:  97%|█████████▋| 4.77G/4.92G [02:06<00:03, 43.6MB/s]
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.51G/4.92G [01:54<00:10, 39.6MB/s]
#
#
#
# hf_model_0002_2.pt:  92%|█████████▏| 4.58G/5.00G [02:10<00:09, 43.8MB/s]
#
#
# hf_model_0003_0.pt:  97%|█████████▋| 4.78G/4.92G [02:06<00:02, 45.5MB/s]
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.53G/4.92G [01:55<00:09, 42.1MB/s]
#
#
#
# hf_model_0002_2.pt:  92%|█████████▏| 4.59G/5.00G [02:11<00:09, 42.7MB/s]
#
#
#
# hf_model_0003_1.pt:  96%|█████████▌| 4.72G/4.92G [02:07<00:04, 44.3MB/s]
#
#
# hf_model_0003_0.pt:  98%|█████████▊| 4.80G/4.92G [02:07<00:02, 42.6MB/s]
#
# hf_model_0003_2.pt:  92%|█████████▏| 4.54G/4.92G [01:55<00:09, 40.7MB/s]
#
#
#
# hf_model_0003_1.pt:  96%|█████████▋| 4.74G/4.92G [02:07<00:03, 45.4MB/s]
#
#
# hf_model_0002_2.pt:  92%|█████████▏| 4.61G/5.00G [02:11<00:09, 41.3MB/s]
#
# hf_model_0003_2.pt:  93%|█████████▎| 4.56G/4.92G [01:56<00:09, 36.5MB/s]
#
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.75G/4.92G [02:07<00:03, 48.9MB/s]
#
#
# hf_model_0002_2.pt:  92%|█████████▏| 4.62G/5.00G [02:11<00:08, 42.8MB/s]
#
# hf_model_0003_2.pt:  93%|█████████▎| 4.58G/4.92G [01:56<00:08, 40.0MB/s]
#
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.77G/4.92G [02:07<00:02, 49.4MB/s]
#
#
# hf_model_0003_0.pt:  99%|█████████▊| 4.85G/4.92G [02:08<00:01, 45.6MB/s]
#
# hf_model_0002_2.pt:  93%|█████████▎| 4.64G/5.00G [02:12<00:09, 38.4MB/s]
#
#
#
# hf_model_0003_1.pt:  97%|█████████▋| 4.78G/4.92G [02:08<00:02, 45.7MB/s]
#
#
# hf_model_0002_2.pt:  93%|█████████▎| 4.66G/5.00G [02:12<00:08, 41.4MB/s]
#
#
# hf_model_0003_0.pt:  99%|█████████▉| 4.88G/4.92G [02:08<00:00, 47.5MB/s]
#
#
#
# hf_model_0002_2.pt:  93%|█████████▎| 4.67G/5.00G [02:12<00:07, 45.2MB/s]
#
# hf_model_0003_2.pt:  94%|█████████▎| 4.61G/4.92G [01:57<00:08, 35.2MB/s]
#
#
# hf_model_0003_0.pt: 100%|█████████▉| 4.90G/4.92G [02:09<00:00, 44.8MB/s]
#
#
#
# hf_model_0003_1.pt:  98%|█████████▊| 4.82G/4.92G [02:09<00:02, 43.1MB/s]
#
# hf_model_0002_2.pt:  94%|█████████▍| 4.69G/5.00G [02:13<00:07, 41.5MB/s]
#
#
# hf_model_0003_0.pt: 100%|█████████▉| 4.91G/4.92G [02:09<00:00, 46.2MB/s]
#
#
#
# hf_model_0003_1.pt:  98%|█████████▊| 4.83G/4.92G [02:09<00:01, 45.2MB/s]
#
# hf_model_0003_0.pt: 100%|██████████| 4.92G/4.92G [02:09<00:00, 37.9MB/s]
#
#
#
#
# hf_model_0003_1.pt:  99%|█████████▊| 4.85G/4.92G [02:09<00:01, 46.4MB/s]
#
# hf_model_0002_2.pt:  94%|█████████▍| 4.72G/5.00G [02:14<00:06, 42.2MB/s]
#
#
#
# hf_model_0003_1.pt:  99%|█████████▉| 4.86G/4.92G [02:10<00:01, 47.5MB/s]
#
# hf_model_0002_2.pt:  95%|█████████▍| 4.74G/5.00G [02:14<00:06, 42.9MB/s]
#
#
#
# hf_model_0003_1.pt:  99%|█████████▉| 4.88G/4.92G [02:10<00:00, 47.8MB/s]
#
# hf_model_0002_2.pt:  95%|█████████▌| 4.75G/5.00G [02:14<00:05, 44.4MB/s]
#
#
#
# hf_model_0003_1.pt: 100%|█████████▉| 4.90G/4.92G [02:10<00:00, 47.9MB/s]
#
# hf_model_0002_2.pt:  95%|█████████▌| 4.77G/5.00G [02:15<00:05, 44.4MB/s]
#
# hf_model_0003_2.pt:  96%|█████████▌| 4.72G/4.92G [01:59<00:04, 46.9MB/s]
#
#
#
# hf_model_0002_2.pt:  96%|█████████▌| 4.78G/5.00G [02:15<00:04, 44.9MB/s]
#
# hf_model_0003_1.pt: 100%|██████████| 4.92G/4.92G [02:11<00:00, 37.3MB/s]
# hf_model_0002_2.pt:  97%|█████████▋| 4.83G/5.00G [02:16<00:03, 47.5MB/s]
#
# hf_model_0002_2.pt:  97%|█████████▋| 4.85G/5.00G [02:16<00:03, 45.0MB/s]
#
# hf_model_0002_2.pt:  97%|█████████▋| 4.86G/5.00G [02:17<00:03, 43.4MB/s]
#
# hf_model_0002_2.pt:  97%|█████████▋| 4.86G/5.00G [02:17<00:05, 23.6MB/s]
#
# hf_model_0002_2.pt:  97%|█████████▋| 4.87G/5.00G [02:18<00:06, 19.1MB/s]
#
# hf_model_0002_2.pt:  98%|█████████▊| 4.88G/5.00G [02:18<00:04, 24.7MB/s]
#
# hf_model_0002_2.pt:  98%|█████████▊| 4.90G/5.00G [02:18<00:03, 31.3MB/s]
#
# hf_model_0003_2.pt:  99%|█████████▊| 4.85G/4.92G [02:03<00:01, 39.6MB/s]
#
# hf_model_0003_2.pt:  99%|█████████▉| 4.86G/4.92G [02:03<00:01, 41.8MB/s]
#
# hf_model_0002_2.pt:  98%|█████████▊| 4.91G/5.00G [02:19<00:03, 22.5MB/s]
#
# hf_model_0002_2.pt:  99%|█████████▊| 4.93G/5.00G [02:20<00:02, 24.8MB/s]
#
# hf_model_0003_2.pt: 100%|██████████| 4.92G/4.92G [02:05<00:00, 39.1MB/s]
# hf_model_0002_2.pt: 100%|██████████| 5.00G/5.00G [02:22<00:00, 35.1MB/s]
#
#
#
#
#
# Upload 17 LFS files:  59%|█████▉    | 10/17 [04:24<03:37, 31.13s/it]oad 17 LFS files: 100%|██████████| 17/17 [04:24<00:00, 15.57s/it]
# https://huggingface.co/multimodalai/resume-critique-llama3_1_8b-tt_lora-model_3_2k-adapter-rev_3/tree/main/.
